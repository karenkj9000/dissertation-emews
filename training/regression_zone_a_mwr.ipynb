# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from pycaret.regression import *

# %%
root = os.path.join('..', 'data', 'imputed')
folder = 'mice'
df = pd.read_csv(os.path.join(root, f'{folder}_df.csv'))

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df[['day', 'date', 'zone_a_mwr_patients', 'zone_a_mwr_cat_3',
       'zone_a_mwr_cat_4', 'zone_a_mwr_sets_of_emews',
       'zone_a_mwr_deescalations', 'zone_a_mwr_escalations']]

# %%
df.columns
# Out:
# Index(['day', 'date', 'zone_a_mwr_patients', 'zone_a_mwr_cat_3',
#        'zone_a_mwr_cat_4', 'zone_a_mwr_sets_of_emews',
#        'zone_a_mwr_deescalations', 'zone_a_mwr_escalations'],
#       dtype='object')

# %% [markdown]
# ## Load Model (optional)

# %%
# pipeline_path = '../pipelines/base_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     created_models = {}

#     for name in model_names_to_load:
#         created_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(created_models)

# %% [markdown]
# ## Pycaret Setup

# %%
s = setup(df, target='zone_a_mwr_sets_of_emews', session_id=123, train_size=0.8)
# Out:
# <style type="text/css">
# #T_bccde_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bccde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bccde_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bccde_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bccde_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bccde_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bccde_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bccde_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bccde_row1_col1" class="data row1 col1" >zone_a_mwr_sets_of_emews</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bccde_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_bccde_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bccde_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_bccde_row3_col1" class="data row3 col1" >(599, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bccde_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_bccde_row4_col1" class="data row4 col1" >(599, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bccde_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_bccde_row5_col1" class="data row5 col1" >(479, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bccde_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_bccde_row6_col1" class="data row6 col1" >(120, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bccde_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_bccde_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bccde_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_bccde_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bccde_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_bccde_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bccde_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_bccde_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bccde_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_bccde_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bccde_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_bccde_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bccde_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_bccde_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bccde_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_bccde_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bccde_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_bccde_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bccde_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_bccde_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bccde_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_bccde_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bccde_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_bccde_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bccde_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_bccde_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bccde_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_bccde_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bccde_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_bccde_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bccde_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_bccde_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_bccde_row22_col1" class="data row22 col1" >b7d9</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(exclude=['lightgbm'], errors='raise')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:52:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_83cce th {
#   text-align: left;
# }
# #T_83cce_row0_col0, #T_83cce_row0_col5, #T_83cce_row1_col0, #T_83cce_row1_col1, #T_83cce_row1_col2, #T_83cce_row1_col3, #T_83cce_row1_col4, #T_83cce_row1_col5, #T_83cce_row1_col6, #T_83cce_row2_col0, #T_83cce_row2_col1, #T_83cce_row2_col2, #T_83cce_row2_col3, #T_83cce_row2_col4, #T_83cce_row2_col5, #T_83cce_row2_col6, #T_83cce_row3_col0, #T_83cce_row3_col1, #T_83cce_row3_col2, #T_83cce_row3_col3, #T_83cce_row3_col4, #T_83cce_row3_col5, #T_83cce_row3_col6, #T_83cce_row4_col0, #T_83cce_row4_col1, #T_83cce_row4_col2, #T_83cce_row4_col3, #T_83cce_row4_col4, #T_83cce_row4_col5, #T_83cce_row4_col6, #T_83cce_row5_col0, #T_83cce_row5_col1, #T_83cce_row5_col2, #T_83cce_row5_col3, #T_83cce_row5_col4, #T_83cce_row5_col5, #T_83cce_row5_col6, #T_83cce_row6_col0, #T_83cce_row6_col1, #T_83cce_row6_col2, #T_83cce_row6_col3, #T_83cce_row6_col4, #T_83cce_row6_col5, #T_83cce_row6_col6, #T_83cce_row7_col0, #T_83cce_row7_col1, #T_83cce_row7_col2, #T_83cce_row7_col3, #T_83cce_row7_col4, #T_83cce_row7_col5, #T_83cce_row7_col6, #T_83cce_row8_col0, #T_83cce_row8_col1, #T_83cce_row8_col2, #T_83cce_row8_col3, #T_83cce_row8_col4, #T_83cce_row8_col5, #T_83cce_row8_col6, #T_83cce_row9_col0, #T_83cce_row9_col1, #T_83cce_row9_col2, #T_83cce_row9_col3, #T_83cce_row9_col4, #T_83cce_row9_col5, #T_83cce_row9_col6, #T_83cce_row10_col0, #T_83cce_row10_col1, #T_83cce_row10_col2, #T_83cce_row10_col3, #T_83cce_row10_col4, #T_83cce_row10_col5, #T_83cce_row10_col6, #T_83cce_row11_col0, #T_83cce_row11_col1, #T_83cce_row11_col2, #T_83cce_row11_col3, #T_83cce_row11_col4, #T_83cce_row11_col5, #T_83cce_row11_col6, #T_83cce_row12_col0, #T_83cce_row12_col1, #T_83cce_row12_col2, #T_83cce_row12_col3, #T_83cce_row12_col4, #T_83cce_row12_col6, #T_83cce_row13_col0, #T_83cce_row13_col1, #T_83cce_row13_col2, #T_83cce_row13_col3, #T_83cce_row13_col4, #T_83cce_row13_col5, #T_83cce_row13_col6, #T_83cce_row14_col0, #T_83cce_row14_col1, #T_83cce_row14_col2, #T_83cce_row14_col3, #T_83cce_row14_col4, #T_83cce_row14_col5, #T_83cce_row14_col6, #T_83cce_row15_col0, #T_83cce_row15_col1, #T_83cce_row15_col2, #T_83cce_row15_col3, #T_83cce_row15_col4, #T_83cce_row15_col5, #T_83cce_row15_col6, #T_83cce_row16_col0, #T_83cce_row16_col1, #T_83cce_row16_col2, #T_83cce_row16_col3, #T_83cce_row16_col4, #T_83cce_row16_col5, #T_83cce_row16_col6, #T_83cce_row17_col0, #T_83cce_row17_col1, #T_83cce_row17_col2, #T_83cce_row17_col3, #T_83cce_row17_col4, #T_83cce_row17_col5, #T_83cce_row17_col6, #T_83cce_row18_col0, #T_83cce_row18_col1, #T_83cce_row18_col2, #T_83cce_row18_col3, #T_83cce_row18_col4, #T_83cce_row18_col5, #T_83cce_row18_col6 {
#   text-align: left;
# }
# #T_83cce_row0_col1, #T_83cce_row0_col2, #T_83cce_row0_col3, #T_83cce_row0_col4, #T_83cce_row0_col6, #T_83cce_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_83cce_row0_col7, #T_83cce_row1_col7, #T_83cce_row3_col7, #T_83cce_row8_col7, #T_83cce_row9_col7, #T_83cce_row10_col7, #T_83cce_row11_col7, #T_83cce_row12_col7, #T_83cce_row13_col7, #T_83cce_row14_col7, #T_83cce_row15_col7, #T_83cce_row17_col7, #T_83cce_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_83cce_row2_col7, #T_83cce_row4_col7, #T_83cce_row5_col7, #T_83cce_row6_col7, #T_83cce_row7_col7, #T_83cce_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_83cce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83cce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_83cce_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_83cce_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_83cce_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_83cce_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_83cce_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_83cce_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_83cce_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83cce_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_83cce_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_83cce_row0_col1" class="data row0 col1" >11.4296</td>
#       <td id="T_83cce_row0_col2" class="data row0 col2" >295.5266</td>
#       <td id="T_83cce_row0_col3" class="data row0 col3" >16.8348</td>
#       <td id="T_83cce_row0_col4" class="data row0 col4" >0.5566</td>
#       <td id="T_83cce_row0_col5" class="data row0 col5" >0.3593</td>
#       <td id="T_83cce_row0_col6" class="data row0 col6" >0.1563</td>
#       <td id="T_83cce_row0_col7" class="data row0 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_83cce_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_83cce_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_83cce_row1_col1" class="data row1 col1" >11.4418</td>
#       <td id="T_83cce_row1_col2" class="data row1 col2" >297.8158</td>
#       <td id="T_83cce_row1_col3" class="data row1 col3" >16.8968</td>
#       <td id="T_83cce_row1_col4" class="data row1 col4" >0.5534</td>
#       <td id="T_83cce_row1_col5" class="data row1 col5" >0.3588</td>
#       <td id="T_83cce_row1_col6" class="data row1 col6" >0.1565</td>
#       <td id="T_83cce_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_83cce_level0_row2" class="row_heading level0 row2" >llar</th>
#       <td id="T_83cce_row2_col0" class="data row2 col0" >Lasso Least Angle Regression</td>
#       <td id="T_83cce_row2_col1" class="data row2 col1" >11.4421</td>
#       <td id="T_83cce_row2_col2" class="data row2 col2" >297.8347</td>
#       <td id="T_83cce_row2_col3" class="data row2 col3" >16.8973</td>
#       <td id="T_83cce_row2_col4" class="data row2 col4" >0.5534</td>
#       <td id="T_83cce_row2_col5" class="data row2 col5" >0.3588</td>
#       <td id="T_83cce_row2_col6" class="data row2 col6" >0.1565</td>
#       <td id="T_83cce_row2_col7" class="data row2 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_83cce_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_83cce_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_83cce_row3_col1" class="data row3 col1" >11.4794</td>
#       <td id="T_83cce_row3_col2" class="data row3 col2" >299.8378</td>
#       <td id="T_83cce_row3_col3" class="data row3 col3" >16.9730</td>
#       <td id="T_83cce_row3_col4" class="data row3 col4" >0.5489</td>
#       <td id="T_83cce_row3_col5" class="data row3 col5" >0.3199</td>
#       <td id="T_83cce_row3_col6" class="data row3 col6" >0.1568</td>
#       <td id="T_83cce_row3_col7" class="data row3 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_83cce_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_83cce_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_83cce_row4_col1" class="data row4 col1" >11.5602</td>
#       <td id="T_83cce_row4_col2" class="data row4 col2" >300.9829</td>
#       <td id="T_83cce_row4_col3" class="data row4 col3" >17.0110</td>
#       <td id="T_83cce_row4_col4" class="data row4 col4" >0.5483</td>
#       <td id="T_83cce_row4_col5" class="data row4 col5" >0.3635</td>
#       <td id="T_83cce_row4_col6" class="data row4 col6" >0.1581</td>
#       <td id="T_83cce_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_83cce_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_83cce_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_83cce_row5_col1" class="data row5 col1" >11.6805</td>
#       <td id="T_83cce_row5_col2" class="data row5 col2" >308.1476</td>
#       <td id="T_83cce_row5_col3" class="data row5 col3" >17.2126</td>
#       <td id="T_83cce_row5_col4" class="data row5 col4" >0.5409</td>
#       <td id="T_83cce_row5_col5" class="data row5 col5" >0.3575</td>
#       <td id="T_83cce_row5
# ElasticNet(random_state=123)

# %% [markdown]
# ## Custom Metrics

# %%
from sklearn.metrics import r2_score, mean_squared_error

def r2_rounded(y_true, y_pred):
    """Calculates R2 score after rounding predictions to the nearest whole number."""
    return r2_score(y_true, np.round(y_pred))

def rmse_rounded(y_true, y_pred):
    """Calculates RMSE after rounding predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.round(y_pred)))

def r2_ceil(y_true, y_pred):
    """Calculates R2 score after ceiling predictions to the nearest whole number."""
    return r2_score(y_true, np.ceil(y_pred))

def rmse_ceil(y_true, y_pred):
    """Calculates RMSE after ceiling predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.ceil(y_pred)))

# %%
add_metric('R2_Rounded', 'R2_RND', r2_rounded, greater_is_better=True)
add_metric('RMSE_Rounded', 'RMSE_RND', rmse_rounded, greater_is_better=False)
add_metric('R2_Ceil', 'R2_CEIL', r2_ceil, greater_is_better=True)
add_metric('RMSE_Ceil', 'RMSE_CEIL', rmse_ceil, greater_is_better=False);

# %% [markdown]
# ## Analyze Model

# %%
model_names_to_create = ['br', 'lasso', 'llar', 'en', 'huber']
created_models = {}

for model_name in model_names_to_create:
    model_object = create_model(model_name, verbose=False)
    created_models[model_name] = model_object

# %% [markdown]
# ### Bayesian Ridge

# %%
evaluate_model(created_models['br'])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Lasso Regression

# %%
# evaluate_model(created_models['lasso'])

# %% [markdown]
# ### Lasso Least Angle Regression

# %%
# evaluate_model(created_models['llar'])

# %% [markdown]
# ### Elastic Net

# %%
# evaluate_model(created_models['en'])

# %% [markdown]
# ### Huber Regressor

# %%
# evaluate_model(created_models['huber'])

# %% [markdown]
# ## Prediction

# %%
holdout_predictions_metric = {}

for model_name, model_object in created_models.items():
    predict_model(model_object, verbose=False)
    holdout_predictions_metric[model_name] = pull()

# %%
# pipeline_path = '../pipelines/base_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in created_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %% [markdown]
# ## Tuning

# %%
# param_grids = {
#     'br': {
#         'max_iter': np.arange(50, 301, 50),
#         'alpha_1': np.logspace(-8, -3, 6),
#         'lambda_1': np.logspace(-8, -3, 6),
#         'alpha_2': np.logspace(-8, -3, 6),
#         'lambda_2': np.logspace(-8, -3, 6)
#     },
#     'lasso': {
#         'alpha': np.logspace(-4, 1, 6),
#         'selection': ['cyclic', 'random']
#     },
#     'llar': {
#         'alpha': np.logspace(-4, 1, 6),
#         'jitter': list(np.logspace(-7, -4, 4)) + [None]
#     },
#     'en': {
#         'alpha': np.logspace(-4, 1, 6),
#         'l1_ratio': np.linspace(0, 1, 9),
#         'max_iter': np.arange(100, 1001, 100),
#         'selection': ['cyclic', 'random']
#     },
#     'huber': {
#         'epsilon': [1.0, 1.1, 1.2, 1.25, 1.3, 1.35, 1.4, 1.5, 2.0],
#         'max_iter': np.arange(10, 101, 10),
#         'alpha': np.logspace(-6, -2, 5)
#     }
# }

# %%
tuned_models = {}

for model_name, model_object in created_models.items():
    print(f"Tuning model: {model_name}")
    tuned_models[model_name] = tune_model(
        model_object,
        search_library='scikit-optimize',
        n_iter=20,
        early_stopping=True
    )
    print("\r")
# Out:
# Tuning model: br
# <style type="text/css">
# #T_48f72_row10_col0, #T_48f72_row10_col1, #T_48f72_row10_col2, #T_48f72_row10_col3, #T_48f72_row10_col4, #T_48f72_row10_col5, #T_48f72_row10_col6, #T_48f72_row10_col7, #T_48f72_row10_col8, #T_48f72_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_48f72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48f72_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_48f72_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_48f72_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_48f72_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_48f72_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_48f72_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_48f72_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_48f72_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_48f72_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_48f72_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48f72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48f72_row0_col0" class="data row0 col0" >10.5224</td>
#       <td id="T_48f72_row0_col1" class="data row0 col1" >214.8553</td>
#       <td id="T_48f72_row0_col2" class="data row0 col2" >14.6579</td>
#       <td id="T_48f72_row0_col3" class="data row0 col3" >0.7133</td>
#       <td id="T_48f72_row0_col4" class="data row0 col4" >0.5811</td>
#       <td id="T_48f72_row0_col5" class="data row0 col5" >0.1748</td>
#       <td id="T_48f72_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_48f72_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_48f72_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_48f72_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48f72_row1_col0" class="data row1 col0" >11.7092</td>
#       <td id="T_48f72_row1_col1" class="data row1 col1" >297.1210</td>
#       <td id="T_48f72_row1_col2" class="data row1 col2" >17.2372</td>
#       <td id="T_48f72_row1_col3" class="data row1 col3" >0.6466</td>
#       <td id="T_48f72_row1_col4" class="data row1 col4" >0.2764</td>
#       <td id="T_48f72_row1_col5" class="data row1 col5" >0.1929</td>
#       <td id="T_48f72_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_48f72_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_48f72_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_48f72_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48f72_row2_col0" class="data row2 col0" >15.3663</td>
#       <td id="T_48f72_row2_col1" class="data row2 col1" >569.0316</td>
#       <td id="T_48f72_row2_col2" class="data row2 col2" >23.8544</td>
#       <td id="T_48f72_row2_col3" class="data row2 col3" >0.4197</td>
#       <td id="T_48f72_row2_col4" class="data row2 col4" >0.4858</td>
#       <td id="T_48f72_row2_col5" class="data row2 col5" >0.1958</td>
#       <td id="T_48f72_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_48f72_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_48f72_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_48f72_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48f72_row3_col0" class="data row3 col0" >10.0138</td>
#       <td id="T_48f72_row3_col1" class="data row3 col1" >199.0476</td>
#       <td id="T_48f72_row3_col2" class="data row3 col2" >14.1084</td>
#       <td id="T_48f72_row3_col3" class="data row3 col3" >0.6713</td>
#       <td id="T_48f72_row3_col4" class="data row3 col4" >0.4018</td>
#       <td id="T_48f72_row3_col5" class="data row3 col5" >0.1096</td>
#       <td id="T_48f72_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_48f72_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_48f72_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_48f72_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48f72_row4_col0" class="data row4 col0" >12.5860</td>
#       <td id="T_48f72_row4_col1" class="data row4 col1" >327.0530</td>
#       <td id="T_48f72_row4_col2" class="data row4 col2" >18.0846</td>
#       <td id="T_48f72_row4_col3" class="data row4 col3" >0.6777</td>
#       <td id="T_48f72_row4_col4" class="data row4 col4" >0.2038</td>
#       <td id="T_48f72_row4_col5" class="data row4 col5" >0.1518</td>
#       <td id="T_48f72_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_48f72_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_48f72_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_48f72_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48f72_row5_col0" class="data row5 col0" >12.4921</td>
#       <td id="T_48f72_row5_col1" class="data row5 col1" >291.1820</td>
#       <td id="T_48f72_row5_col2" class="data row5 col2" >17.0641</td>
#       <td id="T_48f72_row5_col3" class="data row5 col3" >0.2597</td>
#       <td id="T_48f72_row5_col4" class="data row5 col4" >0.1989</td>
#       <td id="T_48f72_row5_col5" class="data row5 col5" >0.1539</td>
#       <td id="T_48f72_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_48f72_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_48f72_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_48f72_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48f72_row6_col0" class="data row6 col0" >12.1715</td>
#       <td id="T_48f72_row6_col1" class="data row6 col1" >282.6883</td>
#       <td id="T_48f72_row6_col2" class="data row6 col2" >16.8133</td>
#       <td id="T_48f72_row6_col3" class="data row6 col3" >0.6379</td>
#       <td id="T_48f72_row6_col4" class="data row6 col4" >0.4293</td>
#       <td id="T_48f72_row6_col5" class="data row6 col5" >0.1573</td>
#       <td id="T_48f72_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_48f72_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_48f72_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_48f72_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_48f72_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_48f72_row7_col0" class="data row7 col0" >7.2558</td>
#       <td id="T_48f72_row7_col1" class="data row7 col1" >112.8456</td>
#       <td id="T_48f72_row7_col2" class="data row7 col2" >10.6229</td>
#       <td id="T_48f72_row7_col3" class="data row7 col3" >0.6990</td>
#       <td id="T_48f72_row7_col4" class="data row7 col4" >0.3808</td>
#       <td id="T_48f72_row7_col5" class="data row7 col5" >0.0932</td>
#       <td id="T_48f72_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_48f72_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_48f72_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_48f72_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: lasso
# <style type="text/css">
# #T_8b57c_row10_col0, #T_8b57c_row10_col1, #T_8b57c_row10_col2, #T_8b57c_row10_col3, #T_8b57c_row10_col4, #T_8b57c_row10_col5, #T_8b57c_row10_col6, #T_8b57c_row10_col7, #T_8b57c_row10_col8, #T_8b57c_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_8b57c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b57c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8b57c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8b57c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8b57c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8b57c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8b57c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_8b57c_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_8b57c_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_8b57c_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_8b57c_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b57c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b57c_row0_col0" class="data row0 col0" >9.9525</td>
#       <td id="T_8b57c_row0_col1" class="data row0 col1" >193.9179</td>
#       <td id="T_8b57c_row0_col2" class="data row0 col2" >13.9254</td>
#       <td id="T_8b57c_row0_col3" class="data row0 col3" >0.7412</td>
#       <td id="T_8b57c_row0_col4" class="data row0 col4" >0.5643</td>
#       <td id="T_8b57c_row0_col5" class="data row0 col5" >0.1691</td>
#       <td id="T_8b57c_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_8b57c_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_8b57c_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_8b57c_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b57c_row1_col0" class="data row1 col0" >11.7547</td>
#       <td id="T_8b57c_row1_col1" class="data row1 col1" >300.8501</td>
#       <td id="T_8b57c_row1_col2" class="data row1 col2" >17.3450</td>
#       <td id="T_8b57c_row1_col3" class="data row1 col3" >0.6421</td>
#       <td id="T_8b57c_row1_col4" class="data row1 col4" >0.2741</td>
#       <td id="T_8b57c_row1_col5" class="data row1 col5" >0.1900</td>
#       <td id="T_8b57c_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_8b57c_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_8b57c_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_8b57c_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b57c_row2_col0" class="data row2 col0" >15.5538</td>
#       <td id="T_8b57c_row2_col1" class="data row2 col1" >585.5116</td>
#       <td id="T_8b57c_row2_col2" class="data row2 col2" >24.1973</td>
#       <td id="T_8b57c_row2_col3" class="data row2 col3" >0.4029</td>
#       <td id="T_8b57c_row2_col4" class="data row2 col4" >0.4823</td>
#       <td id="T_8b57c_row2_col5" class="data row2 col5" >0.1965</td>
#       <td id="T_8b57c_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_8b57c_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_8b57c_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_8b57c_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b57c_row3_col0" class="data row3 col0" >9.9466</td>
#       <td id="T_8b57c_row3_col1" class="data row3 col1" >198.7801</td>
#       <td id="T_8b57c_row3_col2" class="data row3 col2" >14.0989</td>
#       <td id="T_8b57c_row3_col3" class="data row3 col3" >0.6717</td>
#       <td id="T_8b57c_row3_col4" class="data row3 col4" >0.4011</td>
#       <td id="T_8b57c_row3_col5" class="data row3 col5" >0.1085</td>
#       <td id="T_8b57c_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_8b57c_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_8b57c_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_8b57c_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b57c_row4_col0" class="data row4 col0" >12.6425</td>
#       <td id="T_8b57c_row4_col1" class="data row4 col1" >316.7639</td>
#       <td id="T_8b57c_row4_col2" class="data row4 col2" >17.7979</td>
#       <td id="T_8b57c_row4_col3" class="data row4 col3" >0.6878</td>
#       <td id="T_8b57c_row4_col4" class="data row4 col4" >0.2044</td>
#       <td id="T_8b57c_row4_col5" class="data row4 col5" >0.1533</td>
#       <td id="T_8b57c_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_8b57c_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_8b57c_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_8b57c_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b57c_row5_col0" class="data row5 col0" >12.4288</td>
#       <td id="T_8b57c_row5_col1" class="data row5 col1" >290.2013</td>
#       <td id="T_8b57c_row5_col2" class="data row5 col2" >17.0353</td>
#       <td id="T_8b57c_row5_col3" class="data row5 col3" >0.2622</td>
#       <td id="T_8b57c_row5_col4" class="data row5 col4" >0.1982</td>
#       <td id="T_8b57c_row5_col5" class="data row5 col5" >0.1531</td>
#       <td id="T_8b57c_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_8b57c_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_8b57c_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_8b57c_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b57c_row6_col0" class="data row6 col0" >12.1448</td>
#       <td id="T_8b57c_row6_col1" class="data row6 col1" >284.7478</td>
#       <td id="T_8b57c_row6_col2" class="data row6 col2" >16.8745</td>
#       <td id="T_8b57c_row6_col3" class="data row6 col3" >0.6353</td>
#       <td id="T_8b57c_row6_col4" class="data row6 col4" >0.4293</td>
#       <td id="T_8b57c_row6_col5" class="data row6 col5" >0.1572</td>
#       <td id="T_8b57c_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_8b57c_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_8b57c_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_8b57c_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8b57c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b57c_row7_col0" class="data row7 col0" >7.1784</td>
#       <td id="T_8b57c_row7_col1" class="data row7 col1" >112.8317</td>
#       <td id="T_8b57c_row7_col2" class="data row7 col2" >10.6222</td>
#       <td id="T_8b57c_row7_col3" class="data row7 col3" >0.6990</td>
#       <td id="T_8b57c_row7_col4" class="data row7 col4" >0.3738</td>
#       <td id="T_8b57c_row7_col5" class="data row7 col5" >0.0921</td>
#       <td id="T_8b57c_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_8b57c_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_8b57c_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_8b57c_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: llar
# <style type="text/css">
# #T_fe55e_row10_col0, #T_fe55e_row10_col1, #T_fe55e_row10_col2, #T_fe55e_row10_col3, #T_fe55e_row10_col4, #T_fe55e_row10_col5, #T_fe55e_row10_col6, #T_fe55e_row10_col7, #T_fe55e_row10_col8, #T_fe55e_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_fe55e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe55e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fe55e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fe55e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fe55e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fe55e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fe55e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_fe55e_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_fe55e_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_fe55e_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_fe55e_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe55e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe55e_row0_col0" class="data row0 col0" >10.1941</td>
#       <td id="T_fe55e_row0_col1" class="data row0 col1" >201.6088</td>
#       <td id="T_fe55e_row0_col2" class="data row0 col2" >14.1989</td>
#       <td id="T_fe55e_row0_col3" class="data row0 col3" >0.7309</td>
#       <td id="T_fe55e_row0_col4" class="data row0 col4" >0.5691</td>
#       <td id="T_fe55e_row0_col5" class="data row0 col5" >0.1715</td>
#       <td id="T_fe55e_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_fe55e_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_fe55e_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_fe55e_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe55e_row1_col0" class="data row1 col0" >11.7353</td>
#       <td id="T_fe55e_row1_col1" class="data row1 col1" >299.8234</td>
#       <td id="T_fe55e_row1_col2" class="data row1 col2" >17.3154</td>
#       <td id="T_fe55e_row1_col3" class="data row1 col3" >0.6434</td>
#       <td id="T_fe55e_row1_col4" class="data row1 col4" >0.2756</td>
#       <td id="T_fe55e_row1_col5" class="data row1 col5" >0.1919</td>
#       <td id="T_fe55e_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_fe55e_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_fe55e_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_fe55e_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe55e_row2_col0" class="data row2 col0" >15.4446</td>
#       <td id="T_fe55e_row2_col1" class="data row2 col1" >576.4397</td>
#       <td id="T_fe55e_row2_col2" class="data row2 col2" >24.0092</td>
#       <td id="T_fe55e_row2_col3" class="data row2 col3" >0.4121</td>
#       <td id="T_fe55e_row2_col4" class="data row2 col4" >0.4826</td>
#       <td id="T_fe55e_row2_col5" class="data row2 col5" >0.1963</td>
#       <td id="T_fe55e_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_fe55e_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_fe55e_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_fe55e_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe55e_row3_col0" class="data row3 col0" >9.8524</td>
#       <td id="T_fe55e_row3_col1" class="data row3 col1" >194.4009</td>
#       <td id="T_fe55e_row3_col2" class="data row3 col2" >13.9428</td>
#       <td id="T_fe55e_row3_col3" class="data row3 col3" >0.6789</td>
#       <td id="T_fe55e_row3_col4" class="data row3 col4" >0.3999</td>
#       <td id="T_fe55e_row3_col5" class="data row3 col5" >0.1078</td>
#       <td id="T_fe55e_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_fe55e_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_fe55e_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_fe55e_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe55e_row4_col0" class="data row4 col0" >12.4767</td>
#       <td id="T_fe55e_row4_col1" class="data row4 col1" >311.1516</td>
#       <td id="T_fe55e_row4_col2" class="data row4 col2" >17.6395</td>
#       <td id="T_fe55e_row4_col3" class="data row4 col3" >0.6933</td>
#       <td id="T_fe55e_row4_col4" class="data row4 col4" >0.2023</td>
#       <td id="T_fe55e_row4_col5" class="data row4 col5" >0.1512</td>
#       <td id="T_fe55e_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_fe55e_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_fe55e_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_fe55e_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe55e_row5_col0" class="data row5 col0" >12.4279</td>
#       <td id="T_fe55e_row5_col1" class="data row5 col1" >291.3689</td>
#       <td id="T_fe55e_row5_col2" class="data row5 col2" >17.0695</td>
#       <td id="T_fe55e_row5_col3" class="data row5 col3" >0.2592</td>
#       <td id="T_fe55e_row5_col4" class="data row5 col4" >0.1983</td>
#       <td id="T_fe55e_row5_col5" class="data row5 col5" >0.1528</td>
#       <td id="T_fe55e_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_fe55e_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_fe55e_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_fe55e_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe55e_row6_col0" class="data row6 col0" >12.1816</td>
#       <td id="T_fe55e_row6_col1" class="data row6 col1" >288.5449</td>
#       <td id="T_fe55e_row6_col2" class="data row6 col2" >16.9866</td>
#       <td id="T_fe55e_row6_col3" class="data row6 col3" >0.6304</td>
#       <td id="T_fe55e_row6_col4" class="data row6 col4" >0.4290</td>
#       <td id="T_fe55e_row6_col5" class="data row6 col5" >0.1577</td>
#       <td id="T_fe55e_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_fe55e_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_fe55e_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_fe55e_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_fe55e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fe55e_row7_col0" class="data row7 col0" >7.1554</td>
#       <td id="T_fe55e_row7_col1" class="data row7 col1" >111.1567</td>
#       <td id="T_fe55e_row7_col2" class="data row7 col2" >10.5431</td>
#       <td id="T_fe55e_row7_col3" class="data row7 col3" >0.7035</td>
#       <td id="T_fe55e_row7_col4" class="data row7 col4" >0.3707</td>
#       <td id="T_fe55e_row7_col5" class="data row7 col5" >0.0917</td>
#       <td id="T_fe55e_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_fe55e_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_fe55e_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_fe55e_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id=
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# Tuning model: en
# <style type="text/css">
# #T_c843f_row10_col0, #T_c843f_row10_col1, #T_c843f_row10_col2, #T_c843f_row10_col3, #T_c843f_row10_col4, #T_c843f_row10_col5, #T_c843f_row10_col6, #T_c843f_row10_col7, #T_c843f_row10_col8, #T_c843f_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_c843f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c843f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c843f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c843f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c843f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c843f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c843f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_c843f_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_c843f_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_c843f_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_c843f_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c843f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c843f_row0_col0" class="data row0 col0" >10.1199</td>
#       <td id="T_c843f_row0_col1" class="data row0 col1" >198.2761</td>
#       <td id="T_c843f_row0_col2" class="data row0 col2" >14.0811</td>
#       <td id="T_c843f_row0_col3" class="data row0 col3" >0.7354</td>
#       <td id="T_c843f_row0_col4" class="data row0 col4" >0.5717</td>
#       <td id="T_c843f_row0_col5" class="data row0 col5" >0.1710</td>
#       <td id="T_c843f_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_c843f_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_c843f_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_c843f_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c843f_row1_col0" class="data row1 col0" >11.7186</td>
#       <td id="T_c843f_row1_col1" class="data row1 col1" >298.4728</td>
#       <td id="T_c843f_row1_col2" class="data row1 col2" >17.2764</td>
#       <td id="T_c843f_row1_col3" class="data row1 col3" >0.6450</td>
#       <td id="T_c843f_row1_col4" class="data row1 col4" >0.2735</td>
#       <td id="T_c843f_row1_col5" class="data row1 col5" >0.1900</td>
#       <td id="T_c843f_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_c843f_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_c843f_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_c843f_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c843f_row2_col0" class="data row2 col0" >15.4287</td>
#       <td id="T_c843f_row2_col1" class="data row2 col1" >571.5592</td>
#       <td id="T_c843f_row2_col2" class="data row2 col2" >23.9073</td>
#       <td id="T_c843f_row2_col3" class="data row2 col3" >0.4171</td>
#       <td id="T_c843f_row2_col4" class="data row2 col4" >0.4840</td>
#       <td id="T_c843f_row2_col5" class="data row2 col5" >0.1961</td>
#       <td id="T_c843f_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_c843f_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_c843f_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_c843f_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c843f_row3_col0" class="data row3 col0" >9.9852</td>
#       <td id="T_c843f_row3_col1" class="data row3 col1" >198.2408</td>
#       <td id="T_c843f_row3_col2" class="data row3 col2" >14.0798</td>
#       <td id="T_c843f_row3_col3" class="data row3 col3" >0.6726</td>
#       <td id="T_c843f_row3_col4" class="data row3 col4" >0.4032</td>
#       <td id="T_c843f_row3_col5" class="data row3 col5" >0.1092</td>
#       <td id="T_c843f_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_c843f_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_c843f_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_c843f_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c843f_row4_col0" class="data row4 col0" >12.5710</td>
#       <td id="T_c843f_row4_col1" class="data row4 col1" >319.4824</td>
#       <td id="T_c843f_row4_col2" class="data row4 col2" >17.8741</td>
#       <td id="T_c843f_row4_col3" class="data row4 col3" >0.6851</td>
#       <td id="T_c843f_row4_col4" class="data row4 col4" >0.2041</td>
#       <td id="T_c843f_row4_col5" class="data row4 col5" >0.1524</td>
#       <td id="T_c843f_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_c843f_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_c843f_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_c843f_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c843f_row5_col0" class="data row5 col0" >12.4486</td>
#       <td id="T_c843f_row5_col1" class="data row5 col1" >290.7762</td>
#       <td id="T_c843f_row5_col2" class="data row5 col2" >17.0522</td>
#       <td id="T_c843f_row5_col3" class="data row5 col3" >0.2607</td>
#       <td id="T_c843f_row5_col4" class="data row5 col4" >0.1987</td>
#       <td id="T_c843f_row5_col5" class="data row5 col5" >0.1534</td>
#       <td id="T_c843f_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_c843f_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_c843f_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_c843f_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c843f_row6_col0" class="data row6 col0" >12.1549</td>
#       <td id="T_c843f_row6_col1" class="data row6 col1" >281.7981</td>
#       <td id="T_c843f_row6_col2" class="data row6 col2" >16.7868</td>
#       <td id="T_c843f_row6_col3" class="data row6 col3" >0.6391</td>
#       <td id="T_c843f_row6_col4" class="data row6 col4" >0.4299</td>
#       <td id="T_c843f_row6_col5" class="data row6 col5" >0.1574</td>
#       <td id="T_c843f_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_c843f_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_c843f_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_c843f_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c843f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c843f_row7_col0" class="data row7 col0" >7.2145</td>
#       <td id="T_c843f_row7_col1" class="data row7 col1" >113.0373</td>
#       <td id="T_c843f_row7_col2" class="data row7 col2" >10.6319</td>
#       <td id="T_c843f_row7_col3" class="data row7 col3" >0.6985</td>
#       <td id="T_c843f_row7_col4" class="data row7 col4" >0.3755</td>
#       <td id="T_c843f_row7_col5" class="data row7 col5" >0.0926</td>
#       <td id="T_c843f_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_c843f_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_c843f_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_c843f_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id=
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# Tuning model: huber
# <style type="text/css">
# #T_46af2_row10_col0, #T_46af2_row10_col1, #T_46af2_row10_col2, #T_46af2_row10_col3, #T_46af2_row10_col4, #T_46af2_row10_col5, #T_46af2_row10_col6, #T_46af2_row10_col7, #T_46af2_row10_col8, #T_46af2_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_46af2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46af2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_46af2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_46af2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_46af2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_46af2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_46af2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_46af2_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_46af2_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_46af2_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_46af2_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46af2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46af2_row0_col0" class="data row0 col0" >9.9036</td>
#       <td id="T_46af2_row0_col1" class="data row0 col1" >193.8363</td>
#       <td id="T_46af2_row0_col2" class="data row0 col2" >13.9225</td>
#       <td id="T_46af2_row0_col3" class="data row0 col3" >0.7413</td>
#       <td id="T_46af2_row0_col4" class="data row0 col4" >0.5150</td>
#       <td id="T_46af2_row0_col5" class="data row0 col5" >0.1638</td>
#       <td id="T_46af2_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_46af2_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_46af2_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_46af2_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46af2_row1_col0" class="data row1 col0" >12.2850</td>
#       <td id="T_46af2_row1_col1" class="data row1 col1" >306.9620</td>
#       <td id="T_46af2_row1_col2" class="data row1 col2" >17.5203</td>
#       <td id="T_46af2_row1_col3" class="data row1 col3" >0.6349</td>
#       <td id="T_46af2_row1_col4" class="data row1 col4" >0.2902</td>
#       <td id="T_46af2_row1_col5" class="data row1 col5" >0.2126</td>
#       <td id="T_46af2_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_46af2_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_46af2_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_46af2_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46af2_row2_col0" class="data row2 col0" >14.6654</td>
#       <td id="T_46af2_row2_col1" class="data row2 col1" >508.5266</td>
#       <td id="T_46af2_row2_col2" class="data row2 col2" >22.5505</td>
#       <td id="T_46af2_row2_col3" class="data row2 col3" >0.4814</td>
#       <td id="T_46af2_row2_col4" class="data row2 col4" >0.4492</td>
#       <td id="T_46af2_row2_col5" class="data row2 col5" >0.1894</td>
#       <td id="T_46af2_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_46af2_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_46af2_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_46af2_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46af2_row3_col0" class="data row3 col0" >10.3932</td>
#       <td id="T_46af2_row3_col1" class="data row3 col1" >210.6811</td>
#       <td id="T_46af2_row3_col2" class="data row3 col2" >14.5149</td>
#       <td id="T_46af2_row3_col3" class="data row3 col3" >0.6520</td>
#       <td id="T_46af2_row3_col4" class="data row3 col4" >0.3493</td>
#       <td id="T_46af2_row3_col5" class="data row3 col5" >0.1150</td>
#       <td id="T_46af2_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_46af2_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_46af2_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_46af2_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46af2_row4_col0" class="data row4 col0" >12.3938</td>
#       <td id="T_46af2_row4_col1" class="data row4 col1" >296.5953</td>
#       <td id="T_46af2_row4_col2" class="data row4 col2" >17.2219</td>
#       <td id="T_46af2_row4_col3" class="data row4 col3" >0.7077</td>
#       <td id="T_46af2_row4_col4" class="data row4 col4" >0.2067</td>
#       <td id="T_46af2_row4_col5" class="data row4 col5" >0.1532</td>
#       <td id="T_46af2_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_46af2_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_46af2_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_46af2_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46af2_row5_col0" class="data row5 col0" >12.5739</td>
#       <td id="T_46af2_row5_col1" class="data row5 col1" >300.5407</td>
#       <td id="T_46af2_row5_col2" class="data row5 col2" >17.3361</td>
#       <td id="T_46af2_row5_col3" class="data row5 col3" >0.2359</td>
#       <td id="T_46af2_row5_col4" class="data row5 col4" >0.1995</td>
#       <td id="T_46af2_row5_col5" class="data row5 col5" >0.1534</td>
#       <td id="T_46af2_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_46af2_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_46af2_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_46af2_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_46af2_row6_col0" class="data row6 col0" >11.9817</td>
#       <td id="T_46af2_row6_col1" class="data row6 col1" >277.3241</td>
#       <td id="T_46af2_row6_col2" class="data row6 col2" >16.6531</td>
#       <td id="T_46af2_row6_col3" class="data row6 col3" >0.6448</td>
#       <td id="T_46af2_row6_col4" class="data row6 col4" >0.3770</td>
#       <td id="T_46af2_row6_col5" class="data row6 col5" >0.1558</td>
#       <td id="T_46af2_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_46af2_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_46af2_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_46af2_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_46af2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_46af2_row7_col0" class="data row7 col0" >7.0117</td>
#       <td id="T_46af2_row7_col1" class="data row7 col1" >102.5824</td>
#       <td id="T_46af2_row7_col2" class="data row7 col2" >10.1283</td>
#       <td id="T_46af2_row7_col3" class="data row7 col3" >0.7264</td>
#       <td id="T_46af2_row7_col4" class="data row7 col4" >0.3163</td>
#       <td id="T_46af2_row7_col5" class="data row7 col5" >0.0900</td>
#       <td id="T_46af2_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_46af2_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_46af2_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_46af2_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id=
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %%
# pipeline_path = '../pipelines/tuned_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     tuned_models = {}

#     for name in model_names_to_load:
#         tuned_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(tuned_models)

# %%
# pipeline_path = '../pipelines/tuned_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in tuned_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %%
tuning_predictions_metric = {}

for model_name, model_object in tuned_models.items():
    predict_model(model_object, verbose=False)
    tuning_predictions_metric[model_name] = pull()

# %%
list_of_metric_dfs = []

file_name = 'temp_excel.xlsx'

# Iterate through the dictionary and append each DataFrame to the list
for model_name, metrics_df in holdout_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

# Concatenate all DataFrames into a single one
print("--- Holdout Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name) as writer:
    results_df.to_excel(writer, sheet_name='Base Model Metrics', index=False)

list_of_metric_dfs = []
for model_name, metrics_df in tuning_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

print("\n--- Tuned Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name, mode='a') as writer:
    results_df.to_excel(writer, sheet_name='Tuned Model Metrics', index=False)
# Out:
# --- Holdout Predictions DataFrame ---
#
#                           Model      MAE       MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0                Bayesian Ridge  10.2324  222.7322  14.9242  0.7350  0.3492  0.1247  0.7352   14.9189   0.7372    14.8621
# 1              Lasso Regression  10.1560  222.6730  14.9222  0.7351  0.3455  0.1237  0.7348   14.9315   0.7388    14.8158
# 2  Lasso Least Angle Regression  10.1556  222.6626  14.9219  0.7351  0.3454  0.1237  0.7348   14.9315   0.7388    14.8158
# 3                   Elastic Net  10.1909  222.9116  14.9302  0.7348  0.3456  0.1241  0.7350   14.9234   0.7362    14.8896
# 4               Huber Regressor   9.8681  215.9528  14.6953  0.7431  0.2657  0.1211  0.7418   14.7312   0.7462    14.6065
#
# --- Tuned Predictions DataFrame ---
#
#                           Model      MAE       MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0                Bayesian Ridge  10.2210  222.7694  14.9255  0.7350  0.3484  0.1246  0.7344   14.9421   0.7357    14.9039
# 1              Lasso Regression  10.1900  224.0412  14.9680  0.7335  0.3473  0.1240  0.7319   15.0114   0.7351    14.9229
# 2  Lasso Least Angle Regression  10.1556  222.6626  14.9219  0.7351  0.3454  0.1237  0.7348   14.9315   0.7388    14.8158
# 3                   Elastic Net  10.1909  222.9116  14.9302  0.7348  0.3456  0.1241  0.7350   14.9234   0.7362    14.8896
# 4               Huber Regressor  10.0374  215.9667  14.6958  0.7431  0.2820  0.1231  0.7437   14.6771   0.7465    14.5982
