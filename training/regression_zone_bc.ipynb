# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from pycaret.regression import *

# %%
root = os.path.join('..', 'data', 'imputed')
folder = 'mice'
df = pd.read_csv(os.path.join(root, f'{folder}_df.csv'))

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df[['day', 'date', 'zone_b/c_patients', 'zone_b/c_cat_2', 'zone_b/c_cat_3',
       'zone_b/c_sets_of_emews', 'zone_b/c_deescalations',
       'zone_b/c_escalations']]

# %%
df.columns
# Out:
# Index(['day', 'date', 'zone_b/c_patients', 'zone_b/c_cat_2', 'zone_b/c_cat_3',
#        'zone_b/c_sets_of_emews', 'zone_b/c_deescalations',
#        'zone_b/c_escalations'],
#       dtype='object')

# %% [markdown]
# ## Load Model (optional)

# %%
# pipeline_path = '../pipelines/base_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     created_models = {}

#     for name in model_names_to_load:
#         created_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(created_models)

# %% [markdown]
# ## Pycaret Setup

# %%
s = setup(df, target='zone_b/c_sets_of_emews', session_id=123, train_size=0.8)
# Out:
# <style type="text/css">
# #T_f8786_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8786">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8786_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8786_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8786_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8786_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8786_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8786_row1_col1" class="data row1 col1" >zone_b/c_sets_of_emews</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8786_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f8786_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8786_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f8786_row3_col1" class="data row3 col1" >(599, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8786_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f8786_row4_col1" class="data row4 col1" >(599, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8786_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f8786_row5_col1" class="data row5 col1" >(479, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8786_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f8786_row6_col1" class="data row6 col1" >(120, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f8786_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f8786_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f8786_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_f8786_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f8786_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f8786_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f8786_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f8786_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f8786_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f8786_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f8786_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f8786_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f8786_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f8786_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f8786_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f8786_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f8786_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f8786_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f8786_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_f8786_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f8786_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_f8786_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f8786_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_f8786_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f8786_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_f8786_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f8786_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_f8786_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f8786_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_f8786_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f8786_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f8786_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_f8786_row22_col1" class="data row22 col1" >14b0</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(exclude=['lightgbm'], errors='raise')
# Out:
# <style type="text/css">
# #T_77f3c th {
#   text-align: left;
# }
# #T_77f3c_row0_col0, #T_77f3c_row0_col1, #T_77f3c_row0_col2, #T_77f3c_row0_col3, #T_77f3c_row0_col5, #T_77f3c_row0_col6, #T_77f3c_row1_col0, #T_77f3c_row1_col1, #T_77f3c_row1_col2, #T_77f3c_row1_col3, #T_77f3c_row1_col4, #T_77f3c_row1_col5, #T_77f3c_row1_col6, #T_77f3c_row2_col0, #T_77f3c_row2_col4, #T_77f3c_row2_col5, #T_77f3c_row2_col6, #T_77f3c_row3_col0, #T_77f3c_row3_col1, #T_77f3c_row3_col2, #T_77f3c_row3_col3, #T_77f3c_row3_col4, #T_77f3c_row3_col5, #T_77f3c_row3_col6, #T_77f3c_row4_col0, #T_77f3c_row4_col1, #T_77f3c_row4_col2, #T_77f3c_row4_col3, #T_77f3c_row4_col4, #T_77f3c_row4_col5, #T_77f3c_row4_col6, #T_77f3c_row5_col0, #T_77f3c_row5_col1, #T_77f3c_row5_col2, #T_77f3c_row5_col3, #T_77f3c_row5_col4, #T_77f3c_row5_col5, #T_77f3c_row5_col6, #T_77f3c_row6_col0, #T_77f3c_row6_col1, #T_77f3c_row6_col2, #T_77f3c_row6_col3, #T_77f3c_row6_col4, #T_77f3c_row6_col5, #T_77f3c_row6_col6, #T_77f3c_row7_col0, #T_77f3c_row7_col1, #T_77f3c_row7_col2, #T_77f3c_row7_col3, #T_77f3c_row7_col4, #T_77f3c_row7_col5, #T_77f3c_row7_col6, #T_77f3c_row8_col0, #T_77f3c_row8_col1, #T_77f3c_row8_col2, #T_77f3c_row8_col3, #T_77f3c_row8_col4, #T_77f3c_row8_col5, #T_77f3c_row8_col6, #T_77f3c_row9_col0, #T_77f3c_row9_col1, #T_77f3c_row9_col2, #T_77f3c_row9_col3, #T_77f3c_row9_col4, #T_77f3c_row9_col5, #T_77f3c_row9_col6, #T_77f3c_row10_col0, #T_77f3c_row10_col1, #T_77f3c_row10_col2, #T_77f3c_row10_col3, #T_77f3c_row10_col4, #T_77f3c_row10_col5, #T_77f3c_row10_col6, #T_77f3c_row11_col0, #T_77f3c_row11_col1, #T_77f3c_row11_col2, #T_77f3c_row11_col3, #T_77f3c_row11_col4, #T_77f3c_row11_col5, #T_77f3c_row11_col6, #T_77f3c_row12_col0, #T_77f3c_row12_col1, #T_77f3c_row12_col2, #T_77f3c_row12_col3, #T_77f3c_row12_col4, #T_77f3c_row12_col5, #T_77f3c_row12_col6, #T_77f3c_row13_col0, #T_77f3c_row13_col1, #T_77f3c_row13_col2, #T_77f3c_row13_col3, #T_77f3c_row13_col4, #T_77f3c_row13_col5, #T_77f3c_row13_col6, #T_77f3c_row14_col0, #T_77f3c_row14_col1, #T_77f3c_row14_col2, #T_77f3c_row14_col3, #T_77f3c_row14_col4, #T_77f3c_row15_col0, #T_77f3c_row15_col1, #T_77f3c_row15_col2, #T_77f3c_row15_col3, #T_77f3c_row15_col4, #T_77f3c_row15_col5, #T_77f3c_row15_col6, #T_77f3c_row16_col0, #T_77f3c_row16_col1, #T_77f3c_row16_col2, #T_77f3c_row16_col3, #T_77f3c_row16_col4, #T_77f3c_row16_col5, #T_77f3c_row16_col6, #T_77f3c_row17_col0, #T_77f3c_row17_col1, #T_77f3c_row17_col2, #T_77f3c_row17_col3, #T_77f3c_row17_col4, #T_77f3c_row17_col5, #T_77f3c_row17_col6, #T_77f3c_row18_col0, #T_77f3c_row18_col1, #T_77f3c_row18_col2, #T_77f3c_row18_col3, #T_77f3c_row18_col4, #T_77f3c_row18_col5, #T_77f3c_row18_col6 {
#   text-align: left;
# }
# #T_77f3c_row0_col4, #T_77f3c_row2_col1, #T_77f3c_row2_col2, #T_77f3c_row2_col3, #T_77f3c_row14_col5, #T_77f3c_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_77f3c_row0_col7, #T_77f3c_row1_col7, #T_77f3c_row2_col7, #T_77f3c_row3_col7, #T_77f3c_row4_col7, #T_77f3c_row5_col7, #T_77f3c_row6_col7, #T_77f3c_row7_col7, #T_77f3c_row8_col7, #T_77f3c_row9_col7, #T_77f3c_row10_col7, #T_77f3c_row12_col7, #T_77f3c_row13_col7, #T_77f3c_row14_col7, #T_77f3c_row15_col7, #T_77f3c_row16_col7, #T_77f3c_row17_col7, #T_77f3c_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_77f3c_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_77f3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77f3c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_77f3c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_77f3c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_77f3c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_77f3c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_77f3c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_77f3c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_77f3c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77f3c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_77f3c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_77f3c_row0_col1" class="data row0 col1" >5.2395</td>
#       <td id="T_77f3c_row0_col2" class="data row0 col2" >81.9006</td>
#       <td id="T_77f3c_row0_col3" class="data row0 col3" >8.8488</td>
#       <td id="T_77f3c_row0_col4" class="data row0 col4" >0.2575</td>
#       <td id="T_77f3c_row0_col5" class="data row0 col5" >0.1567</td>
#       <td id="T_77f3c_row0_col6" class="data row0 col6" >0.0820</td>
#       <td id="T_77f3c_row0_col7" class="data row0 col7" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_77f3c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_77f3c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_77f3c_row1_col1" class="data row1 col1" >5.2335</td>
#       <td id="T_77f3c_row1_col2" class="data row1 col2" >83.0502</td>
#       <td id="T_77f3c_row1_col3" class="data row1 col3" >8.9061</td>
#       <td id="T_77f3c_row1_col4" class="data row1 col4" >0.2475</td>
#       <td id="T_77f3c_row1_col5" class="data row1 col5" >0.1694</td>
#       <td id="T_77f3c_row1_col6" class="data row1 col6" >0.0854</td>
#       <td id="T_77f3c_row1_col7" class="data row1 col7" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_77f3c_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_77f3c_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_77f3c_row2_col1" class="data row2 col1" >5.1641</td>
#       <td id="T_77f3c_row2_col2" class="data row2 col2" >80.2500</td>
#       <td id="T_77f3c_row2_col3" class="data row2 col3" >8.7926</td>
#       <td id="T_77f3c_row2_col4" class="data row2 col4" >0.2430</td>
#       <td id="T_77f3c_row2_col5" class="data row2 col5" >0.1641</td>
#       <td id="T_77f3c_row2_col6" class="data row2 col6" >0.0818</td>
#       <td id="T_77f3c_row2_col7" class="data row2 col7" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_77f3c_level0_row3" class="row_heading level0 row3" >omp</th>
#       <td id="T_77f3c_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_77f3c_row3_col1" class="data row3 col1" >5.5171</td>
#       <td id="T_77f3c_row3_col2" class="data row3 col2" >80.7923</td>
#       <td id="T_77f3c_row3_col3" class="data row3 col3" >8.8703</td>
#       <td id="T_77f3c_row3_col4" class="data row3 col4" >0.2208</td>
#       <td id="T_77f3c_row3_col5" class="data row3 col5" >0.1794</td>
#       <td id="T_77f3c_row3_col6" class="data row3 col6" >0.0916</td>
#       <td id="T_77f3c_row3_col7" class="data row3 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_77f3c_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_77f3c_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_77f3c_row4_col1" class="data row4 col1" >5.4515</td>
#       <td id="T_77f3c_row4_col2" class="data row4 col2" >81.8914</td>
#       <td id="T_77f3c_row4_col3" class="data row4 col3" >8.8916</td>
#       <td id="T_77f3c_row4_col4" class="data row4 col4" >0.2198</td>
#       <td id="T_77f3c_row4_col5" class="data row4 col5" >0.1801</td>
#       <td id="T_77f3c_row4_col6" class="data row4 col6" >0.0907</td>
#       <td id="T_77f3c_row4_col7" class="data row4 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_77f3c_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_77f3c_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_77f3c_row5_col1" class="data row5 col1" >5.4515</td>
#       <td id="T_77f3c_row5_col2" class="data row5 col2" >81.8913</td>
#       <td id="T_77f3c_row5_col3" class="data row5 col3" >8.8916</td>
#       <td id="T_77f3c_row5_col4" class="data row5 col4" >0.2198</td>
#       <td id="T_77f3c_row5_col5" class="data row5 col5" >0.1801</td>
#       <td id="T_77f
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## Custom Metrics

# %%
from sklearn.metrics import r2_score, mean_squared_error

def r2_rounded(y_true, y_pred):
    """Calculates R2 score after rounding predictions to the nearest whole number."""
    return r2_score(y_true, np.round(y_pred))

def rmse_rounded(y_true, y_pred):
    """Calculates RMSE after rounding predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.round(y_pred)))

def r2_ceil(y_true, y_pred):
    """Calculates R2 score after ceiling predictions to the nearest whole number."""
    return r2_score(y_true, np.ceil(y_pred))

def rmse_ceil(y_true, y_pred):
    """Calculates RMSE after ceiling predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.ceil(y_pred)))

# %%
add_metric('R2_Rounded', 'R2_RND', r2_rounded, greater_is_better=True)
add_metric('RMSE_Rounded', 'RMSE_RND', rmse_rounded, greater_is_better=False)
add_metric('R2_Ceil', 'R2_CEIL', r2_ceil, greater_is_better=True)
add_metric('RMSE_Ceil', 'RMSE_CEIL', rmse_ceil, greater_is_better=False);

# %% [markdown]
# ## Analyze Model

# %%
model_names_to_create = ['et', 'rf', 'catboost', 'omp', 'lasso']
created_models = {}

for model_name in model_names_to_create:
    model_object = create_model(model_name, verbose=False)
    created_models[model_name] = model_object

# %% [markdown]
# ### Bayesian Ridge

# %%
# evaluate_model(created_models['br'])

# %% [markdown]
# ### Lasso Regression

# %%
# evaluate_model(created_models['lasso'])

# %% [markdown]
# ### Lasso Least Angle Regression

# %%
# evaluate_model(created_models['llar'])

# %% [markdown]
# ### Elastic Net

# %%
# evaluate_model(created_models['en'])

# %% [markdown]
# ### Huber Regressor

# %%
# evaluate_model(created_models['huber'])

# %% [markdown]
# ## Prediction

# %%
holdout_predictions_metric = {}

for model_name, model_object in created_models.items():
    predict_model(model_object, verbose=False)
    holdout_predictions_metric[model_name] = pull()

# %%
# pipeline_path = '../pipelines/base_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in created_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %% [markdown]
# ## Tuning

# %%
# param_grids = {
#     'br': {
#         'max_iter': np.arange(50, 301, 50),
#         'alpha_1': np.logspace(-8, -3, 6),
#         'lambda_1': np.logspace(-8, -3, 6),
#         'alpha_2': np.logspace(-8, -3, 6),
#         'lambda_2': np.logspace(-8, -3, 6)
#     },
#     'lasso': {
#         'alpha': np.logspace(-4, 1, 6),
#         'selection': ['cyclic', 'random']
#     },
#     'llar': {
#         'alpha': np.logspace(-4, 1, 6),
#         'jitter': list(np.logspace(-7, -4, 4)) + [None]
#     },
#     'en': {
#         'alpha': np.logspace(-4, 1, 6),
#         'l1_ratio': np.linspace(0, 1, 9),
#         'max_iter': np.arange(100, 1001, 100),
#         'selection': ['cyclic', 'random']
#     },
#     'huber': {
#         'epsilon': [1.0, 1.1, 1.2, 1.25, 1.3, 1.35, 1.4, 1.5, 2.0],
#         'max_iter': np.arange(10, 101, 10),
#         'alpha': np.logspace(-6, -2, 5)
#     }
# }

# %%
tuned_models = {}

for model_name, model_object in created_models.items():
    print(f"Tuning model: {model_name}")
    tuned_models[model_name] = tune_model(
        model_object,
        search_library='scikit-optimize',
        n_iter=20,
        early_stopping=True
    )
    print("\r")
# Out:
# Tuning model: et
# <style type="text/css">
# #T_9e1e3_row10_col0, #T_9e1e3_row10_col1, #T_9e1e3_row10_col2, #T_9e1e3_row10_col3, #T_9e1e3_row10_col4, #T_9e1e3_row10_col5, #T_9e1e3_row10_col6, #T_9e1e3_row10_col7, #T_9e1e3_row10_col8, #T_9e1e3_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_9e1e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e1e3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9e1e3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9e1e3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9e1e3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9e1e3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9e1e3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_9e1e3_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_9e1e3_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_9e1e3_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_9e1e3_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e1e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e1e3_row0_col0" class="data row0 col0" >4.8732</td>
#       <td id="T_9e1e3_row0_col1" class="data row0 col1" >75.9545</td>
#       <td id="T_9e1e3_row0_col2" class="data row0 col2" >8.7152</td>
#       <td id="T_9e1e3_row0_col3" class="data row0 col3" >0.3274</td>
#       <td id="T_9e1e3_row0_col4" class="data row0 col4" >0.1733</td>
#       <td id="T_9e1e3_row0_col5" class="data row0 col5" >0.1011</td>
#       <td id="T_9e1e3_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_9e1e3_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_9e1e3_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_9e1e3_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e1e3_row1_col0" class="data row1 col0" >5.2301</td>
#       <td id="T_9e1e3_row1_col1" class="data row1 col1" >65.6290</td>
#       <td id="T_9e1e3_row1_col2" class="data row1 col2" >8.1012</td>
#       <td id="T_9e1e3_row1_col3" class="data row1 col3" >0.5654</td>
#       <td id="T_9e1e3_row1_col4" class="data row1 col4" >0.2268</td>
#       <td id="T_9e1e3_row1_col5" class="data row1 col5" >0.1382</td>
#       <td id="T_9e1e3_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_9e1e3_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_9e1e3_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_9e1e3_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e1e3_row2_col0" class="data row2 col0" >4.9613</td>
#       <td id="T_9e1e3_row2_col1" class="data row2 col1" >59.8314</td>
#       <td id="T_9e1e3_row2_col2" class="data row2 col2" >7.7351</td>
#       <td id="T_9e1e3_row2_col3" class="data row2 col3" >0.1014</td>
#       <td id="T_9e1e3_row2_col4" class="data row2 col4" >0.1206</td>
#       <td id="T_9e1e3_row2_col5" class="data row2 col5" >0.0775</td>
#       <td id="T_9e1e3_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_9e1e3_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_9e1e3_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_9e1e3_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e1e3_row3_col0" class="data row3 col0" >3.9574</td>
#       <td id="T_9e1e3_row3_col1" class="data row3 col1" >29.8451</td>
#       <td id="T_9e1e3_row3_col2" class="data row3 col2" >5.4631</td>
#       <td id="T_9e1e3_row3_col3" class="data row3 col3" >0.1380</td>
#       <td id="T_9e1e3_row3_col4" class="data row3 col4" >0.0736</td>
#       <td id="T_9e1e3_row3_col5" class="data row3 col5" >0.0537</td>
#       <td id="T_9e1e3_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_9e1e3_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_9e1e3_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_9e1e3_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e1e3_row4_col0" class="data row4 col0" >6.6655</td>
#       <td id="T_9e1e3_row4_col1" class="data row4 col1" >133.9213</td>
#       <td id="T_9e1e3_row4_col2" class="data row4 col2" >11.5724</td>
#       <td id="T_9e1e3_row4_col3" class="data row4 col3" >0.4663</td>
#       <td id="T_9e1e3_row4_col4" class="data row4 col4" >0.5264</td>
#       <td id="T_9e1e3_row4_col5" class="data row4 col5" >0.0739</td>
#       <td id="T_9e1e3_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_9e1e3_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_9e1e3_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_9e1e3_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e1e3_row5_col0" class="data row5 col0" >4.3376</td>
#       <td id="T_9e1e3_row5_col1" class="data row5 col1" >55.5750</td>
#       <td id="T_9e1e3_row5_col2" class="data row5 col2" >7.4549</td>
#       <td id="T_9e1e3_row5_col3" class="data row5 col3" >0.2679</td>
#       <td id="T_9e1e3_row5_col4" class="data row5 col4" >0.0920</td>
#       <td id="T_9e1e3_row5_col5" class="data row5 col5" >0.0603</td>
#       <td id="T_9e1e3_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_9e1e3_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_9e1e3_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_9e1e3_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e1e3_row6_col0" class="data row6 col0" >4.4445</td>
#       <td id="T_9e1e3_row6_col1" class="data row6 col1" >50.7846</td>
#       <td id="T_9e1e3_row6_col2" class="data row6 col2" >7.1263</td>
#       <td id="T_9e1e3_row6_col3" class="data row6 col3" >0.1222</td>
#       <td id="T_9e1e3_row6_col4" class="data row6 col4" >0.0975</td>
#       <td id="T_9e1e3_row6_col5" class="data row6 col5" >0.0621</td>
#       <td id="T_9e1e3_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_9e1e3_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_9e1e3_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_9e1e3_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e1e3_row7_col0" class="data row7 col0" >5.7840</td>
#       <td id="T_9e1e3_row7_col1" class="data row7 col1" >116.8838</td>
#       <td id="T_9e1e3_row7_col2" class="data row7 col2" >10.8113</td>
#       <td id="T_9e1e3_row7_col3" class="data row7 col3" >0.2404</td>
#       <td id="T_9e1e3_row7_col4" class="data row7 col4" >0.1590</td>
#       <td id="T_9e1e3_row7_col5" class="data row7 col5" >0.0946</td>
#       <td id="T_9e1e3_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_9e1e3_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_9e1e3_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_9e1e3_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9e1e3_level0_ro
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: rf
# <style type="text/css">
# #T_f019d_row10_col0, #T_f019d_row10_col1, #T_f019d_row10_col2, #T_f019d_row10_col3, #T_f019d_row10_col4, #T_f019d_row10_col5, #T_f019d_row10_col6, #T_f019d_row10_col7, #T_f019d_row10_col8, #T_f019d_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_f019d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f019d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f019d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f019d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f019d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f019d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f019d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_f019d_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_f019d_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_f019d_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_f019d_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f019d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f019d_row0_col0" class="data row0 col0" >4.9389</td>
#       <td id="T_f019d_row0_col1" class="data row0 col1" >80.2342</td>
#       <td id="T_f019d_row0_col2" class="data row0 col2" >8.9574</td>
#       <td id="T_f019d_row0_col3" class="data row0 col3" >0.2895</td>
#       <td id="T_f019d_row0_col4" class="data row0 col4" >0.1785</td>
#       <td id="T_f019d_row0_col5" class="data row0 col5" >0.1044</td>
#       <td id="T_f019d_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_f019d_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_f019d_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_f019d_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f019d_row1_col0" class="data row1 col0" >5.0425</td>
#       <td id="T_f019d_row1_col1" class="data row1 col1" >62.9179</td>
#       <td id="T_f019d_row1_col2" class="data row1 col2" >7.9321</td>
#       <td id="T_f019d_row1_col3" class="data row1 col3" >0.5834</td>
#       <td id="T_f019d_row1_col4" class="data row1 col4" >0.2142</td>
#       <td id="T_f019d_row1_col5" class="data row1 col5" >0.1261</td>
#       <td id="T_f019d_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_f019d_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_f019d_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_f019d_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f019d_row2_col0" class="data row2 col0" >4.6253</td>
#       <td id="T_f019d_row2_col1" class="data row2 col1" >55.8073</td>
#       <td id="T_f019d_row2_col2" class="data row2 col2" >7.4704</td>
#       <td id="T_f019d_row2_col3" class="data row2 col3" >0.1618</td>
#       <td id="T_f019d_row2_col4" class="data row2 col4" >0.1187</td>
#       <td id="T_f019d_row2_col5" class="data row2 col5" >0.0737</td>
#       <td id="T_f019d_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_f019d_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_f019d_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_f019d_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f019d_row3_col0" class="data row3 col0" >3.7849</td>
#       <td id="T_f019d_row3_col1" class="data row3 col1" >26.8088</td>
#       <td id="T_f019d_row3_col2" class="data row3 col2" >5.1777</td>
#       <td id="T_f019d_row3_col3" class="data row3 col3" >0.2256</td>
#       <td id="T_f019d_row3_col4" class="data row3 col4" >0.0696</td>
#       <td id="T_f019d_row3_col5" class="data row3 col5" >0.0514</td>
#       <td id="T_f019d_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_f019d_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_f019d_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_f019d_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f019d_row4_col0" class="data row4 col0" >6.7777</td>
#       <td id="T_f019d_row4_col1" class="data row4 col1" >125.8684</td>
#       <td id="T_f019d_row4_col2" class="data row4 col2" >11.2191</td>
#       <td id="T_f019d_row4_col3" class="data row4 col3" >0.4984</td>
#       <td id="T_f019d_row4_col4" class="data row4 col4" >0.5070</td>
#       <td id="T_f019d_row4_col5" class="data row4 col5" >0.0774</td>
#       <td id="T_f019d_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_f019d_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_f019d_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_f019d_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f019d_row5_col0" class="data row5 col0" >4.3449</td>
#       <td id="T_f019d_row5_col1" class="data row5 col1" >63.6558</td>
#       <td id="T_f019d_row5_col2" class="data row5 col2" >7.9785</td>
#       <td id="T_f019d_row5_col3" class="data row5 col3" >0.1615</td>
#       <td id="T_f019d_row5_col4" class="data row5 col4" >0.0991</td>
#       <td id="T_f019d_row5_col5" class="data row5 col5" >0.0610</td>
#       <td id="T_f019d_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_f019d_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_f019d_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_f019d_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f019d_row6_col0" class="data row6 col0" >4.4388</td>
#       <td id="T_f019d_row6_col1" class="data row6 col1" >53.3973</td>
#       <td id="T_f019d_row6_col2" class="data row6 col2" >7.3073</td>
#       <td id="T_f019d_row6_col3" class="data row6 col3" >0.0770</td>
#       <td id="T_f019d_row6_col4" class="data row6 col4" >0.1011</td>
#       <td id="T_f019d_row6_col5" class="data row6 col5" >0.0622</td>
#       <td id="T_f019d_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_f019d_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_f019d_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_f019d_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f019d_row7_col0" class="data row7 col0" >5.9417</td>
#       <td id="T_f019d_row7_col1" class="data row7 col1" >126.5160</td>
#       <td id="T_f019d_row7_col2" class="data row7 col2" >11.2479</td>
#       <td id="T_f019d_row7_col3" class="data row7 col3" >0.1778</td>
#       <td id="T_f019d_row7_col4" class="data row7 col4" >0.1662</td>
#       <td id="T_f019d_row7_col5" class="data row7 col5" >0.0972</td>
#       <td id="T_f019d_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_f019d_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_f019d_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_f019d_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f019d_level0_ro
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: catboost
# <style type="text/css">
# #T_c3468_row10_col0, #T_c3468_row10_col1, #T_c3468_row10_col2, #T_c3468_row10_col3, #T_c3468_row10_col4, #T_c3468_row10_col5, #T_c3468_row10_col6, #T_c3468_row10_col7, #T_c3468_row10_col8, #T_c3468_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_c3468">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3468_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c3468_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c3468_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c3468_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c3468_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c3468_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_c3468_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_c3468_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_c3468_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_c3468_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3468_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3468_row0_col0" class="data row0 col0" >5.4882</td>
#       <td id="T_c3468_row0_col1" class="data row0 col1" >97.0293</td>
#       <td id="T_c3468_row0_col2" class="data row0 col2" >9.8503</td>
#       <td id="T_c3468_row0_col3" class="data row0 col3" >0.1408</td>
#       <td id="T_c3468_row0_col4" class="data row0 col4" >0.1908</td>
#       <td id="T_c3468_row0_col5" class="data row0 col5" >0.1151</td>
#       <td id="T_c3468_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_c3468_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_c3468_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_c3468_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3468_row1_col0" class="data row1 col0" >5.9591</td>
#       <td id="T_c3468_row1_col1" class="data row1 col1" >76.2043</td>
#       <td id="T_c3468_row1_col2" class="data row1 col2" >8.7295</td>
#       <td id="T_c3468_row1_col3" class="data row1 col3" >0.4954</td>
#       <td id="T_c3468_row1_col4" class="data row1 col4" >0.2581</td>
#       <td id="T_c3468_row1_col5" class="data row1 col5" >0.1734</td>
#       <td id="T_c3468_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_c3468_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_c3468_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_c3468_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3468_row2_col0" class="data row2 col0" >5.0730</td>
#       <td id="T_c3468_row2_col1" class="data row2 col1" >62.9478</td>
#       <td id="T_c3468_row2_col2" class="data row2 col2" >7.9340</td>
#       <td id="T_c3468_row2_col3" class="data row2 col3" >0.0546</td>
#       <td id="T_c3468_row2_col4" class="data row2 col4" >0.1247</td>
#       <td id="T_c3468_row2_col5" class="data row2 col5" >0.0816</td>
#       <td id="T_c3468_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_c3468_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_c3468_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_c3468_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3468_row3_col0" class="data row3 col0" >4.0880</td>
#       <td id="T_c3468_row3_col1" class="data row3 col1" >30.3417</td>
#       <td id="T_c3468_row3_col2" class="data row3 col2" >5.5083</td>
#       <td id="T_c3468_row3_col3" class="data row3 col3" >0.1236</td>
#       <td id="T_c3468_row3_col4" class="data row3 col4" >0.0749</td>
#       <td id="T_c3468_row3_col5" class="data row3 col5" >0.0556</td>
#       <td id="T_c3468_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_c3468_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_c3468_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_c3468_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3468_row4_col0" class="data row4 col0" >6.7223</td>
#       <td id="T_c3468_row4_col1" class="data row4 col1" >134.8683</td>
#       <td id="T_c3468_row4_col2" class="data row4 col2" >11.6133</td>
#       <td id="T_c3468_row4_col3" class="data row4 col3" >0.4625</td>
#       <td id="T_c3468_row4_col4" class="data row4 col4" >0.5174</td>
#       <td id="T_c3468_row4_col5" class="data row4 col5" >0.0764</td>
#       <td id="T_c3468_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_c3468_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_c3468_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_c3468_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3468_row5_col0" class="data row5 col0" >4.0027</td>
#       <td id="T_c3468_row5_col1" class="data row5 col1" >61.7411</td>
#       <td id="T_c3468_row5_col2" class="data row5 col2" >7.8576</td>
#       <td id="T_c3468_row5_col3" class="data row5 col3" >0.1867</td>
#       <td id="T_c3468_row5_col4" class="data row5 col4" >0.0919</td>
#       <td id="T_c3468_row5_col5" class="data row5 col5" >0.0529</td>
#       <td id="T_c3468_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_c3468_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_c3468_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_c3468_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3468_row6_col0" class="data row6 col0" >4.6973</td>
#       <td id="T_c3468_row6_col1" class="data row6 col1" >47.0288</td>
#       <td id="T_c3468_row6_col2" class="data row6 col2" >6.8578</td>
#       <td id="T_c3468_row6_col3" class="data row6 col3" >0.1871</td>
#       <td id="T_c3468_row6_col4" class="data row6 col4" >0.0961</td>
#       <td id="T_c3468_row6_col5" class="data row6 col5" >0.0671</td>
#       <td id="T_c3468_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_c3468_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_c3468_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_c3468_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3468_row7_col0" class="data row7 col0" >6.9043</td>
#       <td id="T_c3468_row7_col1" class="data row7 col1" >142.7782</td>
#       <td id="T_c3468_row7_col2" class="data row7 col2" >11.9490</td>
#       <td id="T_c3468_row7_col3" class="data row7 col3" >0.0721</td>
#       <td id="T_c3468_row7_col4" class="data row7 col4" >0.1800</td>
#       <td id="T_c3468_row7_col5" class="data row7 col5" >0.1119</td>
#       <td id="T_c3468_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_c3468_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_c3468_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_c3468_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3468_level0_ro
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# Tuning model: omp
# <style type="text/css">
# #T_5dc18_row10_col0, #T_5dc18_row10_col1, #T_5dc18_row10_col2, #T_5dc18_row10_col3, #T_5dc18_row10_col4, #T_5dc18_row10_col5, #T_5dc18_row10_col6, #T_5dc18_row10_col7, #T_5dc18_row10_col8, #T_5dc18_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_5dc18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dc18_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5dc18_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5dc18_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5dc18_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5dc18_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5dc18_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_5dc18_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_5dc18_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_5dc18_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_5dc18_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dc18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dc18_row0_col0" class="data row0 col0" >5.5447</td>
#       <td id="T_5dc18_row0_col1" class="data row0 col1" >93.4844</td>
#       <td id="T_5dc18_row0_col2" class="data row0 col2" >9.6687</td>
#       <td id="T_5dc18_row0_col3" class="data row0 col3" >0.1722</td>
#       <td id="T_5dc18_row0_col4" class="data row0 col4" >0.1872</td>
#       <td id="T_5dc18_row0_col5" class="data row0 col5" >0.1144</td>
#       <td id="T_5dc18_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_5dc18_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_5dc18_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_5dc18_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dc18_row1_col0" class="data row1 col0" >5.6162</td>
#       <td id="T_5dc18_row1_col1" class="data row1 col1" >58.6620</td>
#       <td id="T_5dc18_row1_col2" class="data row1 col2" >7.6591</td>
#       <td id="T_5dc18_row1_col3" class="data row1 col3" >0.6115</td>
#       <td id="T_5dc18_row1_col4" class="data row1 col4" >0.1978</td>
#       <td id="T_5dc18_row1_col5" class="data row1 col5" >0.1259</td>
#       <td id="T_5dc18_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_5dc18_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_5dc18_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_5dc18_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dc18_row2_col0" class="data row2 col0" >5.4628</td>
#       <td id="T_5dc18_row2_col1" class="data row2 col1" >66.2017</td>
#       <td id="T_5dc18_row2_col2" class="data row2 col2" >8.1364</td>
#       <td id="T_5dc18_row2_col3" class="data row2 col3" >0.0057</td>
#       <td id="T_5dc18_row2_col4" class="data row2 col4" >0.1245</td>
#       <td id="T_5dc18_row2_col5" class="data row2 col5" >0.0843</td>
#       <td id="T_5dc18_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_5dc18_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_5dc18_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_5dc18_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dc18_row3_col0" class="data row3 col0" >4.5973</td>
#       <td id="T_5dc18_row3_col1" class="data row3 col1" >39.4471</td>
#       <td id="T_5dc18_row3_col2" class="data row3 col2" >6.2807</td>
#       <td id="T_5dc18_row3_col3" class="data row3 col3" >-0.1394</td>
#       <td id="T_5dc18_row3_col4" class="data row3 col4" >0.0845</td>
#       <td id="T_5dc18_row3_col5" class="data row3 col5" >0.0621</td>
#       <td id="T_5dc18_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_5dc18_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_5dc18_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_5dc18_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5dc18_row4_col0" class="data row4 col0" >6.7587</td>
#       <td id="T_5dc18_row4_col1" class="data row4 col1" >120.6849</td>
#       <td id="T_5dc18_row4_col2" class="data row4 col2" >10.9857</td>
#       <td id="T_5dc18_row4_col3" class="data row4 col3" >0.5190</td>
#       <td id="T_5dc18_row4_col4" class="data row4 col4" >0.4997</td>
#       <td id="T_5dc18_row4_col5" class="data row4 col5" >0.0794</td>
#       <td id="T_5dc18_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_5dc18_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_5dc18_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_5dc18_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5dc18_row5_col0" class="data row5 col0" >6.0219</td>
#       <td id="T_5dc18_row5_col1" class="data row5 col1" >84.1986</td>
#       <td id="T_5dc18_row5_col2" class="data row5 col2" >9.1760</td>
#       <td id="T_5dc18_row5_col3" class="data row5 col3" >-0.1091</td>
#       <td id="T_5dc18_row5_col4" class="data row5 col4" >0.1162</td>
#       <td id="T_5dc18_row5_col5" class="data row5 col5" >0.0849</td>
#       <td id="T_5dc18_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_5dc18_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_5dc18_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_5dc18_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5dc18_row6_col0" class="data row6 col0" >4.2552</td>
#       <td id="T_5dc18_row6_col1" class="data row6 col1" >41.3133</td>
#       <td id="T_5dc18_row6_col2" class="data row6 col2" >6.4275</td>
#       <td id="T_5dc18_row6_col3" class="data row6 col3" >0.2859</td>
#       <td id="T_5dc18_row6_col4" class="data row6 col4" >0.0925</td>
#       <td id="T_5dc18_row6_col5" class="data row6 col5" >0.0622</td>
#       <td id="T_5dc18_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_5dc18_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_5dc18_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_5dc18_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5dc18_row7_col0" class="data row7 col0" >5.2808</td>
#       <td id="T_5dc18_row7_col1" class="data row7 col1" >92.4047</td>
#       <td id="T_5dc18_row7_col2" class="data row7 col2" >9.6127</td>
#       <td id="T_5dc18_row7_col3" class="data row7 col3" >0.3995</td>
#       <td id="T_5dc18_row7_col4" class="data row7 col4" >0.1424</td>
#       <td id="T_5dc18_row7_col5" class="data row7 col5" >0.0859</td>
#       <td id="T_5dc18_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_5dc18_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_5dc18_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_5dc18_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc18_level0_ro
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: lasso
# <style type="text/css">
# #T_187ec_row10_col0, #T_187ec_row10_col1, #T_187ec_row10_col2, #T_187ec_row10_col3, #T_187ec_row10_col4, #T_187ec_row10_col5, #T_187ec_row10_col6, #T_187ec_row10_col7, #T_187ec_row10_col8, #T_187ec_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_187ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_187ec_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_187ec_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_187ec_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_187ec_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_187ec_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_187ec_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_187ec_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_187ec_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_187ec_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_187ec_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_187ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_187ec_row0_col0" class="data row0 col0" >5.3231</td>
#       <td id="T_187ec_row0_col1" class="data row0 col1" >93.7225</td>
#       <td id="T_187ec_row0_col2" class="data row0 col2" >9.6810</td>
#       <td id="T_187ec_row0_col3" class="data row0 col3" >0.1701</td>
#       <td id="T_187ec_row0_col4" class="data row0 col4" >0.1882</td>
#       <td id="T_187ec_row0_col5" class="data row0 col5" >0.1116</td>
#       <td id="T_187ec_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_187ec_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_187ec_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_187ec_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_187ec_row1_col0" class="data row1 col0" >5.7080</td>
#       <td id="T_187ec_row1_col1" class="data row1 col1" >70.1083</td>
#       <td id="T_187ec_row1_col2" class="data row1 col2" >8.3731</td>
#       <td id="T_187ec_row1_col3" class="data row1 col3" >0.5357</td>
#       <td id="T_187ec_row1_col4" class="data row1 col4" >0.2503</td>
#       <td id="T_187ec_row1_col5" class="data row1 col5" >0.1633</td>
#       <td id="T_187ec_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_187ec_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_187ec_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_187ec_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_187ec_row2_col0" class="data row2 col0" >4.9980</td>
#       <td id="T_187ec_row2_col1" class="data row2 col1" >61.3548</td>
#       <td id="T_187ec_row2_col2" class="data row2 col2" >7.8329</td>
#       <td id="T_187ec_row2_col3" class="data row2 col3" >0.0785</td>
#       <td id="T_187ec_row2_col4" class="data row2 col4" >0.1222</td>
#       <td id="T_187ec_row2_col5" class="data row2 col5" >0.0780</td>
#       <td id="T_187ec_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_187ec_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_187ec_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_187ec_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_187ec_row3_col0" class="data row3 col0" >4.4434</td>
#       <td id="T_187ec_row3_col1" class="data row3 col1" >38.4994</td>
#       <td id="T_187ec_row3_col2" class="data row3 col2" >6.2048</td>
#       <td id="T_187ec_row3_col3" class="data row3 col3" >-0.1120</td>
#       <td id="T_187ec_row3_col4" class="data row3 col4" >0.0831</td>
#       <td id="T_187ec_row3_col5" class="data row3 col5" >0.0598</td>
#       <td id="T_187ec_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_187ec_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_187ec_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_187ec_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_187ec_row4_col0" class="data row4 col0" >7.0868</td>
#       <td id="T_187ec_row4_col1" class="data row4 col1" >143.7973</td>
#       <td id="T_187ec_row4_col2" class="data row4 col2" >11.9916</td>
#       <td id="T_187ec_row4_col3" class="data row4 col3" >0.4269</td>
#       <td id="T_187ec_row4_col4" class="data row4 col4" >0.5454</td>
#       <td id="T_187ec_row4_col5" class="data row4 col5" >0.0803</td>
#       <td id="T_187ec_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_187ec_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_187ec_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_187ec_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_187ec_row5_col0" class="data row5 col0" >5.6424</td>
#       <td id="T_187ec_row5_col1" class="data row5 col1" >71.9535</td>
#       <td id="T_187ec_row5_col2" class="data row5 col2" >8.4825</td>
#       <td id="T_187ec_row5_col3" class="data row5 col3" >0.0522</td>
#       <td id="T_187ec_row5_col4" class="data row5 col4" >0.1082</td>
#       <td id="T_187ec_row5_col5" class="data row5 col5" >0.0799</td>
#       <td id="T_187ec_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_187ec_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_187ec_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_187ec_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_187ec_row6_col0" class="data row6 col0" >4.3081</td>
#       <td id="T_187ec_row6_col1" class="data row6 col1" >40.4428</td>
#       <td id="T_187ec_row6_col2" class="data row6 col2" >6.3595</td>
#       <td id="T_187ec_row6_col3" class="data row6 col3" >0.3010</td>
#       <td id="T_187ec_row6_col4" class="data row6 col4" >0.0879</td>
#       <td id="T_187ec_row6_col5" class="data row6 col5" >0.0609</td>
#       <td id="T_187ec_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_187ec_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_187ec_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_187ec_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_187ec_row7_col0" class="data row7 col0" >5.2758</td>
#       <td id="T_187ec_row7_col1" class="data row7 col1" >100.7500</td>
#       <td id="T_187ec_row7_col2" class="data row7 col2" >10.0374</td>
#       <td id="T_187ec_row7_col3" class="data row7 col3" >0.3452</td>
#       <td id="T_187ec_row7_col4" class="data row7 col4" >0.1482</td>
#       <td id="T_187ec_row7_col5" class="data row7 col5" >0.0864</td>
#       <td id="T_187ec_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_187ec_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_187ec_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_187ec_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_187ec_level0_r
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %%
# pipeline_path = '../pipelines/tuned_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     tuned_models = {}

#     for name in model_names_to_load:
#         tuned_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(tuned_models)

# %%
# pipeline_path = '../pipelines/tuned_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in tuned_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %%
tuning_predictions_metric = {}

for model_name, model_object in tuned_models.items():
    predict_model(model_object, verbose=False)
    tuning_predictions_metric[model_name] = pull()

# %%
list_of_metric_dfs = []

file_name = 'temp_excel.xlsx'

# Iterate through the dictionary and append each DataFrame to the list
for model_name, metrics_df in holdout_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

# Concatenate all DataFrames into a single one
print("--- Holdout Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name) as writer:
    results_df.to_excel(writer, sheet_name='Base Model Metrics', index=False)

list_of_metric_dfs = []
for model_name, metrics_df in tuning_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

print("\n--- Tuned Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name, mode='a') as writer:
    results_df.to_excel(writer, sheet_name='Tuned Model Metrics', index=False)
# Out:
# --- Holdout Predictions DataFrame ---
#
#                          Model     MAE       MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0        Extra Trees Regressor  6.3524  168.4311  12.9781  0.1954  0.1513  0.0823  0.1955   12.9772   0.1999    12.9415
# 1      Random Forest Regressor  6.4262  171.7083  13.1038  0.1797  0.1498  0.0816  0.1796   13.1044   0.1864    13.0499
# 2           CatBoost Regressor  6.5761  176.5000  13.2853  0.1568  0.1550  0.0848  0.1517   13.3257   0.1630    13.2363
# 3  Orthogonal Matching Pursuit  6.4794  152.1385  12.3344  0.2732  0.1401  0.0834  0.2706   12.3565   0.2794    12.2821
# 4             Lasso Regression  6.3786  156.5715  12.5129  0.2520  0.1400  0.0816  0.2523   12.5103   0.2589    12.4556
#
# --- Tuned Predictions DataFrame ---
#
#                          Model     MAE       MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0        Extra Trees Regressor  6.1853  156.4877  12.5095  0.2524  0.1413  0.0777  0.2527   12.5077   0.2601    12.4449
# 1      Random Forest Regressor  6.2975  162.8003  12.7593  0.2223  0.1438  0.0790  0.2223   12.7590   0.2281    12.7115
# 2           CatBoost Regressor  6.5761  176.5000  13.2853  0.1568  0.1550  0.0848  0.1517   13.3257   0.1630    13.2363
# 3  Orthogonal Matching Pursuit  6.5159  152.8746  12.3642  0.2697  0.1405  0.0841  0.2708   12.3552   0.2753    12.3167
# 4             Lasso Regression  6.3770  159.6977  12.6372  0.2371  0.1428  0.0811  0.2325   12.6751   0.2450    12.5711
