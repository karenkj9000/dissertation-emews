# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from pycaret.regression import *

# %%
root = os.path.join('..', 'data', 'imputed')
folder = 'mice'
df = pd.read_csv(os.path.join(root, f'{folder}_df.csv'))

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df[['day', 'date', 'zone_a__patients', 'zone_a__cat_2', 'zone_a__cat_3',
       'zone_a__sets_of_emews', 'zone_a__deescalations', 'zone_a__escalations']]

# %%
df.columns
# Out:
# Index(['day', 'date', 'zone_a__patients', 'zone_a__cat_2', 'zone_a__cat_3',
#        'zone_a__sets_of_emews', 'zone_a__deescalations',
#        'zone_a__escalations'],
#       dtype='object')

# %% [markdown]
# ## Load Model (optional)

# %%
# pipeline_path = '../pipelines/base_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     created_models = {}

#     for name in model_names_to_load:
#         created_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(created_models)

# %% [markdown]
# ## Pycaret Setup

# %%
s = setup(df, target='zone_a__sets_of_emews', session_id=123, train_size=0.8)
# Out:
# <style type="text/css">
# #T_f945b_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f945b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f945b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f945b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f945b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f945b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f945b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f945b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f945b_row1_col1" class="data row1 col1" >zone_a__sets_of_emews</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f945b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f945b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f945b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f945b_row3_col1" class="data row3 col1" >(599, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f945b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f945b_row4_col1" class="data row4 col1" >(599, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f945b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f945b_row5_col1" class="data row5 col1" >(479, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f945b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f945b_row6_col1" class="data row6 col1" >(120, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f945b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f945b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f945b_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_f945b_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f945b_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f945b_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f945b_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f945b_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f945b_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f945b_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f945b_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f945b_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f945b_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f945b_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f945b_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f945b_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f945b_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f945b_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f945b_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_f945b_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f945b_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_f945b_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f945b_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_f945b_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f945b_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_f945b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f945b_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_f945b_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f945b_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_f945b_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f945b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f945b_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_f945b_row22_col1" class="data row22 col1" >7495</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(exclude=['lightgbm'], errors='raise')
# Out:
# <style type="text/css">
# #T_cf2ce th {
#   text-align: left;
# }
# #T_cf2ce_row0_col0, #T_cf2ce_row0_col1, #T_cf2ce_row0_col5, #T_cf2ce_row0_col6, #T_cf2ce_row1_col0, #T_cf2ce_row1_col1, #T_cf2ce_row1_col2, #T_cf2ce_row1_col3, #T_cf2ce_row1_col4, #T_cf2ce_row1_col5, #T_cf2ce_row1_col6, #T_cf2ce_row2_col0, #T_cf2ce_row2_col1, #T_cf2ce_row2_col2, #T_cf2ce_row2_col3, #T_cf2ce_row2_col4, #T_cf2ce_row2_col5, #T_cf2ce_row2_col6, #T_cf2ce_row3_col0, #T_cf2ce_row3_col1, #T_cf2ce_row3_col2, #T_cf2ce_row3_col3, #T_cf2ce_row3_col4, #T_cf2ce_row3_col5, #T_cf2ce_row3_col6, #T_cf2ce_row4_col0, #T_cf2ce_row4_col1, #T_cf2ce_row4_col2, #T_cf2ce_row4_col3, #T_cf2ce_row4_col4, #T_cf2ce_row4_col5, #T_cf2ce_row4_col6, #T_cf2ce_row5_col0, #T_cf2ce_row5_col1, #T_cf2ce_row5_col2, #T_cf2ce_row5_col3, #T_cf2ce_row5_col4, #T_cf2ce_row5_col5, #T_cf2ce_row5_col6, #T_cf2ce_row6_col0, #T_cf2ce_row6_col1, #T_cf2ce_row6_col2, #T_cf2ce_row6_col3, #T_cf2ce_row6_col4, #T_cf2ce_row6_col5, #T_cf2ce_row6_col6, #T_cf2ce_row7_col0, #T_cf2ce_row7_col1, #T_cf2ce_row7_col2, #T_cf2ce_row7_col3, #T_cf2ce_row7_col4, #T_cf2ce_row7_col5, #T_cf2ce_row7_col6, #T_cf2ce_row8_col0, #T_cf2ce_row8_col1, #T_cf2ce_row8_col2, #T_cf2ce_row8_col3, #T_cf2ce_row8_col4, #T_cf2ce_row8_col5, #T_cf2ce_row8_col6, #T_cf2ce_row9_col0, #T_cf2ce_row9_col1, #T_cf2ce_row9_col2, #T_cf2ce_row9_col3, #T_cf2ce_row9_col4, #T_cf2ce_row9_col5, #T_cf2ce_row9_col6, #T_cf2ce_row10_col0, #T_cf2ce_row10_col1, #T_cf2ce_row10_col2, #T_cf2ce_row10_col3, #T_cf2ce_row10_col4, #T_cf2ce_row10_col5, #T_cf2ce_row10_col6, #T_cf2ce_row11_col0, #T_cf2ce_row11_col2, #T_cf2ce_row11_col3, #T_cf2ce_row11_col4, #T_cf2ce_row11_col5, #T_cf2ce_row12_col0, #T_cf2ce_row12_col1, #T_cf2ce_row12_col2, #T_cf2ce_row12_col3, #T_cf2ce_row12_col4, #T_cf2ce_row12_col6, #T_cf2ce_row13_col0, #T_cf2ce_row13_col1, #T_cf2ce_row13_col2, #T_cf2ce_row13_col3, #T_cf2ce_row13_col4, #T_cf2ce_row13_col5, #T_cf2ce_row13_col6, #T_cf2ce_row14_col0, #T_cf2ce_row14_col1, #T_cf2ce_row14_col2, #T_cf2ce_row14_col3, #T_cf2ce_row14_col4, #T_cf2ce_row14_col5, #T_cf2ce_row14_col6, #T_cf2ce_row15_col0, #T_cf2ce_row15_col1, #T_cf2ce_row15_col2, #T_cf2ce_row15_col3, #T_cf2ce_row15_col4, #T_cf2ce_row15_col5, #T_cf2ce_row15_col6, #T_cf2ce_row16_col0, #T_cf2ce_row16_col1, #T_cf2ce_row16_col2, #T_cf2ce_row16_col3, #T_cf2ce_row16_col4, #T_cf2ce_row16_col5, #T_cf2ce_row16_col6, #T_cf2ce_row17_col0, #T_cf2ce_row17_col1, #T_cf2ce_row17_col2, #T_cf2ce_row17_col3, #T_cf2ce_row17_col4, #T_cf2ce_row17_col5, #T_cf2ce_row17_col6, #T_cf2ce_row18_col0, #T_cf2ce_row18_col1, #T_cf2ce_row18_col2, #T_cf2ce_row18_col3, #T_cf2ce_row18_col4, #T_cf2ce_row18_col5, #T_cf2ce_row18_col6 {
#   text-align: left;
# }
# #T_cf2ce_row0_col2, #T_cf2ce_row0_col3, #T_cf2ce_row0_col4, #T_cf2ce_row11_col1, #T_cf2ce_row11_col6, #T_cf2ce_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cf2ce_row0_col7, #T_cf2ce_row1_col7, #T_cf2ce_row2_col7, #T_cf2ce_row3_col7, #T_cf2ce_row5_col7, #T_cf2ce_row6_col7, #T_cf2ce_row7_col7, #T_cf2ce_row8_col7, #T_cf2ce_row9_col7, #T_cf2ce_row10_col7, #T_cf2ce_row11_col7, #T_cf2ce_row12_col7, #T_cf2ce_row13_col7, #T_cf2ce_row14_col7, #T_cf2ce_row15_col7, #T_cf2ce_row16_col7, #T_cf2ce_row17_col7, #T_cf2ce_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cf2ce_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cf2ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf2ce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cf2ce_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cf2ce_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cf2ce_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cf2ce_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cf2ce_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cf2ce_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cf2ce_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf2ce_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_cf2ce_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_cf2ce_row0_col1" class="data row0 col1" >20.6837</td>
#       <td id="T_cf2ce_row0_col2" class="data row0 col2" >730.6975</td>
#       <td id="T_cf2ce_row0_col3" class="data row0 col3" >26.8333</td>
#       <td id="T_cf2ce_row0_col4" class="data row0 col4" >0.4216</td>
#       <td id="T_cf2ce_row0_col5" class="data row0 col5" >0.3236</td>
#       <td id="T_cf2ce_row0_col6" class="data row0 col6" >0.2756</td>
#       <td id="T_cf2ce_row0_col7" class="data row0 col7" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_cf2ce_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_cf2ce_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_cf2ce_row1_col1" class="data row1 col1" >20.5237</td>
#       <td id="T_cf2ce_row1_col2" class="data row1 col2" >735.5680</td>
#       <td id="T_cf2ce_row1_col3" class="data row1 col3" >26.9409</td>
#       <td id="T_cf2ce_row1_col4" class="data row1 col4" >0.4205</td>
#       <td id="T_cf2ce_row1_col5" class="data row1 col5" >0.5026</td>
#       <td id="T_cf2ce_row1_col6" class="data row1 col6" >0.2701</td>
#       <td id="T_cf2ce_row1_col7" class="data row1 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_cf2ce_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_cf2ce_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_cf2ce_row2_col1" class="data row2 col1" >20.5224</td>
#       <td id="T_cf2ce_row2_col2" class="data row2 col2" >735.5303</td>
#       <td id="T_cf2ce_row2_col3" class="data row2 col3" >26.9400</td>
#       <td id="T_cf2ce_row2_col4" class="data row2 col4" >0.4205</td>
#       <td id="T_cf2ce_row2_col5" class="data row2 col5" >0.5025</td>
#       <td id="T_cf2ce_row2_col6" class="data row2 col6" >0.2701</td>
#       <td id="T_cf2ce_row2_col7" class="data row2 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_cf2ce_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_cf2ce_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_cf2ce_row3_col1" class="data row3 col1" >20.5623</td>
#       <td id="T_cf2ce_row3_col2" class="data row3 col2" >737.7339</td>
#       <td id="T_cf2ce_row3_col3" class="data row3 col3" >26.9926</td>
#       <td id="T_cf2ce_row3_col4" class="data row3 col4" >0.4183</td>
#       <td id="T_cf2ce_row3_col5" class="data row3 col5" >0.5035</td>
#       <td id="T_cf2ce_row3_col6" class="data row3 col6" >0.2713</td>
#       <td id="T_cf2ce_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_cf2ce_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_cf2ce_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_cf2ce_row4_col1" class="data row4 col1" >20.5725</td>
#       <td id="T_cf2ce_row4_col2" class="data row4 col2" >738.5953</td>
#       <td id="T_cf2ce_row4_col3" class="data row4 col3" >27.0156</td>
#       <td id="T_cf2ce_row4_col4" class="data row4 col4" >0.4172</td>
#       <td id="T_cf2ce_row4_col5" class="data row4 col5" >0.5035</td>
#       <td id="T_cf2ce_row4_col6" class="data row4 col6" >0.2716</td>
#       <td id="T_cf2ce_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_cf2ce_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_cf2ce_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_cf2ce_row5_col1" class="data row5 col1" >20.6013</td>
#       <td id="T_cf2ce_row5_col2" class="data row5 col2" >736.7935</td>
#       <td id="T_cf2ce_row5_col3" class="data row5 col3" >26.9161</td>
#       <td id="T_cf2ce_row5_col4" class="data row5 col4" >0.4147</td>
#       <td id="T_cf2ce_row5_col5" class="data row5 col5" >0.3802</td>
#       <td id="T_cf2ce
# RandomForestRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## Custom Metrics

# %%
from sklearn.metrics import r2_score, mean_squared_error

def r2_rounded(y_true, y_pred):
    """Calculates R2 score after rounding predictions to the nearest whole number."""
    return r2_score(y_true, np.round(y_pred))

def rmse_rounded(y_true, y_pred):
    """Calculates RMSE after rounding predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.round(y_pred)))

def r2_ceil(y_true, y_pred):
    """Calculates R2 score after ceiling predictions to the nearest whole number."""
    return r2_score(y_true, np.ceil(y_pred))

def rmse_ceil(y_true, y_pred):
    """Calculates RMSE after ceiling predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.ceil(y_pred)))

# %%
add_metric('R2_Rounded', 'R2_RND', r2_rounded, greater_is_better=True)
add_metric('RMSE_Rounded', 'RMSE_RND', rmse_rounded, greater_is_better=False)
add_metric('R2_Ceil', 'R2_CEIL', r2_ceil, greater_is_better=True)
add_metric('RMSE_Ceil', 'RMSE_CEIL', rmse_ceil, greater_is_better=False);

# %% [markdown]
# ## Analyze Model

# %%
model_names_to_create = ['llar', 'rf', 'lasso', 'et', 'huber']
created_models = {}

for model_name in model_names_to_create:
    model_object = create_model(model_name, verbose=False)
    created_models[model_name] = model_object

# %% [markdown]
# ### Bayesian Ridge

# %%
# evaluate_model(created_models['br'])

# %% [markdown]
# ### Lasso Regression

# %%
# evaluate_model(created_models['lasso'])

# %% [markdown]
# ### Lasso Least Angle Regression

# %%
# evaluate_model(created_models['llar'])

# %% [markdown]
# ### Elastic Net

# %%
# evaluate_model(created_models['en'])

# %% [markdown]
# ### Huber Regressor

# %%
# evaluate_model(created_models['huber'])

# %% [markdown]
# ## Prediction

# %%
holdout_predictions_metric = {}

for model_name, model_object in created_models.items():
    predict_model(model_object, verbose=False)
    holdout_predictions_metric[model_name] = pull()

# %%
# pipeline_path = '../pipelines/base_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in created_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %% [markdown]
# ## Tuning

# %%
# param_grids = {
#     'br': {
#         'max_iter': np.arange(50, 301, 50),
#         'alpha_1': np.logspace(-8, -3, 6),
#         'lambda_1': np.logspace(-8, -3, 6),
#         'alpha_2': np.logspace(-8, -3, 6),
#         'lambda_2': np.logspace(-8, -3, 6)
#     },
#     'lasso': {
#         'alpha': np.logspace(-4, 1, 6),
#         'selection': ['cyclic', 'random']
#     },
#     'llar': {
#         'alpha': np.logspace(-4, 1, 6),
#         'jitter': list(np.logspace(-7, -4, 4)) + [None]
#     },
#     'en': {
#         'alpha': np.logspace(-4, 1, 6),
#         'l1_ratio': np.linspace(0, 1, 9),
#         'max_iter': np.arange(100, 1001, 100),
#         'selection': ['cyclic', 'random']
#     },
#     'huber': {
#         'epsilon': [1.0, 1.1, 1.2, 1.25, 1.3, 1.35, 1.4, 1.5, 2.0],
#         'max_iter': np.arange(10, 101, 10),
#         'alpha': np.logspace(-6, -2, 5)
#     }
# }

# %%
tuned_models = {}

for model_name, model_object in created_models.items():
    print(f"Tuning model: {model_name}")
    tuned_models[model_name] = tune_model(
        model_object,
        search_library='scikit-optimize',
        n_iter=20,
        early_stopping=True
    )
    print("\r")
# Out:
# Tuning model: llar
# <style type="text/css">
# #T_72042_row10_col0, #T_72042_row10_col1, #T_72042_row10_col2, #T_72042_row10_col3, #T_72042_row10_col4, #T_72042_row10_col5, #T_72042_row10_col6, #T_72042_row10_col7, #T_72042_row10_col8, #T_72042_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_72042">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72042_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72042_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72042_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72042_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72042_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_72042_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_72042_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_72042_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_72042_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_72042_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72042_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72042_row0_col0" class="data row0 col0" >22.6373</td>
#       <td id="T_72042_row0_col1" class="data row0 col1" >982.7263</td>
#       <td id="T_72042_row0_col2" class="data row0 col2" >31.3485</td>
#       <td id="T_72042_row0_col3" class="data row0 col3" >0.3060</td>
#       <td id="T_72042_row0_col4" class="data row0 col4" >0.3661</td>
#       <td id="T_72042_row0_col5" class="data row0 col5" >0.3340</td>
#       <td id="T_72042_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_72042_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_72042_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_72042_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72042_row1_col0" class="data row1 col0" >16.5750</td>
#       <td id="T_72042_row1_col1" class="data row1 col1" >432.2318</td>
#       <td id="T_72042_row1_col2" class="data row1 col2" >20.7902</td>
#       <td id="T_72042_row1_col3" class="data row1 col3" >0.6171</td>
#       <td id="T_72042_row1_col4" class="data row1 col4" >0.6639</td>
#       <td id="T_72042_row1_col5" class="data row1 col5" >0.2108</td>
#       <td id="T_72042_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_72042_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_72042_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_72042_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72042_row2_col0" class="data row2 col0" >23.1639</td>
#       <td id="T_72042_row2_col1" class="data row2 col1" >756.1326</td>
#       <td id="T_72042_row2_col2" class="data row2 col2" >27.4979</td>
#       <td id="T_72042_row2_col3" class="data row2 col3" >0.5067</td>
#       <td id="T_72042_row2_col4" class="data row2 col4" >0.7310</td>
#       <td id="T_72042_row2_col5" class="data row2 col5" >0.3873</td>
#       <td id="T_72042_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_72042_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_72042_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_72042_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72042_row3_col0" class="data row3 col0" >19.2740</td>
#       <td id="T_72042_row3_col1" class="data row3 col1" >687.5247</td>
#       <td id="T_72042_row3_col2" class="data row3 col2" >26.2207</td>
#       <td id="T_72042_row3_col3" class="data row3 col3" >0.4830</td>
#       <td id="T_72042_row3_col4" class="data row3 col4" >0.5352</td>
#       <td id="T_72042_row3_col5" class="data row3 col5" >0.2562</td>
#       <td id="T_72042_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_72042_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_72042_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_72042_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72042_row4_col0" class="data row4 col0" >22.9949</td>
#       <td id="T_72042_row4_col1" class="data row4 col1" >907.6263</td>
#       <td id="T_72042_row4_col2" class="data row4 col2" >30.1268</td>
#       <td id="T_72042_row4_col3" class="data row4 col3" >0.4600</td>
#       <td id="T_72042_row4_col4" class="data row4 col4" >0.6804</td>
#       <td id="T_72042_row4_col5" class="data row4 col5" >0.2568</td>
#       <td id="T_72042_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_72042_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_72042_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_72042_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72042_row5_col0" class="data row5 col0" >18.5077</td>
#       <td id="T_72042_row5_col1" class="data row5 col1" >564.6795</td>
#       <td id="T_72042_row5_col2" class="data row5 col2" >23.7630</td>
#       <td id="T_72042_row5_col3" class="data row5 col3" >0.4920</td>
#       <td id="T_72042_row5_col4" class="data row5 col4" >0.6478</td>
#       <td id="T_72042_row5_col5" class="data row5 col5" >0.2035</td>
#       <td id="T_72042_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_72042_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_72042_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_72042_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72042_row6_col0" class="data row6 col0" >21.8425</td>
#       <td id="T_72042_row6_col1" class="data row6 col1" >850.6053</td>
#       <td id="T_72042_row6_col2" class="data row6 col2" >29.1651</td>
#       <td id="T_72042_row6_col3" class="data row6 col3" >0.1216</td>
#       <td id="T_72042_row6_col4" class="data row6 col4" >0.3319</td>
#       <td id="T_72042_row6_col5" class="data row6 col5" >0.2993</td>
#       <td id="T_72042_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_72042_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_72042_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_72042_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_72042_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72042_row7_col0" class="data row7 col0" >18.3867</td>
#       <td id="T_72042_row7_col1" class="data row7 col1" >564.9171</td>
#       <td id="T_72042_row7_col2" class="data row7 col2" >23.7680</td>
#       <td id="T_72042_row7_col3" class="data row7 col3" >0.4072</td>
#       <td id="T_72042_row7_col4" class="data row7 col4" >0.2731</td>
#       <td id="T_72042_row7_col5" class="data row7 col5" >0.2341</td>
#       <td id="T_72042_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_72042_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_72042_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_72042_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th i
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# Tuning model: rf
# <style type="text/css">
# #T_2c3f0_row10_col0, #T_2c3f0_row10_col1, #T_2c3f0_row10_col2, #T_2c3f0_row10_col3, #T_2c3f0_row10_col4, #T_2c3f0_row10_col5, #T_2c3f0_row10_col6, #T_2c3f0_row10_col7, #T_2c3f0_row10_col8, #T_2c3f0_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_2c3f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c3f0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2c3f0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2c3f0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2c3f0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2c3f0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2c3f0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_2c3f0_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_2c3f0_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_2c3f0_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_2c3f0_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c3f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c3f0_row0_col0" class="data row0 col0" >23.0749</td>
#       <td id="T_2c3f0_row0_col1" class="data row0 col1" >946.5049</td>
#       <td id="T_2c3f0_row0_col2" class="data row0 col2" >30.7653</td>
#       <td id="T_2c3f0_row0_col3" class="data row0 col3" >0.3316</td>
#       <td id="T_2c3f0_row0_col4" class="data row0 col4" >0.3552</td>
#       <td id="T_2c3f0_row0_col5" class="data row0 col5" >0.3270</td>
#       <td id="T_2c3f0_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_2c3f0_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_2c3f0_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_2c3f0_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c3f0_row1_col0" class="data row1 col0" >16.4808</td>
#       <td id="T_2c3f0_row1_col1" class="data row1 col1" >418.8575</td>
#       <td id="T_2c3f0_row1_col2" class="data row1 col2" >20.4660</td>
#       <td id="T_2c3f0_row1_col3" class="data row1 col3" >0.6289</td>
#       <td id="T_2c3f0_row1_col4" class="data row1 col4" >0.5718</td>
#       <td id="T_2c3f0_row1_col5" class="data row1 col5" >0.2207</td>
#       <td id="T_2c3f0_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_2c3f0_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_2c3f0_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_2c3f0_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c3f0_row2_col0" class="data row2 col0" >21.1909</td>
#       <td id="T_2c3f0_row2_col1" class="data row2 col1" >691.3984</td>
#       <td id="T_2c3f0_row2_col2" class="data row2 col2" >26.2945</td>
#       <td id="T_2c3f0_row2_col3" class="data row2 col3" >0.5490</td>
#       <td id="T_2c3f0_row2_col4" class="data row2 col4" >0.6400</td>
#       <td id="T_2c3f0_row2_col5" class="data row2 col5" >0.3408</td>
#       <td id="T_2c3f0_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_2c3f0_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_2c3f0_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_2c3f0_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c3f0_row3_col0" class="data row3 col0" >19.1153</td>
#       <td id="T_2c3f0_row3_col1" class="data row3 col1" >661.7768</td>
#       <td id="T_2c3f0_row3_col2" class="data row3 col2" >25.7250</td>
#       <td id="T_2c3f0_row3_col3" class="data row3 col3" >0.5024</td>
#       <td id="T_2c3f0_row3_col4" class="data row3 col4" >0.4494</td>
#       <td id="T_2c3f0_row3_col5" class="data row3 col5" >0.2421</td>
#       <td id="T_2c3f0_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_2c3f0_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_2c3f0_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_2c3f0_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c3f0_row4_col0" class="data row4 col0" >21.5819</td>
#       <td id="T_2c3f0_row4_col1" class="data row4 col1" >891.3626</td>
#       <td id="T_2c3f0_row4_col2" class="data row4 col2" >29.8557</td>
#       <td id="T_2c3f0_row4_col3" class="data row4 col3" >0.4697</td>
#       <td id="T_2c3f0_row4_col4" class="data row4 col4" >0.5739</td>
#       <td id="T_2c3f0_row4_col5" class="data row4 col5" >0.2454</td>
#       <td id="T_2c3f0_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_2c3f0_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_2c3f0_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_2c3f0_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c3f0_row5_col0" class="data row5 col0" >17.6184</td>
#       <td id="T_2c3f0_row5_col1" class="data row5 col1" >513.1748</td>
#       <td id="T_2c3f0_row5_col2" class="data row5 col2" >22.6534</td>
#       <td id="T_2c3f0_row5_col3" class="data row5 col3" >0.5383</td>
#       <td id="T_2c3f0_row5_col4" class="data row5 col4" >0.5334</td>
#       <td id="T_2c3f0_row5_col5" class="data row5 col5" >0.1983</td>
#       <td id="T_2c3f0_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_2c3f0_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_2c3f0_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_2c3f0_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c3f0_row6_col0" class="data row6 col0" >23.7330</td>
#       <td id="T_2c3f0_row6_col1" class="data row6 col1" >855.2906</td>
#       <td id="T_2c3f0_row6_col2" class="data row6 col2" >29.2454</td>
#       <td id="T_2c3f0_row6_col3" class="data row6 col3" >0.1168</td>
#       <td id="T_2c3f0_row6_col4" class="data row6 col4" >0.3458</td>
#       <td id="T_2c3f0_row6_col5" class="data row6 col5" >0.3282</td>
#       <td id="T_2c3f0_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_2c3f0_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_2c3f0_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_2c3f0_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c3f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c3f0_row7_col0" class="data row7 col0" >17.1450</td>
#       <td id="T_2c3f0_row7_col1" class="data row7 col1" >516.3605</td>
#       <td id="T_2c3f0_row7_col2" class="data row7 col2" >22.7236</td>
#       <td id="T_2c3f0_row7_col3" class="data row7 col3" >0.4582</td>
#       <td id="T_2c3f0_row7_col4" class="data row7 col4" >0.2670</td>
#       <td id="T_2c3f0_row7_col5" class="data row7 col5" >0.2213</td>
#       <td id="T_2c3f0_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_2c3f0_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_2c3f0_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_2c3f0_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th i
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: lasso
# <style type="text/css">
# #T_a9029_row10_col0, #T_a9029_row10_col1, #T_a9029_row10_col2, #T_a9029_row10_col3, #T_a9029_row10_col4, #T_a9029_row10_col5, #T_a9029_row10_col6, #T_a9029_row10_col7, #T_a9029_row10_col8, #T_a9029_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_a9029">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9029_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a9029_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a9029_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a9029_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a9029_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a9029_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_a9029_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_a9029_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_a9029_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_a9029_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9029_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9029_row0_col0" class="data row0 col0" >22.6182</td>
#       <td id="T_a9029_row0_col1" class="data row0 col1" >977.1983</td>
#       <td id="T_a9029_row0_col2" class="data row0 col2" >31.2602</td>
#       <td id="T_a9029_row0_col3" class="data row0 col3" >0.3099</td>
#       <td id="T_a9029_row0_col4" class="data row0 col4" >0.3661</td>
#       <td id="T_a9029_row0_col5" class="data row0 col5" >0.3342</td>
#       <td id="T_a9029_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_a9029_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_a9029_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_a9029_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9029_row1_col0" class="data row1 col0" >16.5724</td>
#       <td id="T_a9029_row1_col1" class="data row1 col1" >431.5336</td>
#       <td id="T_a9029_row1_col2" class="data row1 col2" >20.7734</td>
#       <td id="T_a9029_row1_col3" class="data row1 col3" >0.6177</td>
#       <td id="T_a9029_row1_col4" class="data row1 col4" >0.6658</td>
#       <td id="T_a9029_row1_col5" class="data row1 col5" >0.2101</td>
#       <td id="T_a9029_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_a9029_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_a9029_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_a9029_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9029_row2_col0" class="data row2 col0" >23.1865</td>
#       <td id="T_a9029_row2_col1" class="data row2 col1" >757.2323</td>
#       <td id="T_a9029_row2_col2" class="data row2 col2" >27.5179</td>
#       <td id="T_a9029_row2_col3" class="data row2 col3" >0.5060</td>
#       <td id="T_a9029_row2_col4" class="data row2 col4" >0.7327</td>
#       <td id="T_a9029_row2_col5" class="data row2 col5" >0.3882</td>
#       <td id="T_a9029_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_a9029_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_a9029_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_a9029_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9029_row3_col0" class="data row3 col0" >19.2616</td>
#       <td id="T_a9029_row3_col1" class="data row3 col1" >686.3019</td>
#       <td id="T_a9029_row3_col2" class="data row3 col2" >26.1974</td>
#       <td id="T_a9029_row3_col3" class="data row3 col3" >0.4839</td>
#       <td id="T_a9029_row3_col4" class="data row3 col4" >0.5369</td>
#       <td id="T_a9029_row3_col5" class="data row3 col5" >0.2564</td>
#       <td id="T_a9029_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_a9029_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_a9029_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_a9029_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9029_row4_col0" class="data row4 col0" >23.0080</td>
#       <td id="T_a9029_row4_col1" class="data row4 col1" >909.5833</td>
#       <td id="T_a9029_row4_col2" class="data row4 col2" >30.1593</td>
#       <td id="T_a9029_row4_col3" class="data row4 col3" >0.4588</td>
#       <td id="T_a9029_row4_col4" class="data row4 col4" >0.6829</td>
#       <td id="T_a9029_row4_col5" class="data row4 col5" >0.2568</td>
#       <td id="T_a9029_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_a9029_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_a9029_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_a9029_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9029_row5_col0" class="data row5 col0" >18.5077</td>
#       <td id="T_a9029_row5_col1" class="data row5 col1" >564.2939</td>
#       <td id="T_a9029_row5_col2" class="data row5 col2" >23.7549</td>
#       <td id="T_a9029_row5_col3" class="data row5 col3" >0.4923</td>
#       <td id="T_a9029_row5_col4" class="data row5 col4" >0.6506</td>
#       <td id="T_a9029_row5_col5" class="data row5 col5" >0.2036</td>
#       <td id="T_a9029_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_a9029_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_a9029_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_a9029_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9029_row6_col0" class="data row6 col0" >21.8321</td>
#       <td id="T_a9029_row6_col1" class="data row6 col1" >849.3585</td>
#       <td id="T_a9029_row6_col2" class="data row6 col2" >29.1438</td>
#       <td id="T_a9029_row6_col3" class="data row6 col3" >0.1229</td>
#       <td id="T_a9029_row6_col4" class="data row6 col4" >0.3318</td>
#       <td id="T_a9029_row6_col5" class="data row6 col5" >0.2992</td>
#       <td id="T_a9029_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_a9029_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_a9029_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_a9029_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a9029_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9029_row7_col0" class="data row7 col0" >18.3782</td>
#       <td id="T_a9029_row7_col1" class="data row7 col1" >566.0050</td>
#       <td id="T_a9029_row7_col2" class="data row7 col2" >23.7909</td>
#       <td id="T_a9029_row7_col3" class="data row7 col3" >0.4061</td>
#       <td id="T_a9029_row7_col4" class="data row7 col4" >0.2736</td>
#       <td id="T_a9029_row7_col5" class="data row7 col5" >0.2341</td>
#       <td id="T_a9029_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_a9029_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_a9029_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_a9029_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th i
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: et
# <style type="text/css">
# #T_a5081_row10_col0, #T_a5081_row10_col1, #T_a5081_row10_col2, #T_a5081_row10_col3, #T_a5081_row10_col4, #T_a5081_row10_col5, #T_a5081_row10_col6, #T_a5081_row10_col7, #T_a5081_row10_col8, #T_a5081_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_a5081">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5081_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a5081_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a5081_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a5081_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a5081_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a5081_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_a5081_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_a5081_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_a5081_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_a5081_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5081_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5081_row0_col0" class="data row0 col0" >22.9586</td>
#       <td id="T_a5081_row0_col1" class="data row0 col1" >944.9678</td>
#       <td id="T_a5081_row0_col2" class="data row0 col2" >30.7403</td>
#       <td id="T_a5081_row0_col3" class="data row0 col3" >0.3327</td>
#       <td id="T_a5081_row0_col4" class="data row0 col4" >0.3589</td>
#       <td id="T_a5081_row0_col5" class="data row0 col5" >0.3298</td>
#       <td id="T_a5081_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_a5081_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_a5081_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_a5081_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5081_row1_col0" class="data row1 col0" >16.4817</td>
#       <td id="T_a5081_row1_col1" class="data row1 col1" >438.3726</td>
#       <td id="T_a5081_row1_col2" class="data row1 col2" >20.9373</td>
#       <td id="T_a5081_row1_col3" class="data row1 col3" >0.6117</td>
#       <td id="T_a5081_row1_col4" class="data row1 col4" >0.5401</td>
#       <td id="T_a5081_row1_col5" class="data row1 col5" >0.2171</td>
#       <td id="T_a5081_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_a5081_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_a5081_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_a5081_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5081_row2_col0" class="data row2 col0" >21.7132</td>
#       <td id="T_a5081_row2_col1" class="data row2 col1" >714.4002</td>
#       <td id="T_a5081_row2_col2" class="data row2 col2" >26.7283</td>
#       <td id="T_a5081_row2_col3" class="data row2 col3" >0.5340</td>
#       <td id="T_a5081_row2_col4" class="data row2 col4" >0.6318</td>
#       <td id="T_a5081_row2_col5" class="data row2 col5" >0.3592</td>
#       <td id="T_a5081_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_a5081_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_a5081_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_a5081_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5081_row3_col0" class="data row3 col0" >19.3014</td>
#       <td id="T_a5081_row3_col1" class="data row3 col1" >687.3483</td>
#       <td id="T_a5081_row3_col2" class="data row3 col2" >26.2173</td>
#       <td id="T_a5081_row3_col3" class="data row3 col3" >0.4831</td>
#       <td id="T_a5081_row3_col4" class="data row3 col4" >0.4416</td>
#       <td id="T_a5081_row3_col5" class="data row3 col5" >0.2515</td>
#       <td id="T_a5081_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_a5081_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_a5081_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_a5081_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5081_row4_col0" class="data row4 col0" >21.3252</td>
#       <td id="T_a5081_row4_col1" class="data row4 col1" >906.3525</td>
#       <td id="T_a5081_row4_col2" class="data row4 col2" >30.1057</td>
#       <td id="T_a5081_row4_col3" class="data row4 col3" >0.4607</td>
#       <td id="T_a5081_row4_col4" class="data row4 col4" >0.5583</td>
#       <td id="T_a5081_row4_col5" class="data row4 col5" >0.2417</td>
#       <td id="T_a5081_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_a5081_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_a5081_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_a5081_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5081_row5_col0" class="data row5 col0" >17.4067</td>
#       <td id="T_a5081_row5_col1" class="data row5 col1" >493.1279</td>
#       <td id="T_a5081_row5_col2" class="data row5 col2" >22.2065</td>
#       <td id="T_a5081_row5_col3" class="data row5 col3" >0.5564</td>
#       <td id="T_a5081_row5_col4" class="data row5 col4" >0.5289</td>
#       <td id="T_a5081_row5_col5" class="data row5 col5" >0.1956</td>
#       <td id="T_a5081_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_a5081_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_a5081_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_a5081_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5081_row6_col0" class="data row6 col0" >22.8611</td>
#       <td id="T_a5081_row6_col1" class="data row6 col1" >768.4026</td>
#       <td id="T_a5081_row6_col2" class="data row6 col2" >27.7201</td>
#       <td id="T_a5081_row6_col3" class="data row6 col3" >0.2065</td>
#       <td id="T_a5081_row6_col4" class="data row6 col4" >0.3282</td>
#       <td id="T_a5081_row6_col5" class="data row6 col5" >0.3143</td>
#       <td id="T_a5081_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_a5081_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_a5081_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_a5081_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5081_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5081_row7_col0" class="data row7 col0" >16.5116</td>
#       <td id="T_a5081_row7_col1" class="data row7 col1" >487.1383</td>
#       <td id="T_a5081_row7_col2" class="data row7 col2" >22.0712</td>
#       <td id="T_a5081_row7_col3" class="data row7 col3" >0.4888</td>
#       <td id="T_a5081_row7_col4" class="data row7 col4" >0.2632</td>
#       <td id="T_a5081_row7_col5" class="data row7 col5" >0.2174</td>
#       <td id="T_a5081_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_a5081_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_a5081_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_a5081_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th i
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
#
# Tuning model: huber
# <style type="text/css">
# #T_bdde8_row10_col0, #T_bdde8_row10_col1, #T_bdde8_row10_col2, #T_bdde8_row10_col3, #T_bdde8_row10_col4, #T_bdde8_row10_col5, #T_bdde8_row10_col6, #T_bdde8_row10_col7, #T_bdde8_row10_col8, #T_bdde8_row10_col9 {
#   background: yellow;
# }
# </style>
# <table id="T_bdde8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdde8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bdde8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bdde8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bdde8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bdde8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bdde8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_bdde8_level0_col6" class="col_heading level0 col6" >R2_RND</th>
#       <th id="T_bdde8_level0_col7" class="col_heading level0 col7" >RMSE_RND</th>
#       <th id="T_bdde8_level0_col8" class="col_heading level0 col8" >R2_CEIL</th>
#       <th id="T_bdde8_level0_col9" class="col_heading level0 col9" >RMSE_CEIL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdde8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdde8_row0_col0" class="data row0 col0" >22.5619</td>
#       <td id="T_bdde8_row0_col1" class="data row0 col1" >1043.0638</td>
#       <td id="T_bdde8_row0_col2" class="data row0 col2" >32.2965</td>
#       <td id="T_bdde8_row0_col3" class="data row0 col3" >0.2634</td>
#       <td id="T_bdde8_row0_col4" class="data row0 col4" >0.3487</td>
#       <td id="T_bdde8_row0_col5" class="data row0 col5" >0.3048</td>
#       <td id="T_bdde8_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_bdde8_row0_col7" class="data row0 col7" >-0.0000</td>
#       <td id="T_bdde8_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_bdde8_row0_col9" class="data row0 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdde8_row1_col0" class="data row1 col0" >16.2459</td>
#       <td id="T_bdde8_row1_col1" class="data row1 col1" >439.7366</td>
#       <td id="T_bdde8_row1_col2" class="data row1 col2" >20.9699</td>
#       <td id="T_bdde8_row1_col3" class="data row1 col3" >0.6104</td>
#       <td id="T_bdde8_row1_col4" class="data row1 col4" >0.5696</td>
#       <td id="T_bdde8_row1_col5" class="data row1 col5" >0.2057</td>
#       <td id="T_bdde8_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_bdde8_row1_col7" class="data row1 col7" >-0.0000</td>
#       <td id="T_bdde8_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_bdde8_row1_col9" class="data row1 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bdde8_row2_col0" class="data row2 col0" >22.4646</td>
#       <td id="T_bdde8_row2_col1" class="data row2 col1" >747.0884</td>
#       <td id="T_bdde8_row2_col2" class="data row2 col2" >27.3329</td>
#       <td id="T_bdde8_row2_col3" class="data row2 col3" >0.5126</td>
#       <td id="T_bdde8_row2_col4" class="data row2 col4" >0.6264</td>
#       <td id="T_bdde8_row2_col5" class="data row2 col5" >0.3700</td>
#       <td id="T_bdde8_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_bdde8_row2_col7" class="data row2 col7" >-0.0000</td>
#       <td id="T_bdde8_row2_col8" class="data row2 col8" >0.0000</td>
#       <td id="T_bdde8_row2_col9" class="data row2 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bdde8_row3_col0" class="data row3 col0" >20.1387</td>
#       <td id="T_bdde8_row3_col1" class="data row3 col1" >745.0609</td>
#       <td id="T_bdde8_row3_col2" class="data row3 col2" >27.2958</td>
#       <td id="T_bdde8_row3_col3" class="data row3 col3" >0.4397</td>
#       <td id="T_bdde8_row3_col4" class="data row3 col4" >0.4486</td>
#       <td id="T_bdde8_row3_col5" class="data row3 col5" >0.2529</td>
#       <td id="T_bdde8_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_bdde8_row3_col7" class="data row3 col7" >-0.0000</td>
#       <td id="T_bdde8_row3_col8" class="data row3 col8" >0.0000</td>
#       <td id="T_bdde8_row3_col9" class="data row3 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bdde8_row4_col0" class="data row4 col0" >22.0184</td>
#       <td id="T_bdde8_row4_col1" class="data row4 col1" >857.7186</td>
#       <td id="T_bdde8_row4_col2" class="data row4 col2" >29.2868</td>
#       <td id="T_bdde8_row4_col3" class="data row4 col3" >0.4897</td>
#       <td id="T_bdde8_row4_col4" class="data row4 col4" >0.5087</td>
#       <td id="T_bdde8_row4_col5" class="data row4 col5" >0.2488</td>
#       <td id="T_bdde8_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_bdde8_row4_col7" class="data row4 col7" >-0.0000</td>
#       <td id="T_bdde8_row4_col8" class="data row4 col8" >0.0000</td>
#       <td id="T_bdde8_row4_col9" class="data row4 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bdde8_row5_col0" class="data row5 col0" >18.2576</td>
#       <td id="T_bdde8_row5_col1" class="data row5 col1" >572.4947</td>
#       <td id="T_bdde8_row5_col2" class="data row5 col2" >23.9269</td>
#       <td id="T_bdde8_row5_col3" class="data row5 col3" >0.4849</td>
#       <td id="T_bdde8_row5_col4" class="data row5 col4" >0.5217</td>
#       <td id="T_bdde8_row5_col5" class="data row5 col5" >0.2055</td>
#       <td id="T_bdde8_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_bdde8_row5_col7" class="data row5 col7" >-0.0000</td>
#       <td id="T_bdde8_row5_col8" class="data row5 col8" >0.0000</td>
#       <td id="T_bdde8_row5_col9" class="data row5 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bdde8_row6_col0" class="data row6 col0" >20.9970</td>
#       <td id="T_bdde8_row6_col1" class="data row6 col1" >844.4140</td>
#       <td id="T_bdde8_row6_col2" class="data row6 col2" >29.0588</td>
#       <td id="T_bdde8_row6_col3" class="data row6 col3" >0.1280</td>
#       <td id="T_bdde8_row6_col4" class="data row6 col4" >0.3292</td>
#       <td id="T_bdde8_row6_col5" class="data row6 col5" >0.2850</td>
#       <td id="T_bdde8_row6_col6" class="data row6 col6" >0.0000</td>
#       <td id="T_bdde8_row6_col7" class="data row6 col7" >-0.0000</td>
#       <td id="T_bdde8_row6_col8" class="data row6 col8" >0.0000</td>
#       <td id="T_bdde8_row6_col9" class="data row6 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bdde8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bdde8_row7_col0" class="data row7 col0" >18.5809</td>
#       <td id="T_bdde8_row7_col1" class="data row7 col1" >570.6229</td>
#       <td id="T_bdde8_row7_col2" class="data row7 col2" >23.8877</td>
#       <td id="T_bdde8_row7_col3" class="data row7 col3" >0.4012</td>
#       <td id="T_bdde8_row7_col4" class="data row7 col4" >0.2683</td>
#       <td id="T_bdde8_row7_col5" class="data row7 col5" >0.2323</td>
#       <td id="T_bdde8_row7_col6" class="data row7 col6" >0.0000</td>
#       <td id="T_bdde8_row7_col7" class="data row7 col7" >-0.0000</td>
#       <td id="T_bdde8_row7_col8" class="data row7 col8" >0.0000</td>
#       <td id="T_bdde8_row7_col9" class="data row7 col9" >-0.0000</td>
#     </tr>
#     <tr>
#       <th
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %%
# pipeline_path = '../pipelines/tuned_models/'
# if not os.path.exists(pipeline_path):
#     print("Path to pipeline does not exist")
# else:
#     model_names_to_load = ['br', 'lasso', 'llar', 'en', 'huber']

#     tuned_models = {}

#     for name in model_names_to_load:
#         tuned_models[name] = load_model(os.path.join(pipeline_path, name)).named_steps['trained_model']
    
#     print(tuned_models)

# %%
# pipeline_path = '../pipelines/tuned_models/'
# os.makedirs(pipeline_path, exist_ok=True)

# for model_name, model_object in tuned_models.items():
#     save_model(model_object, os.path.join(pipeline_path, model_name));

# %%
tuning_predictions_metric = {}

for model_name, model_object in tuned_models.items():
    predict_model(model_object, verbose=False)
    tuning_predictions_metric[model_name] = pull()

# %%
list_of_metric_dfs = []

file_name = 'temp_excel.xlsx'

# Iterate through the dictionary and append each DataFrame to the list
for model_name, metrics_df in holdout_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

# Concatenate all DataFrames into a single one
print("--- Holdout Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name) as writer:
    results_df.to_excel(writer, sheet_name='Base Model Metrics', index=False)

list_of_metric_dfs = []
for model_name, metrics_df in tuning_predictions_metric.items():
    list_of_metric_dfs.append(metrics_df)

print("\n--- Tuned Predictions DataFrame ---", end='\n\n')
results_df = pd.concat(list_of_metric_dfs, ignore_index=True)
print(results_df.to_string())

with pd.ExcelWriter(file_name, mode='a') as writer:
    results_df.to_excel(writer, sheet_name='Tuned Model Metrics', index=False)
# Out:
# --- Holdout Predictions DataFrame ---
#
#                           Model      MAE        MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0  Lasso Least Angle Regression  22.4764   808.0530  28.4263  0.2859  0.3397  0.3038  0.2842   28.4612   0.2861    28.4236
# 1       Random Forest Regressor  24.8310  1014.2894  31.8479  0.1037  0.3752  0.3329  0.1051   31.8222   0.1035    31.8512
# 2              Lasso Regression  22.4764   808.0561  28.4263  0.2859  0.3397  0.3038  0.2842   28.4612   0.2861    28.4236
# 3         Extra Trees Regressor  24.4420   968.2271  31.1163  0.1444  0.3727  0.3270  0.1414   31.1706   0.1440    31.1235
# 4               Huber Regressor  22.6155   839.5115  28.9743  0.2581  0.3398  0.2991  0.2581   28.9756   0.2566    29.0045
#
# --- Tuned Predictions DataFrame ---
#
#                           Model      MAE       MSE     RMSE      R2   RMSLE    MAPE  R2_RND  RMSE_RND  R2_CEIL  RMSE_CEIL
# 0  Lasso Least Angle Regression  22.4764  808.0530  28.4263  0.2859  0.3397  0.3038  0.2842   28.4612   0.2861    28.4236
# 1       Random Forest Regressor  22.5751  850.1634  29.1576  0.2487  0.3474  0.3025  0.2514   29.1054   0.2474    29.1826
# 2              Lasso Regression  22.4570  807.3954  28.4147  0.2865  0.3397  0.3038  0.2873   28.3985   0.2859    28.4264
# 3         Extra Trees Regressor  22.6434  828.9390  28.7913  0.2675  0.3445  0.3063  0.2677   28.7861   0.2671    28.7990
# 4               Huber Regressor  22.5208  831.5756  28.8371  0.2651  0.3395  0.3005  0.2661   28.8181   0.2643    28.8537
