# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
import os
from typing import Union, Tuple

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import SimpleImputer, KNNImputer, IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
df = pd.read_csv("data/EMEWS_cleaned_with_nan.csv")
df.head()
# Out:
#         day                 date  total_number_of_patients  \
# 0  thursday  2024-01-04 00:00:00                     100.0
# 1    friday  2024-01-05 00:00:00                     112.0
# 2  saturday  2024-01-06 00:00:00                      69.0
# 3    sunday  2024-01-07 00:00:00                      74.0
# 4    monday  2024-01-08 00:00:00                      87.0
#
#    total_number_of_emews  zone_a_mwr_patients  zone_a_mwr_cat_3  \
# 0                  302.0                 64.0              53.0
# 1                  220.0                 59.0              59.0
# 2                  175.0                 36.0              36.0
# 3                  206.0                 30.0              27.0
# 4                  267.0                 41.0              38.0
#
#    zone_a_mwr_cat_4  zone_a_mwr_sets_of_emews  zone_a_mwr_deescalations  \
# 0              11.0                     192.0                      10.0
# 1               0.0                      90.0                      10.0
# 2               0.0                      58.0                       3.0
# 3               3.0                      41.0                       2.0
# 4               3.0                     116.0                      10.0
#
#    zone_a_mwr_escalations  ...  zone_a__cat_3  zone_a__sets_of_emews  \
# 0                     6.0  ...            9.0                   50.0
# 1                     0.0  ...           12.0                   60.0
# 2                     2.0  ...            0.0                   67.0
# 3                    11.0  ...            6.0                   61.0
# 4                     1.0  ...            5.0                   73.0
#
#    zone_a__deescalations  zone_a__escalations  zone_b/c_patients  \
# 0                    9.0                  1.0               15.0
# 1                   10.0                  0.0               27.0
# 2                    5.0                  2.0               15.0
# 3                    7.0                  3.0               16.0
# 4                    8.0                  1.0               23.0
#
#    zone_b/c_cat_2  zone_b/c_cat_3  zone_b/c_sets_of_emews  \
# 0             NaN             NaN                    60.0
# 1            12.0            15.0                    70.0
# 2             NaN             NaN                    50.0
# 3             NaN             NaN                    50.0
# 4            10.0            13.0                    78.0
#
#    zone_b/c_deescalations  zone_b/c_escalations
# 0                     1.0                   5.0
# 1                     0.0                   5.0
# 2                     0.0                   5.0
# 3                     0.0                   5.0
# 4                     0.0                   4.0
#
# [5 rows x 22 columns]

# %%
date_req = pd.to_datetime('2024-01-17')
df['date'] = pd.to_datetime(df['date'])

new_row = pd.DataFrame([{col: np.nan for col in df.columns}])
new_row['date'] = date_req
new_row['day'] = date_req.day_name().lower()


df = pd.concat([new_row, df], ignore_index=True)
df.sort_values('date', inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
split_idx = int(len(df) * 0.9)
train_data = df.iloc[:split_idx]
test_data = df.iloc[split_idx:]

# Then split X and y
X_train = train_data.drop(columns=['total_number_of_patients', 'total_number_of_emews'])
y_train = train_data[['total_number_of_patients', 'total_number_of_emews']]

X_test = test_data.drop(columns=['total_number_of_patients', 'total_number_of_emews'])
y_test = test_data[['total_number_of_patients', 'total_number_of_emews']]

# X_train = train_df.drop(columns=['total_number_of_patients'])
# y_train = train_df[['total_number_of_patients']]

# X_test = test_df.drop(columns=['total_number_of_patients'])
# y_test = test_df[['total_number_of_patients']]

# %%
def apply_imputation(
        X_train: pd.DataFrame, 
        X_test: pd.DataFrame,
        imputer: Union[KNNImputer, IterativeImputer, SimpleImputer]
        ) -> Tuple[pd.DataFrame, pd.DataFrame]:

    num_cols = X_train.select_dtypes(include='number').columns
    non_num_cols = X_train.columns.difference(num_cols).to_list()

    X_train_num = X_train[num_cols]
    X_test_num = X_test[num_cols]

    needs_scaling = type(imputer) in (KNNImputer, IterativeImputer)

    if needs_scaling:
        scaler = StandardScaler()
        X_train_num = scaler.fit_transform(X_train_num)
        X_test_num = scaler.transform(X_test_num)

    X_train_imputed = imputer.fit_transform(X_train_num)
    X_test_imputed = imputer.transform(X_test_num)

    if needs_scaling:
        X_train_imputed = scaler.inverse_transform(X_train_imputed)
        X_test_imputed = scaler.inverse_transform(X_test_imputed)

    X_train_imputed = np.round(X_train_imputed).astype(int)
    X_test_imputed = np.round(X_test_imputed).astype(int)

    # Replace only numeric columns
    X_train_copy = X_train.copy()
    X_train_copy[num_cols] = X_train_imputed
    X_train_copy[non_num_cols] = X_train[non_num_cols]

    X_test_copy = X_test.copy()
    X_test_copy[num_cols] = X_test_imputed
    X_test_copy[non_num_cols] = X_test[non_num_cols]

    return X_train_copy, X_test_copy

# %%
imputation_strategies = {
    'mean': SimpleImputer(strategy='mean'),
    'median': SimpleImputer(strategy='median'),
    'mode': SimpleImputer(strategy='most_frequent'),
    'mice': IterativeImputer(random_state=42),
    'mice_hgb': IterativeImputer(estimator=HistGradientBoostingRegressor(random_state=42), random_state=42),
    'mice_lr': IterativeImputer(estimator=LinearRegression(), random_state=42),
    'mice_rf': IterativeImputer(estimator=RandomForestRegressor(random_state=42), random_state=42),
    'mice_svr': IterativeImputer(estimator=SVR(), random_state=42)
}

for i in range(3, 6):
    key = f'knn_{i}'
    imputation_strategies[key] = KNNImputer(n_neighbors=i)
    key = f'knn_{i}_distance'
    imputation_strategies[key] = KNNImputer(n_neighbors=i, weights='distance')
    key = f'mice_knn_{i}'
    imputation_strategies[key] = IterativeImputer(estimator=KNeighborsRegressor(n_neighbors=i), random_state=42)
    key = f'mice_knn_{i}_distance'
    imputation_strategies[key] = IterativeImputer(estimator=KNeighborsRegressor(n_neighbors=i, weights='distance'), random_state=42)
    

datasets = {}

for name, imputer in imputation_strategies.items():
    X_train_imp, X_test_imp = apply_imputation(X_train, X_test, imputer)

    train_df = pd.concat([X_train_imp, y_train], axis=1)
    test_df = pd.concat([X_test_imp, y_test], axis=1)

    train_df['date'] = pd.to_datetime(train_df['date'])
    test_df['date'] = pd.to_datetime(test_df['date'])

    # manual checks...
    patient_count_cols = ['zone_a_mwr_patients', 'zone_a__patients', 'zone_b/c_patients']
    emews_count_cols = ['zone_a_mwr_sets_of_emews', 'zone_a__sets_of_emews', 'zone_b/c_sets_of_emews']
    
    train_df['total_number_of_patients'] = train_df['total_number_of_patients'].fillna(train_df[patient_count_cols].sum(axis=1))
    test_df['total_number_of_patients'] = test_df['total_number_of_patients'].fillna(test_df[patient_count_cols].sum(axis=1))

    train_df['total_number_of_emews'] = train_df['total_number_of_emews'].fillna(train_df[emews_count_cols].sum(axis=1))
    test_df['total_number_of_emews'] = test_df['total_number_of_emews'].fillna(test_df[emews_count_cols].sum(axis=1))

    # train_df['corrected_total_number_of_patients'] = train_df[patient_count_cols].sum(axis=1)
    # test_df['corrected_total_number_of_patients'] = test_df[patient_count_cols].sum(axis=1)

    datasets[name] = (train_df, test_df)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def r2_rounded(y_true, y_pred):
    """Calculates R2 score after rounding predictions to the nearest whole number."""
    return r2_score(y_true, np.round(y_pred))

def rmse_rounded(y_true, y_pred):
    """Calculates RMSE after rounding predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.round(y_pred)))

def r2_ceil(y_true, y_pred):
    """Calculates R2 score after ceiling predictions to the nearest whole number."""
    return r2_score(y_true, np.ceil(y_pred))

def rmse_ceil(y_true, y_pred):
    """Calculates RMSE after ceiling predictions to the nearest whole number."""
    return np.sqrt(mean_squared_error(y_true, np.ceil(y_pred)))

def mae_rounded(y_true, y_pred):
    """Calculates MAE after rounding predictions to the nearest whole number."""
    return mean_absolute_error(y_true, np.round(y_pred))

def mae_ceil(y_true, y_pred):
    """Calculates MAE after ceiling predictions to the nearest whole number."""
    return mean_absolute_error(y_true, np.ceil(y_pred))

# %%
from pycaret.regression import *
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit

results = []

for name, (train_df, test_df) in datasets.items():
    print(f"\n🔍 Processing dataset: {name}")
    # train_df = train_df.copy().drop(columns=['corrected_total_number_of_patients'])
    # test_df = test_df.copy().drop(columns=['corrected_total_number_of_patients'])

    setup(
        data=train_df,
        target='total_number_of_patients',
        session_id=42,
        verbose=False,
        test_data=test_df,  # Use predefined test set,
        fold_strategy='timeseries',
        data_split_shuffle=False,
        fold_shuffle=False
    )

    best_model = compare_models(exclude=['lightgbm', 'par', 'dummy', 'lar'], sort='R2')
    leaderboard = pull()
    top_model_results = leaderboard.iloc[0]

    preds = predict_model(best_model, data=test_df)
    
    y_true = test_df['total_number_of_patients'].values
    y_pred = preds['prediction_label'].values

    # Standard metrics
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)

    # Custom metrics
    r2_r = r2_rounded(y_true, y_pred)
    rmse_r = rmse_rounded(y_true, y_pred)
    r2_c = r2_ceil(y_true, y_pred)
    rmse_c = rmse_ceil(y_true, y_pred)
    mae_r = mae_rounded(y_true, y_pred)
    mae_c = mae_ceil(y_true, y_pred)

    results.append({
        'dataset': name,
        'model': top_model_results['Model'],
        'R2_train': top_model_results['R2'],
        'R2_test': r2,
        'RMSE_train': top_model_results['RMSE'],
        'RMSE_test': rmse,
        'MAE_train': top_model_results['MAE'],
        'MAE_test': mae,
        'R2_rounded': r2_r,
        'RMSE_rounded': rmse_r,
        'MAE_rounded': mae_r,
        'R2_ceil': r2_c,
        'RMSE_ceil': rmse_c,
        'MAE_ceil': mae_c
    })

results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by='R2_test', ascending=False)
print("\n📊 Final Results:")
results_df
# Out:
# 🔍 Processing dataset: mean
# <style type="text/css">
# #T_d4012 th {
#   text-align: left;
# }
# #T_d4012_row0_col0, #T_d4012_row1_col0, #T_d4012_row1_col1, #T_d4012_row1_col2, #T_d4012_row1_col3, #T_d4012_row1_col4, #T_d4012_row1_col5, #T_d4012_row1_col6, #T_d4012_row2_col0, #T_d4012_row2_col1, #T_d4012_row2_col2, #T_d4012_row2_col3, #T_d4012_row2_col4, #T_d4012_row2_col5, #T_d4012_row2_col6, #T_d4012_row3_col0, #T_d4012_row3_col1, #T_d4012_row3_col2, #T_d4012_row3_col3, #T_d4012_row3_col4, #T_d4012_row3_col5, #T_d4012_row3_col6, #T_d4012_row4_col0, #T_d4012_row4_col1, #T_d4012_row4_col2, #T_d4012_row4_col3, #T_d4012_row4_col4, #T_d4012_row4_col5, #T_d4012_row4_col6, #T_d4012_row5_col0, #T_d4012_row5_col1, #T_d4012_row5_col2, #T_d4012_row5_col3, #T_d4012_row5_col4, #T_d4012_row5_col5, #T_d4012_row5_col6, #T_d4012_row6_col0, #T_d4012_row6_col1, #T_d4012_row6_col2, #T_d4012_row6_col3, #T_d4012_row6_col4, #T_d4012_row6_col5, #T_d4012_row6_col6, #T_d4012_row7_col0, #T_d4012_row7_col1, #T_d4012_row7_col2, #T_d4012_row7_col3, #T_d4012_row7_col4, #T_d4012_row7_col5, #T_d4012_row7_col6, #T_d4012_row8_col0, #T_d4012_row8_col1, #T_d4012_row8_col2, #T_d4012_row8_col3, #T_d4012_row8_col4, #T_d4012_row8_col5, #T_d4012_row8_col6, #T_d4012_row9_col0, #T_d4012_row9_col1, #T_d4012_row9_col2, #T_d4012_row9_col3, #T_d4012_row9_col4, #T_d4012_row9_col5, #T_d4012_row9_col6, #T_d4012_row10_col0, #T_d4012_row10_col1, #T_d4012_row10_col2, #T_d4012_row10_col3, #T_d4012_row10_col4, #T_d4012_row10_col5, #T_d4012_row10_col6, #T_d4012_row11_col0, #T_d4012_row11_col1, #T_d4012_row11_col2, #T_d4012_row11_col3, #T_d4012_row11_col4, #T_d4012_row11_col5, #T_d4012_row11_col6, #T_d4012_row12_col0, #T_d4012_row12_col1, #T_d4012_row12_col2, #T_d4012_row12_col3, #T_d4012_row12_col4, #T_d4012_row12_col5, #T_d4012_row12_col6, #T_d4012_row13_col0, #T_d4012_row13_col1, #T_d4012_row13_col2, #T_d4012_row13_col3, #T_d4012_row13_col4, #T_d4012_row13_col5, #T_d4012_row13_col6, #T_d4012_row14_col0, #T_d4012_row14_col1, #T_d4012_row14_col2, #T_d4012_row14_col3, #T_d4012_row14_col4, #T_d4012_row14_col5, #T_d4012_row14_col6, #T_d4012_row15_col0, #T_d4012_row15_col1, #T_d4012_row15_col2, #T_d4012_row15_col3, #T_d4012_row15_col4, #T_d4012_row15_col5, #T_d4012_row15_col6 {
#   text-align: left;
# }
# #T_d4012_row0_col1, #T_d4012_row0_col2, #T_d4012_row0_col3, #T_d4012_row0_col4, #T_d4012_row0_col5, #T_d4012_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d4012_row0_col7, #T_d4012_row1_col7, #T_d4012_row2_col7, #T_d4012_row4_col7, #T_d4012_row6_col7, #T_d4012_row7_col7, #T_d4012_row8_col7, #T_d4012_row9_col7, #T_d4012_row10_col7, #T_d4012_row11_col7, #T_d4012_row12_col7, #T_d4012_row13_col7, #T_d4012_row14_col7, #T_d4012_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d4012_row3_col7, #T_d4012_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d4012">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4012_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d4012_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d4012_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d4012_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d4012_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d4012_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d4012_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d4012_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4012_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_d4012_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_d4012_row0_col1" class="data row0 col1" >2.8704</td>
#       <td id="T_d4012_row0_col2" class="data row0 col2" >35.2056</td>
#       <td id="T_d4012_row0_col3" class="data row0 col3" >5.5136</td>
#       <td id="T_d4012_row0_col4" class="data row0 col4" >0.9120</td>
#       <td id="T_d4012_row0_col5" class="data row0 col5" >0.3106</td>
#       <td id="T_d4012_row0_col6" class="data row0 col6" >0.0955</td>
#       <td id="T_d4012_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_d4012_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_d4012_row1_col1" class="data row1 col1" >4.4972</td>
#       <td id="T_d4012_row1_col2" class="data row1 col2" >44.1738</td>
#       <td id="T_d4012_row1_col3" class="data row1 col3" >6.2896</td>
#       <td id="T_d4012_row1_col4" class="data row1 col4" >0.8892</td>
#       <td id="T_d4012_row1_col5" class="data row1 col5" >0.3720</td>
#       <td id="T_d4012_row1_col6" class="data row1 col6" >0.1604</td>
#       <td id="T_d4012_row1_col7" class="data row1 col7" >0.2930</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row2" class="row_heading level0 row2" >llar</th>
#       <td id="T_d4012_row2_col0" class="data row2 col0" >Lasso Least Angle Regression</td>
#       <td id="T_d4012_row2_col1" class="data row2 col1" >4.4972</td>
#       <td id="T_d4012_row2_col2" class="data row2 col2" >44.1731</td>
#       <td id="T_d4012_row2_col3" class="data row2 col3" >6.2895</td>
#       <td id="T_d4012_row2_col4" class="data row2 col4" >0.8892</td>
#       <td id="T_d4012_row2_col5" class="data row2 col5" >0.3719</td>
#       <td id="T_d4012_row2_col6" class="data row2 col6" >0.1604</td>
#       <td id="T_d4012_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_d4012_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_d4012_row3_col1" class="data row3 col1" >4.5194</td>
#       <td id="T_d4012_row3_col2" class="data row3 col2" >44.9587</td>
#       <td id="T_d4012_row3_col3" class="data row3 col3" >6.3342</td>
#       <td id="T_d4012_row3_col4" class="data row3 col4" >0.8877</td>
#       <td id="T_d4012_row3_col5" class="data row3 col5" >0.3720</td>
#       <td id="T_d4012_row3_col6" class="data row3 col6" >0.1589</td>
#       <td id="T_d4012_row3_col7" class="data row3 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_d4012_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_d4012_row4_col1" class="data row4 col1" >4.4659</td>
#       <td id="T_d4012_row4_col2" class="data row4 col2" >46.5528</td>
#       <td id="T_d4012_row4_col3" class="data row4 col3" >6.4912</td>
#       <td id="T_d4012_row4_col4" class="data row4 col4" >0.8823</td>
#       <td id="T_d4012_row4_col5" class="data row4 col5" >0.3799</td>
#       <td id="T_d4012_row4_col6" class="data row4 col6" >0.1551</td>
#       <td id="T_d4012_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_d4012_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_d4012_row5_col1" class="data row5 col1" >4.8270</td>
#       <td id="T_d4012_row5_col2" class="data row5 col2" >53.0170</td>
#       <td id="T_d4012_row5_col3" class="data row5 col3" >6.9475</td>
#       <td id="T_d4012_row5_col4" class="data row5 col4" >0.8675</td>
#       <td id="T_d4012_row5_col5" class="data row5 col5" >0.3777</td>
#       <td id="T_d4012_row5_col6" class="data row5 col6" >0.1528</td>
#       <td id="T_d4012_row5_col7" class="data row5 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_d4012_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_d4012_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_d4012_row6_col1" class="data row6 col1" >4.8881</td>
#       <td id="T_d4012_row6_col2" class="data row6 col2" >54.4063</td>
#       <td id="T_d4012_row6_col3" class="data row6 col3" >7.0154</td>
#       <td id="T_d4012_row6_col4" cla
# <style type="text/css">
# </style>
# <table id="T_2fffd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fffd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2fffd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2fffd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2fffd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2fffd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2fffd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2fffd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fffd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fffd_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_2fffd_row0_col1" class="data row0 col1" >3.3223</td>
#       <td id="T_2fffd_row0_col2" class="data row0 col2" >28.8363</td>
#       <td id="T_2fffd_row0_col3" class="data row0 col3" >5.3699</td>
#       <td id="T_2fffd_row0_col4" class="data row0 col4" >0.9309</td>
#       <td id="T_2fffd_row0_col5" class="data row0 col5" >0.1128</td>
#       <td id="T_2fffd_row0_col6" class="data row0 col6" >0.0547</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: median
# <style type="text/css">
# #T_367e1 th {
#   text-align: left;
# }
# #T_367e1_row0_col0, #T_367e1_row1_col0, #T_367e1_row1_col1, #T_367e1_row1_col2, #T_367e1_row1_col3, #T_367e1_row1_col4, #T_367e1_row1_col5, #T_367e1_row1_col6, #T_367e1_row2_col0, #T_367e1_row2_col1, #T_367e1_row2_col2, #T_367e1_row2_col3, #T_367e1_row2_col4, #T_367e1_row2_col5, #T_367e1_row2_col6, #T_367e1_row3_col0, #T_367e1_row3_col1, #T_367e1_row3_col2, #T_367e1_row3_col3, #T_367e1_row3_col4, #T_367e1_row3_col5, #T_367e1_row3_col6, #T_367e1_row4_col0, #T_367e1_row4_col1, #T_367e1_row4_col2, #T_367e1_row4_col3, #T_367e1_row4_col4, #T_367e1_row4_col5, #T_367e1_row4_col6, #T_367e1_row5_col0, #T_367e1_row5_col1, #T_367e1_row5_col2, #T_367e1_row5_col3, #T_367e1_row5_col4, #T_367e1_row5_col5, #T_367e1_row5_col6, #T_367e1_row6_col0, #T_367e1_row6_col1, #T_367e1_row6_col2, #T_367e1_row6_col3, #T_367e1_row6_col4, #T_367e1_row6_col5, #T_367e1_row6_col6, #T_367e1_row7_col0, #T_367e1_row7_col1, #T_367e1_row7_col2, #T_367e1_row7_col3, #T_367e1_row7_col4, #T_367e1_row7_col5, #T_367e1_row7_col6, #T_367e1_row8_col0, #T_367e1_row8_col1, #T_367e1_row8_col2, #T_367e1_row8_col3, #T_367e1_row8_col4, #T_367e1_row8_col5, #T_367e1_row8_col6, #T_367e1_row9_col0, #T_367e1_row9_col1, #T_367e1_row9_col2, #T_367e1_row9_col3, #T_367e1_row9_col4, #T_367e1_row9_col5, #T_367e1_row9_col6, #T_367e1_row10_col0, #T_367e1_row10_col1, #T_367e1_row10_col2, #T_367e1_row10_col3, #T_367e1_row10_col4, #T_367e1_row10_col5, #T_367e1_row10_col6, #T_367e1_row11_col0, #T_367e1_row11_col1, #T_367e1_row11_col2, #T_367e1_row11_col3, #T_367e1_row11_col4, #T_367e1_row11_col5, #T_367e1_row11_col6, #T_367e1_row12_col0, #T_367e1_row12_col1, #T_367e1_row12_col2, #T_367e1_row12_col3, #T_367e1_row12_col4, #T_367e1_row12_col5, #T_367e1_row12_col6, #T_367e1_row13_col0, #T_367e1_row13_col1, #T_367e1_row13_col2, #T_367e1_row13_col3, #T_367e1_row13_col4, #T_367e1_row13_col5, #T_367e1_row13_col6, #T_367e1_row14_col0, #T_367e1_row14_col1, #T_367e1_row14_col2, #T_367e1_row14_col3, #T_367e1_row14_col4, #T_367e1_row14_col5, #T_367e1_row14_col6, #T_367e1_row15_col0, #T_367e1_row15_col1, #T_367e1_row15_col2, #T_367e1_row15_col3, #T_367e1_row15_col4, #T_367e1_row15_col5, #T_367e1_row15_col6 {
#   text-align: left;
# }
# #T_367e1_row0_col1, #T_367e1_row0_col2, #T_367e1_row0_col3, #T_367e1_row0_col4, #T_367e1_row0_col5, #T_367e1_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_367e1_row0_col7, #T_367e1_row1_col7, #T_367e1_row2_col7, #T_367e1_row4_col7, #T_367e1_row6_col7, #T_367e1_row7_col7, #T_367e1_row8_col7, #T_367e1_row9_col7, #T_367e1_row10_col7, #T_367e1_row11_col7, #T_367e1_row12_col7, #T_367e1_row13_col7, #T_367e1_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_367e1_row3_col7, #T_367e1_row5_col7, #T_367e1_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_367e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_367e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_367e1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_367e1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_367e1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_367e1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_367e1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_367e1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_367e1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_367e1_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_367e1_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_367e1_row0_col1" class="data row0 col1" >2.8616</td>
#       <td id="T_367e1_row0_col2" class="data row0 col2" >36.7857</td>
#       <td id="T_367e1_row0_col3" class="data row0 col3" >5.5823</td>
#       <td id="T_367e1_row0_col4" class="data row0 col4" >0.9095</td>
#       <td id="T_367e1_row0_col5" class="data row0 col5" >0.3190</td>
#       <td id="T_367e1_row0_col6" class="data row0 col6" >0.0941</td>
#       <td id="T_367e1_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_367e1_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_367e1_row1_col1" class="data row1 col1" >4.4388</td>
#       <td id="T_367e1_row1_col2" class="data row1 col2" >44.6495</td>
#       <td id="T_367e1_row1_col3" class="data row1 col3" >6.3034</td>
#       <td id="T_367e1_row1_col4" class="data row1 col4" >0.8887</td>
#       <td id="T_367e1_row1_col5" class="data row1 col5" >0.3671</td>
#       <td id="T_367e1_row1_col6" class="data row1 col6" >0.1570</td>
#       <td id="T_367e1_row1_col7" class="data row1 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row2" class="row_heading level0 row2" >llar</th>
#       <td id="T_367e1_row2_col0" class="data row2 col0" >Lasso Least Angle Regression</td>
#       <td id="T_367e1_row2_col1" class="data row2 col1" >4.4386</td>
#       <td id="T_367e1_row2_col2" class="data row2 col2" >44.6472</td>
#       <td id="T_367e1_row2_col3" class="data row2 col3" >6.3032</td>
#       <td id="T_367e1_row2_col4" class="data row2 col4" >0.8887</td>
#       <td id="T_367e1_row2_col5" class="data row2 col5" >0.3671</td>
#       <td id="T_367e1_row2_col6" class="data row2 col6" >0.1570</td>
#       <td id="T_367e1_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_367e1_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_367e1_row3_col1" class="data row3 col1" >4.4640</td>
#       <td id="T_367e1_row3_col2" class="data row3 col2" >45.3953</td>
#       <td id="T_367e1_row3_col3" class="data row3 col3" >6.3462</td>
#       <td id="T_367e1_row3_col4" class="data row3 col4" >0.8875</td>
#       <td id="T_367e1_row3_col5" class="data row3 col5" >0.3679</td>
#       <td id="T_367e1_row3_col6" class="data row3 col6" >0.1550</td>
#       <td id="T_367e1_row3_col7" class="data row3 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_367e1_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_367e1_row4_col1" class="data row4 col1" >4.3930</td>
#       <td id="T_367e1_row4_col2" class="data row4 col2" >46.8690</td>
#       <td id="T_367e1_row4_col3" class="data row4 col3" >6.4900</td>
#       <td id="T_367e1_row4_col4" class="data row4 col4" >0.8829</td>
#       <td id="T_367e1_row4_col5" class="data row4 col5" >0.3765</td>
#       <td id="T_367e1_row4_col6" class="data row4 col6" >0.1501</td>
#       <td id="T_367e1_row4_col7" class="data row4 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_367e1_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_367e1_row5_col1" class="data row5 col1" >4.7103</td>
#       <td id="T_367e1_row5_col2" class="data row5 col2" >52.2162</td>
#       <td id="T_367e1_row5_col3" class="data row5 col3" >6.8538</td>
#       <td id="T_367e1_row5_col4" class="data row5 col4" >0.8715</td>
#       <td id="T_367e1_row5_col5" class="data row5 col5" >0.3753</td>
#       <td id="T_367e1_row5_col6" class="data row5 col6" >0.1440</td>
#       <td id="T_367e1_row5_col7" class="data row5 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_367e1_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_367e1_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_367e1_row6_col1" class="data row6 col1" >4.7729</td>
#       <td id="T_367e1_row6_col2" class="data row6 col2" >53.7288</td>
#       <td id="T_367e1_row6_col3" class="data row6 col3" >6.9302</td>
#       <td id="T_367e1_row6_col4" cla
# <style type="text/css">
# </style>
# <table id="T_5ac1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ac1d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5ac1d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5ac1d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5ac1d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5ac1d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5ac1d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5ac1d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ac1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ac1d_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_5ac1d_row0_col1" class="data row0 col1" >3.2800</td>
#       <td id="T_5ac1d_row0_col2" class="data row0 col2" >32.7253</td>
#       <td id="T_5ac1d_row0_col3" class="data row0 col3" >5.7206</td>
#       <td id="T_5ac1d_row0_col4" class="data row0 col4" >0.9223</td>
#       <td id="T_5ac1d_row0_col5" class="data row0 col5" >0.1166</td>
#       <td id="T_5ac1d_row0_col6" class="data row0 col6" >0.0548</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mode
# <style type="text/css">
# #T_e9d74 th {
#   text-align: left;
# }
# #T_e9d74_row0_col0, #T_e9d74_row0_col5, #T_e9d74_row1_col0, #T_e9d74_row1_col1, #T_e9d74_row1_col2, #T_e9d74_row1_col3, #T_e9d74_row1_col4, #T_e9d74_row1_col5, #T_e9d74_row1_col6, #T_e9d74_row2_col0, #T_e9d74_row2_col1, #T_e9d74_row2_col2, #T_e9d74_row2_col3, #T_e9d74_row2_col4, #T_e9d74_row2_col5, #T_e9d74_row2_col6, #T_e9d74_row3_col0, #T_e9d74_row3_col1, #T_e9d74_row3_col2, #T_e9d74_row3_col3, #T_e9d74_row3_col4, #T_e9d74_row3_col5, #T_e9d74_row3_col6, #T_e9d74_row4_col0, #T_e9d74_row4_col1, #T_e9d74_row4_col2, #T_e9d74_row4_col3, #T_e9d74_row4_col4, #T_e9d74_row4_col5, #T_e9d74_row4_col6, #T_e9d74_row5_col0, #T_e9d74_row5_col1, #T_e9d74_row5_col2, #T_e9d74_row5_col3, #T_e9d74_row5_col4, #T_e9d74_row5_col6, #T_e9d74_row6_col0, #T_e9d74_row6_col1, #T_e9d74_row6_col2, #T_e9d74_row6_col3, #T_e9d74_row6_col4, #T_e9d74_row6_col5, #T_e9d74_row6_col6, #T_e9d74_row7_col0, #T_e9d74_row7_col1, #T_e9d74_row7_col2, #T_e9d74_row7_col3, #T_e9d74_row7_col4, #T_e9d74_row7_col5, #T_e9d74_row7_col6, #T_e9d74_row8_col0, #T_e9d74_row8_col1, #T_e9d74_
#     </tr>
#     <tr>
#       <th id="T_e9d74_level0_row6" class="row_heading level0 row6" >catboost</th>
#       <td id="T_e9d74_row6_col0" class="data row6 col0" >CatBoost Regressor</td>
#       <td id="T_e9d74_row6_col1" class="data row6 col1" >4.4428</td>
#       <td id="T_e9d74_row6_col2" class="data row6 col2" >58.8796</td>
#       <td id="T_e9d74_row6_col3" class="data row6 col3" >6.9131</td>
#       <td id="T_e9d74_row6_
# <style type="text/css">
# </style>
# <table id="T_58fbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58fbd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_58fbd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_58fbd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_58fbd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_58fbd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_58fbd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_58fbd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58fbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58fbd_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_58fbd_row0_col1" class="data row0 col1" >3.6033</td>
#       <td id="T_58fbd_row0_col2" class="data row0 col2" >36.7412</td>
#       <td id="T_58fbd_row0_col3" class="data row0 col3" >6.0614</td>
#       <td id="T_58fbd_row0_col4" class="data row0 col4" >0.9127</td>
#       <td id="T_58fbd_row0_col5" class="data row0 col5" >0.0966</td>
#       <td id="T_58fbd_row0_col6" class="data row0 col6" >0.0611</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice
# <style type="text/css">
# #T_7484c th {
#   text-align: left;
# }
# #T_7484c_row0_col0, #T_7484c_row1_col0, #T_7484c_row1_col1, #T_7484c_row1_col2, #T_7484c_row1_col3, #T_7484c_row1_col4, #T_7484c_row1_col5, #T_7484c_row1_col6, #T_7484c_row2_col0, #T_7484c_row2_col1, #T_7484c_row2_col2, #T_7484c_row2_col3, #T_7484c_row2_col4, #T_7484c_row2_col5, #T_7484c_row2_col6, #T_7484c_row3_col0, #T_7484c_row3_col1, #T_7484c_row3_col2, #T_7484c_row3_col3, #T_7484c_row3_col4, #T_7484c_row3_col5, #T_7484c_row3_col6, #T_7484c_row4_col0, #T_7484c_row4_col1, #T_7484c_row4_col2, #T_7484c_row4_col3, #T_7484c_row4_col4, #T_7484c_row4_col5, #T_7484c_row4_col6, #T_7484c_row5_col0, #T_7484c_row5_col1, #T_7484c_row5_col2, #T_7484c_row5_col3, #T_7484c_row5_col4, #T_7484c_row5_col5, #T_7484c_row5_col6, #T_7484c_row6_col0, #T_7484c_row6_col1, #T_7484c_row6_col2, #T_7484c_row6_col3, #T_7484c_row6_col4, #T_7484c_row6_col5, #T_7484c_row6_col6, #T_7484c_row7_col0, #T_7484c_row7_col1, #T_7484c_row7_col2, #T_7484c_row7_col3, #T_7484c_row7_col4, #T_7484c_row7_col5, #T_7484c_row7_col6, #T_7484c_row8_col0, #T_7484c_row8_col1, #T_7484c_row8_col2, #T_7484c_row8_col3, #T_7484c_row8_col4, #T_7484c_row8_col5, #T_7484c_row8_col6, #T_7484c_row9_col0, #T_7484c_row9_col1, #T_7484c_row9_col2, #T_7484c_row9_col3, #T_7484c_row9_col4, #T_7484c_row9_col5, #T_7484c_row9_col6, #T_7484c_row10_col0, #T_7484c_row10_col1, #T_7484c_row10_col2, #T_7484c_row10_col3, #T_7484c_row10_col4, #T_7484c_row10_col5, #T_7484c_row10_col6, #T_7484c_row11_col0, #T_7484c_row11_col1, #T_7484c_row11_col2, #T_7484c_row11_col3, #T_7484c_row11_col4, #T_7484c_row11_col5, #T_7484c_row11_col6, #T_7484c_row12_col0, #T_7484c_row12_col1, #T_7484c_row12_col2, #T_7484c_row12_col3, #T_7484c_row12_col4, #T_7484c_row12_col5, #T_7484c_row12_col6, #T_7484c_row13_col0, #T_7484c_row13_col1, #T_7484c_row13_col2, #T_7484c_row13_col3, #T_7484c_row13_col4, #T_7484c_row13_col5, #T_7484c_row13_col6, #T_7484c_row14_col0, #T_7484c_row14_col1, #T_7484c_row14_col2, #T_7484c_row14_col3, #T_7484c_row14_col4, #T_7484c_row14_col5, #T_7484c_row14_col6, #T_7484c_row15_col0, #T_7484c_row15_col1, #T_7484c_row15_col2, #T_7484c_row15_col3, #T_7484c_row15_col4, #T_7484c_row15_col5, #T_7484c_row15_col6 {
#   text-align: left;
# }
# #T_7484c_row0_col1, #T_7484c_row0_col2, #T_7484c_row0_col3, #T_7484c_row0_col4, #T_7484c_row0_col5, #T_7484c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7484c_row0_col7, #T_7484c_row1_col7, #T_7484c_row2_col7, #T_7484c_row3_col7, #T_7484c_row5_col7, #T_7484c_row6_col7, #T_7484c_row7_col7, #T_7484c_row8_col7, #T_7484c_row9_col7, #T_7484c_row10_col7, #T_7484c_row11_col7, #T_7484c_row12_col7, #T_7484c_row13_col7, #T_7484c_row14_col7, #T_7484c_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7484c_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7484c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7484c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7484c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7484c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7484c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7484c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7484c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7484c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7484c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7484c_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_7484c_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_7484c_row0_col1" class="data row0 col1" >3.1378</td>
#       <td id="T_7484c_row0_col2" class="data row0 col2" >29.7448</td>
#       <td id="T_7484c_row0_col3" class="data row0 col3" >4.9910</td>
#       <td id="T_7484c_row0_col4" class="data row0 col4" >0.9261</td>
#       <td id="T_7484c_row0_col5" class="data row0 col5" >0.2525</td>
#       <td id="T_7484c_row0_col6" class="data row0 col6" >0.1075</td>
#       <td id="T_7484c_row0_col7" class="data row0 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_7484c_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_7484c_row1_col1" class="data row1 col1" >4.6122</td>
#       <td id="T_7484c_row1_col2" class="data row1 col2" >44.1376</td>
#       <td id="T_7484c_row1_col3" class="data row1 col3" >6.2519</td>
#       <td id="T_7484c_row1_col4" class="data row1 col4" >0.8879</td>
#       <td id="T_7484c_row1_col5" class="data row1 col5" >0.3326</td>
#       <td id="T_7484c_row1_col6" class="data row1 col6" >0.1608</td>
#       <td id="T_7484c_row1_col7" class="data row1 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_7484c_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_7484c_row2_col1" class="data row2 col1" >4.7508</td>
#       <td id="T_7484c_row2_col2" class="data row2 col2" >44.8463</td>
#       <td id="T_7484c_row2_col3" class="data row2 col3" >6.2679</td>
#       <td id="T_7484c_row2_col4" class="data row2 col4" >0.8877</td>
#       <td id="T_7484c_row2_col5" class="data row2 col5" >0.3275</td>
#       <td id="T_7484c_row2_col6" class="data row2 col6" >0.1634</td>
#       <td id="T_7484c_row2_col7" class="data row2 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_7484c_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_7484c_row3_col1" class="data row3 col1" >4.7759</td>
#       <td id="T_7484c_row3_col2" class="data row3 col2" >44.6456</td>
#       <td id="T_7484c_row3_col3" class="data row3 col3" >6.2655</td>
#       <td id="T_7484c_row3_col4" class="data row3 col4" >0.8874</td>
#       <td id="T_7484c_row3_col5" class="data row3 col5" >0.3287</td>
#       <td id="T_7484c_row3_col6" class="data row3 col6" >0.1657</td>
#       <td id="T_7484c_row3_col7" class="data row3 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_7484c_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_7484c_row4_col1" class="data row4 col1" >4.7763</td>
#       <td id="T_7484c_row4_col2" class="data row4 col2" >44.6509</td>
#       <td id="T_7484c_row4_col3" class="data row4 col3" >6.2658</td>
#       <td id="T_7484c_row4_col4" class="data row4 col4" >0.8874</td>
#       <td id="T_7484c_row4_col5" class="data row4 col5" >0.3287</td>
#       <td id="T_7484c_row4_col6" class="data row4 col6" >0.1657</td>
#       <td id="T_7484c_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_7484c_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_7484c_row5_col1" class="data row5 col1" >5.2022</td>
#       <td id="T_7484c_row5_col2" class="data row5 col2" >57.6982</td>
#       <td id="T_7484c_row5_col3" class="data row5 col3" >6.9504</td>
#       <td id="T_7484c_row5_col4" class="data row5 col4" >0.8643</td>
#       <td id="T_7484c_row5_col5" class="data row5 col5" >0.3282</td>
#       <td id="T_7484c_row5_col6" class="data row5 col6" >0.1622</td>
#       <td id="T_7484c_row5_col7" class="data row5 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_7484c_level0_row6" class="row_heading level0 row6" >et</th>
#       <td id="T_7484c_row6_col0" class="data row6 col0" >Extra Trees Regressor</td>
#       <td id="T_7484c_row6_col1" class="data row6 col1" >4.7914</td>
#       <td id="T_7484c_row6_col2" class="data row6 col2" >62.8181</td>
#       <td id="T_7484c_row6_col3" class="data row6 col3" >7.3825</td>
#       <td id="T_7484c_row6_col4"
# <style type="text/css">
# </style>
# <table id="T_1c406">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c406_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1c406_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1c406_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1c406_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1c406_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1c406_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1c406_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c406_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c406_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T
col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_a89ed_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_a89ed_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_a89ed_row6_col1" class="data row6 col1" >5.8330</td>
#       <td id="T_a89ed_row6_col2" class="data row6 col2" >66.2445</td>
#       <td id="T_a89ed_row6_col3" class="data row6 col3" >7.5805</td>
#       <td id="T_a89ed_row6_col4" cla
# <style type="text/css">
# </style>
# <table id="T_05ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05ef4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_05ef4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_05ef4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_05ef4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_05ef4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_05ef4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_05ef4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05ef4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05ef4_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_05ef4_row0_col1" class="data row0 col1" >4.3058</td>
#       <td id="T_05ef4_row0_col2" class="data row0 col2" >41.2616</td>
#       <td id="T_05ef4_row0_col3" class="data row0 col3" >6.4235</td>
#       <td id="T_05ef4_row0_col4" class="data row0 col4" >0.9020</td>
#       <td id="T_05ef4_row0_col5" class="data row0 col5" >0.1134</td>
#       <td id="T_05ef4_row0_col6" class="data row0 col6" >0.0778</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice_knn_5_distance
# <style type="text/css">
# #T_67c26 th {
#   text-align: left;
# }
# #T_67c26_row0_col0, #T_67c26_row1_col0, #T_67c26_row1_col1, #T_67c26_row1_col2, #T_67c26_row1_col3, #T_67c26_row1_col4, #T_67c26_row1_col5, #T_67c26_row1_col6, #T_67c26_row2_col0, #T_67c26_row2_col1, #T_67c26_row2_col2, #T_67c26_row2_col3, #T_67c26_row2_col4, #T_67c26_row2_col5, #T_67c26_row2_col6, #T_67c26_row3_col0, #T_67c26_row3_col1, #T_67c26_row3_col2, #T_67c26_row3_col3, #T_67c26_row3_col4, #T_67c26_row3_col5, #T_67c26_row3_col6, #T_67c26_row4_col0, #T_67c26_row4_col1, #T_67c26_row4_col2, #T_67c26_row4_col3, #T_67c26_row4_col4, #T_67c26_row4_col5, #T_67c26_row4_col6, #T_67c26_row5_col0, #T_67c26_row5_col1, #T_67c26_row5_col2, #T_67c26_row5_col3, #T_67c26_row5_col4, #T_67c26_row5_col5, #T_67c26_row5_col6, #T_67c26_row6_col0, #T_67c26_row6_col1, #T_67c26_row6_col2, #T_67c26_row6_col3, #T_67c26_row6_col4, #T_67c26_row6_col5, #T_67c26_row6_col6, #T_67c26_row7_col0, #T_67c26_row7_col1, #T_67c26_row7_col2, #T_67c26_row7_col3, #T_67c26_row7_col4, #T_67c26_row7_col5, #T_67c26_row7_col6, #T_67c26_row8_col0, #T_67c26_row8_col1, #T_67c26_row8_col2, #T_67c26_row8_col3, #T_67c26_row8_col4, #T_67c26_row8_col5, #T_67c26_row8_col6, #T_67c26_row9_col0, #T_67c26_row9_col1, #T_67c26_row9_col2, #T_67c26_row9_col3, #T_67c26_row9_col4, #T_67c26_row9_col5, #T_67c26_row9_col6, #T_67c26_row10_col0, #T_67c26_row10_col1, #T_67c26_row10_col2, #T_67c26_row10_col3, #T_67c26_row10_col4, #T_67c26_row10_col5, #T_67
row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_2df73_row0_col1" class="data row0 col1" >4.4232</td>
#       <td id="T_2df73_row0_col2" class="data row0 col2" >40.6881</td>
#       <td id="T_2df73_row0_col3" class="data row0 col3" >6.3787</td>
#       <td id="T_2df73_row0_col4" class="data row0 col4" >0.9037</td>
#       <td id="T_2df73_row0_col5" class="data row0 col5" >0.1047</td>
#       <td id="T_2df73_row0_col6" class="data row0 col6" >0.0765</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Final Results:
#                 dataset            model  R2_train   R2_test  RMSE_train  \
# 0                  mean  Huber Regressor    0.9120  0.930880      5.5136
# 1                median  Huber Regressor    0.9095  0.922313      5.5823
# 2                  mode  Huber Regressor    0.9010  0.912652      6.0425
# 5               mice_lr  Huber Regressor    0.9234  0.911111      5.1476
# 19  mice_knn_5_distance  Huber Regressor    0.8905  0.903712      6.0863
# 18           mice_knn_5  Huber Regressor    0.8910  0.902049      6.0195
# 15  mice_knn_4_distance  Huber Regressor    0.8883  0.899324      6.0642
# 17       knn_5_distance  Huber Regressor    0.8828  0.895837      6.2037
# 14           mice_knn_4  Huber Regressor    0.8883  0.894467      6.1037
# 3                  mice  Huber Regressor    0.9261  0.889505      4.9910
# 9        knn_3_distance  Huber Regressor    0.8669  0.888725      6.5771
# 10           mice_knn_3  Huber Regressor    0.8632  0.886504      6.7238
# 16                knn_5  Huber Regressor    0.8875  0.885370      6.1207
# 12                knn_4  Huber Regressor    0.8721  0.883181      6.5176
# 8                 knn_3  Huber Regressor    0.8701  0.882273      6.5305
# 13       knn_4_distance  Huber Regressor    0.8753  0.881408      6.4096
# 11  mice_knn_3_distance  Huber Regressor    0.8583  0.869725      6.8060
# 4              mice_hgb  Huber Regressor    0.8822  0.865058      6.3337
# 7              mice_svr  Huber Regressor    0.8778  0.861103      6.2083
# 6               mice_rf  Huber Regressor    0.8744  0.843974      6.5031
#
#     RMSE_test  MAE_train  MAE_test  R2_rounded  RMSE_rounded  MAE_rounded  \
# 0    5.369945     2.8704  3.322315    0.931326      5.352569     3.250000
# 1    5.720601     2.8616  3.280030    0.920395      5.790797     3.333333
# 2    6.061448     2.9933  3.603343    0.914255      6.005553     3.566667
# 5    6.109827     3.1821  3.798831    0.911381      6.100546     3.750000
# 19   6.378724     4.1768  4.423230    0.903329      6.391400     4.383333
# 18   6.423521     4.1172  4.305810    0.901562      6.439462     4.266667
# 15   6.589455     4.0469  4.201934    0.900107      6.563790     4.150000
# 17   6.689791     4.3095  4.309459    0.895379      6.704476     4.283333
# 14   6.746551     4.1135  4.285714    0.893692      6.771263     4.283333
# 3    6.903329     3.1378  3.989016    0.888128      6.946222     4.050000
# 9    7.002284     4.5129  4.732276    0.887361      7.045093     4.833333
# 10   7.022843     4.6267  5.076438    0.885439      7.055731     5.116667
# 16   6.993337     4.2639  4.436075    0.884409      7.022583     4.416667
# 12   7.175702     4.5950  4.702045    0.882063      7.209947     4.683333
# 8    7.202437     4.5080  5.002017    0.881082      7.238784     5.033333
# 13   7.229951     4.5006  4.806749    0.882933      7.183314     4.733333
# 11   7.563276     4.5954  5.441403    0.871022      7.525512     5.400000
# 4    8.045467     4.4552  5.424209    0.865050      8.045703     5.433333
# 7    7.689498     4.2127  5.264097    0.862188      7.659417     5.200000
# 6    8.354178     4.4709  5.531875    0.842876      8.383516     5.583333
#
#      R2_ceil  RMSE_ceil  MAE_ceil
# 10   7.022843     4.6267  5.076438    0.885439      7.055731     5.116667
# 16   6.993337     4.2639  4.436075    0.884409      7.022583     4.416667
# 13   7.229951     4.5006  4.806749    0.882933      7.183314     4.733333
# 12   7.175702     4.5950  4.702045    0.882063      7.209947     4.683333
# 8    7.202437     4.5080  5.002017    0.881082      7.238784     5.033333
# 11   7.563276     4.5954  5.441403    0.871022      7.525512     5.400000
# 4    8.045467     4.4552  5.424209    0.865050      8.045703     5.433333
# 7    7.689498     4.2127  5.264097    0.862188      7.659417     5.200000
# 6    8.354178     4.4709  5.531875    0.842876      8.383516     5.583333
#
#      R2_ceil  RMSE_ceil  MAE_ceil
# 0   0.927052   5.516641  3.233333
# 1   0.919643   5.818075  3.250000
# 2   0.906370   6.275614  3.716667
# 5   0.906619   6.262321  3.816667
# 19  0.901159   6.462714  4.433333
# 18  0.897685   6.565059  4.400000
# 15  0.894620   6.741662  4.283333
# 17  0.893091   6.777413  4.333333
# 14  0.890910   6.859300  4.350000
# 3   0.885423   7.029699  3.950000
# 9   0.886491   7.072246  4.650000
# 10  0.882064   7.158911  5.116667
# 16  0.885503   6.989278  4.383333
# 13  0.878168   7.328028  4.866667
# 12  0.881836   7.216878  4.683333
# 8   0.881082   7.238784  5.000000
# 11  0.864684   7.708221  5.450000
# 4   0.863104   8.103497  5.400000
# 7   0.856393   7.818781  5.366667
# 6   0.840156   8.455767  5.466667

# %%
from pycaret.regression import setup, compare_models, pull
import pandas as pd

results = []

for name, (train_df, test_df) in datasets.items():
    print(f"\n🔍 Processing dataset: {name}")
    # train_df = train_df.copy().drop(columns=['corrected_total_number_of_patients'])
    # test_df = test_df.copy().drop(columns=['corrected_total_number_of_patients'])

    setup(
        data=train_df,
        target='total_number_of_emews',
        session_id=42,
        verbose=False,
        test_data=test_df,  # Use predefined test set,
        fold_strategy='timeseries',
        data_split_shuffle=False,
        fold_shuffle=False
    )

    best_model = compare_models(exclude=['lightgbm', 'par', 'dummy', 'lar'], sort='R2')
    leaderboard = pull()
    top_model_results = leaderboard.iloc[0]

    preds = predict_model(best_model, data=test_df)
    
    y_true = test_df['total_number_of_emews'].values
    y_pred = preds['prediction_label'].values

    # Standard metrics
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)

    # Custom metrics
    r2_r = r2_rounded(y_true, y_pred)
    rmse_r = rmse_rounded(y_true, y_pred)
    r2_c = r2_ceil(y_true, y_pred)
    rmse_c = rmse_ceil(y_true, y_pred)
    mae_r = mae_rounded(y_true, y_pred)
    mae_c = mae_ceil(y_true, y_pred)

    results.append({
        'dataset': name,
        'model': top_model_results['Model'],
        'R2_train': top_model_results['R2'],
        'R2_test': r2,
        'RMSE_train': top_model_results['RMSE'],
        'RMSE_test': rmse,
        'MAE_train': top_model_results['MAE'],
        'MAE_test': mae,
        'R2_rounded': r2_r,
        'RMSE_rounded': rmse_r,
        'MAE_rounded': mae_r,
        'R2_ceil': r2_c,
        'RMSE_ceil': rmse_c,
        'MAE_ceil': mae_c
    })

results_df_2 = pd.DataFrame(results)
results_df_2 = results_df_2.sort_values(by='R2_test', ascending=False)
print("\n📊 Final Results:")
results_df_2
# Out:
# 🔍 Processing dataset: mean
# <style type="text/css">
# #T_14ad2 th {
#   text-align: left;
# }
# #T_14ad2_row0_col0, #T_14ad2_row0_col5, #T_14ad2_row1_col0, #T_14ad2_row1_col1, #T_14ad2_row1_col2, #T_14ad2_row1_col3, #T_14ad2_row1_col4, #T_14ad2_row1_col5, #T_14ad2_row1_col6, #T_14ad2_row2_col0, #T_14ad2_row2_col1, #T_14ad2_row2_col2, #T_14ad2_row2_col3, #T_14ad2_row2_col4, #T_14ad2_row2_col5, #T_14ad2_row2_col6, #T_14ad2_row3_col0, #T_14ad2_row3_col1, #T_14ad2_row3_col2, #T_14ad2_row3_col3, #T_14ad2_row3_col4, #T_14ad2_row3_col5, #T_14ad2_row3_col6, #T_14ad2_row4_col0, #T_14ad2_row4_col1, #T_14ad2_row4_col2, #T_14ad2_row4_col3, #T_14ad2_row4_col4, #T_14ad2_row4_col5, #T_14ad2_row4_col6, #T_14ad2_row5_col0, #T_14ad2_row5_col1, #T_14ad2_row5_col2, #T_14ad2_row5_col3, #T_14ad2_row5_col4, #T_14ad2_row5_col5, #T_14ad2_row5_col6, #T_14ad2_row6_col0, #T_14ad2_row6_col1, #T_14ad2_row6_col2, #T_14ad2_row6_col3, #T_14ad2_row6_col4, #T_14ad2_row6_col5, #T_14ad2_row6_col6, #T_14ad2_row7_col0, #T_14ad2_row7_col1, #T_14ad2_row7_col2, #T_14ad2_row7_col3, #T_14ad2_row7_col4, #T_14ad2_row7_col5, #T_14ad2_row7_col6, #T_14ad2_row8_col0, #T_14ad2_row8_col1, #T_14ad2_row8_col2, #T_14ad2_row8_col3, #T_14ad2_row8_col4, #T_14ad2_row8_col5, #T_14ad2_row8_col6, #T_14ad2_row9_col0, #T_14ad2_row9_col1, #T_14ad2_row9_col2, #T_14ad2_row9_col3, #T_14ad2_row9_col4, #T_14ad2_row9_col6, #T_14ad2_row10_col0, #T_14ad2_row10_col1, #T_14ad2_row10_col2, #T_14ad2_row10_col3, #T_14ad2_row10_col4, #T_14ad2_row10_col5, #T_14ad2_row10_col6, #T_14ad2_row11_col0, #T_14ad2_row11_col1, #T_14ad2_row11_col2, #T_14ad2_row11_col3, #T_14ad2_row11_col4, #T_14ad2_row11_col5, #T_14ad2_row11_col6, #T_14ad2_row12_col0, #T_14ad2_row12_col1, #T_14ad2_row12_col2, #T_14ad2_row12_col3, #T_14ad2_row12_col4, #T_14ad2_row12_col5, #T_14ad2_row12_col6, #T_14ad2_row13_col0, #T_14ad2_row13_col1, #T_14ad2_row13_col2, #T_14ad2_row13_col3, #T_14ad2_row13_col4, #T_14ad2_row13_col5, #T_14ad2_row13_col6, #T_14ad2_row14_col0, #T_14ad2_row14_col1, #T_14ad2_row14_col2, #T_14ad2_row14_col3, #T_14ad2_row14_col4, #T_14ad2_row14_col5, #T_14ad2_row14_col6, #T_14ad2_row15_col0, #T_14ad2_row15_col1, #T_14ad2_row15_col2, #T_14ad2_row15_col3, #T_14ad2_row15_col4, #T_14ad2_row15_col5, #T_14ad2_row15_col6 {
#   text-align: left;
# }
# #T_14ad2_row0_col1, #T_14ad2_row0_col2, #T_14ad2_row0_col3, #T_14ad2_row0_col4, #T_14ad2_row0_col6, #T_14ad2_row9_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_14ad2_row0_col7, #T_14ad2_row2_col7, #T_14ad2_row3_col7, #T_14ad2_row4_col7, #T_14ad2_row5_col7, #T_14ad2_row6_col7, #T_14ad2_row7_col7, #T_14ad2_row8_col7, #T_14ad2_row9_col7, #T_14ad2_row10_col7, #T_14ad2_row11_col7, #T_14ad2_row14_col7, #T_14ad2_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_14ad2_row1_col7, #T_14ad2_row12_col7, #T_14ad2_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_14ad2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14ad2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_14ad2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_14ad2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_14ad2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_14ad2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_14ad2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_14ad2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_14ad2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14ad2_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_14ad2_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_14ad2_row0_col1" class="data row0 col1" >7.0997</td>
#       <td id="T_14ad2_row0_col2" class="data row0 col2" >312.9918</td>
#       <td id="T_14ad2_row0_col3" class="data row0 col3" >16.1848</td>
#       <td id="T_14ad2_row0_col4" class="data row0 col4" >0.9267</td>
#       <td id="T_14ad2_row0_col5" class="data row0 col5" >0.4353</td>
#       <td id="T_14ad2_row0_col6" class="data row0 col6" >0.0557</td>
#       <td id="T_14ad2_row0_col7" class="data row0 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_14ad2_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_14ad2_row1_col1" class="data row1 col1" >10.1029</td>
#       <td id="T_14ad2_row1_col2" class="data row1 col2" >336.3050</td>
#       <td id="T_14ad2_row1_col3" class="data row1 col3" >16.7265</td>
#       <td id="T_14ad2_row1_col4" class="data row1 col4" >0.9205</td>
#       <td id="T_14ad2_row1_col5" class="data row1 col5" >0.4533</td>
#       <td id="T_14ad2_row1_col6" class="data row1 col6" >0.0953</td>
#       <td id="T_14ad2_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_14ad2_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_14ad2_row2_col1" class="data row2 col1" >10.8984</td>
#       <td id="T_14ad2_row2_col2" class="data row2 col2" >356.3280</td>
#       <td id="T_14ad2_row2_col3" class="data row2 col3" >17.0704</td>
#       <td id="T_14ad2_row2_col4" class="data row2 col4" >0.9178</td>
#       <td id="T_14ad2_row2_col5" class="data row2 col5" >0.4084</td>
#       <td id="T_14ad2_row2_col6" class="data row2 col6" >0.1034</td>
#       <td id="T_14ad2_row2_col7" class="data row2 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_14ad2_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_14ad2_row3_col1" class="data row3 col1" >11.8486</td>
#       <td id="T_14ad2_row3_col2" class="data row3 col2" >396.5323</td>
#       <td id="T_14ad2_row3_col3" class="data row3 col3" >18.1623</td>
#       <td id="T_14ad2_row3_col4" class="data row3 col4" >0.9101</td>
#       <td id="T_14ad2_row3_col5" class="data row3 col5" >0.4235</td>
#       <td id="T_14ad2_row3_col6" class="data row3 col6" >0.1093</td>
#       <td id="T_14ad2_row3_col7" class="data row3 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_14ad2_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_14ad2_row4_col1" class="data row4 col1" >11.8492</td>
#       <td id="T_14ad2_row4_col2" class="data row4 col2" >396.5089</td>
#       <td id="T_14ad2_row4_col3" class="data row4 col3" >18.1620</td>
#       <td id="T_14ad2_row4_col4" class="data row4 col4" >0.9101</td>
#       <td id="T_14ad2_row4_col5" class="data row4 col5" >0.4236</td>
#       <td id="T_14ad2_row4_col6" class="data row4 col6" >0.1093</td>
#       <td id="T_14ad2_row4_col7" class="data row4 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_14ad2_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_14ad2_row5_col1" class="data row5 col1" >13.7131</td>
#       <td id="T_14ad2_row5_col2" class="data row5 col2" >518.1401</td>
#       <td id="T_14ad2_row5_col3" class="data row5 col3" >20.8403</td>
#       <td id="T_14ad2_row5_col4" class="data row5 col4" >0.8885</td>
#       <td id="T_14ad2_row5_col5" class="data row5 col5" >0.4054</td>
#       <td id="T_14ad2_row5_col6" class="data row5 col6" >0.1143</td>
#       <td id="T_14ad2_row5_col7" class="data row5 col7" >0.7770</td>
#     </tr>
#     <tr>
#       <th id="T_14ad2_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_14ad2_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_14ad2_row6_col1" class="data row6 col1" >14.0581</td>
#       <td id="T_14ad2_row6_col2" class="data row6 col2" >521.6504</td>
#       <td id="T_14ad2_row6_col3" class="data row6 col3" >20.7265</td>
#       <td
# <style type="text/css">
# </style>
# <table id="T_1aa2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1aa2a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1aa2a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1aa2a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1aa2a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1aa2a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1aa2a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1aa2a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aa2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1aa2a_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_1aa2a_row0_col1" class="data row0 col1" >9.1381</td>
#       <td id="T_1aa2a_row0_col2" class="data row0 col2" >274.8858</td>
#       <td id="T_1aa2a_row0_col3" class="data row0 col3" >16.5797</td>
#       <td id="T_1aa2a_row0_col4" class="data row0 col4" >0.9457</td>
#       <td id="T_1aa2a_row0_col5" class="data row0 col5" >0.0924</td>
#       <td id="T_1aa2a_row0_col6" class="data row0 col6" >0.0472</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: median
# <style type="text/css">
# #T_769a2 th {
#   text-align: left;
# }
# #T_769a2_row0_col0, #T_769a2_row0_col5, #T_769a2_row1_col0, #T_769a2_row1_col1, #T_769a2_row1_col2, #T_769a2_row1_col3, #T_769a2_row1_col4, #T_769a2_row1_col5, #T_769a2_row1_col6, #T_769a2_row2_col0, #T_769a2_row2_col1, #T_769a2_row2_col2, #T_769a2_row2_col3, #T_769a2_row2_col4, #T_769a2_row2_col5, #T_769a2_row2_col6, #T_769a2_row3_col0, #T_769a2_row3_col1, #T_769a2_row3_col2, #T_769a2_row3_col3, #T_769a2_row3_col4, #T_769a2_row3_col5, #T_769a2_row3_col6, #T_769a2_row4_col0, #T_769a2_row4_col1, #T_769a2_row4_col2, #T_769a2_row4_col3, #T_769a2_row4_col4, #T_769a2_row4_col5, #T_769a2_row4_col6, #T_769a2_row5_col0, #T_769a2_row5_col1, #T_769a2_row5_col2, #T_769a2_row5_col3, #T_769a2_row5_col4, #T_769a2_row5_col5, #T_769a2_row5_col6, #T_769a2_row6_col0, #T_769a2_row6_col1, #T_769a2_row6_col2, #T_769a2_row6_col3, #T_769a2_row6_col4, #T_769a2_row6_col5, #T_769a2_row6_col6, #T_769a2_row7_col0, #T_769a2_row7_col1, #T_769a2_row7_col2, #T_769a2_row7_col3, #T_769a2_row7_col4, #T_769a2_row7_col5, #T_769a2_row7_col6, #T_769a2_row8_col0, #T_769a2_row8_col1, #T_769a2_row8_col2, #T_769a2_row8_col3, #T_769a2_row8_col4, #T_769a2_row8_col5, #T_769a2_row8_col6, #T_769a2_row9_col0, #T_769a2_row9_col1, #T_769a2_row9_col2, #T_769a2_row9_col3, #T_769a2_row9_col4, #T_769a2_row9_col6, #T_769a2_row10_col0, #T_769a2_row10_col1, #T_769a2_row10_col2, #T_769a2_row10_col3, #T_769a2_row10_col4, #T_769a2_row10_col5, #T_769a2_row10_col6, #T_769a2_row11_col0, #T_769a2_row11_col1, #T_769a2_row11_col2, #T_769a2_row11_col3, #T_769a2_row11_col4, #T_769a2_row11_col5, #T_769a2_row11_col6, #T_769a2_row12_col0, #T_769a2_row12_col1, #T_769a2_row12_col2, #T_769a2_row12_col3, #T_769a2_row12_col4, #T_769a2_row12_col5, #T_769a2_row12_col6, #T_769a2_row13_col0, #T_769a2_row13_col1, #T_769a2_row13_col2, #T_769a2_row13_col3, #T_769a2_row13_col4, #T_769a2_row13_col5, #T_769a2_row13_col6, #T_769a2_row14_col0, #T_769a2_row14_col1, #T_769a2_row14_col2, #T_769a2_row14_col3, #T_769a2_row14_col4, #T_769a2_row14_col5, #T_769a2_row14_col6, #T_769a2_row15_col0, #T_769a2_row15_col1, #T_769a2_row15_col2, #T_769a2_row15_col3, #T_769a2_row15_col4, #T_769a2_row15_col5, #T_769a2_row15_col6 {
#   text-align: left;
# }
# #T_769a2_row0_col1, #T_769a2_row0_col2, #T_769a2_row0_col3, #T_769a2_row0_col4, #T_769a2_row0_col6, #T_769a2_row9_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_769a2_row0_col7, #T_769a2_row1_col7, #T_769a2_row3_col7, #T_769a2_row4_col7, #T_769a2_row5_col7, #T_769a2_row6_col7, #T_769a2_row7_col7, #T_769a2_row8_col7, #T_769a2_row9_col7, #T_769a2_row10_col7, #T_769a2_row11_col7, #T_769a2_row12_col7, #T_769a2_row13_col7, #T_769a2_row14_col7, #T_769a2_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_769a2_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_769a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_769a2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_769a2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_769a2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_769a2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_769a2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_769a2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_769a2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_769a2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_769a2_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_769a2_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_769a2_row0_col1" class="data row0 col1" >6.8021</td>
#       <td id="T_769a2_row0_col2" class="data row0 col2" >291.6858</td>
#       <td id="T_769a2_row0_col3" class="data row0 col3" >15.9132</td>
#       <td id="T_769a2_row0_col4" class="data row0 col4" >0.9298</td>
#       <td id="T_769a2_row0_col5" class="data row0 col5" >0.4655</td>
#       <td id="T_769a2_row0_col6" class="data row0 col6" >0.0542</td>
#       <td id="T_769a2_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_769a2_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_769a2_row1_col1" class="data row1 col1" >9.4512</td>
#       <td id="T_769a2_row1_col2" class="data row1 col2" >310.1910</td>
#       <td id="T_769a2_row1_col3" class="data row1 col3" >16.0317</td>
#       <td id="T_769a2_row1_col4" class="data row1 col4" >0.9270</td>
#       <td id="T_769a2_row1_col5" class="data row1 col5" >0.4214</td>
#       <td id="T_769a2_row1_col6" class="data row1 col6" >0.0893</td>
#       <td id="T_769a2_row1_col7" class="data row1 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_769a2_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_769a2_row2_col1" class="data row2 col1" >10.2008</td>
#       <td id="T_769a2_row2_col2" class="data row2 col2" >322.4664</td>
#       <td id="T_769a2_row2_col3" class="data row2 col3" >16.2984</td>
#       <td id="T_769a2_row2_col4" class="data row2 col4" >0.9254</td>
#       <td id="T_769a2_row2_col5" class="data row2 col5" >0.3960</td>
#       <td id="T_769a2_row2_col6" class="data row2 col6" >0.0969</td>
#       <td id="T_769a2_row2_col7" class="data row2 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_769a2_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_769a2_row3_col1" class="data row3 col1" >11.1603</td>
#       <td id="T_769a2_row3_col2" class="data row3 col2" >366.6739</td>
#       <td id="T_769a2_row3_col3" class="data row3 col3" >17.5064</td>
#       <td id="T_769a2_row3_col4" class="data row3 col4" >0.9165</td>
#       <td id="T_769a2_row3_col5" class="data row3 col5" >0.4121</td>
#       <td id="T_769a2_row3_col6" class="data row3 col6" >0.1019</td>
#       <td id="T_769a2_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_769a2_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_769a2_row4_col1" class="data row4 col1" >11.1616</td>
#       <td id="T_769a2_row4_col2" class="data row4 col2" >366.7303</td>
#       <td id="T_769a2_row4_col3" class="data row4 col3" >17.5072</td>
#       <td id="T_769a2_row4_col4" class="data row4 col4" >0.9165</td>
#       <td id="T_769a2_row4_col5" class="data row4 col5" >0.4121</td>
#       <td id="T_769a2_row4_col6" class="data row4 col6" >0.1020</td>
#       <td id="T_769a2_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_769a2_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_769a2_row5_col1" class="data row5 col1" >13.5691</td>
#       <td id="T_769a2_row5_col2" class="data row5 col2" >497.4554</td>
#       <td id="T_769a2_row5_col3" class="data row5 col3" >20.3825</td>
#       <td id="T_769a2_row5_col4" class="data row5 col4" >0.8932</td>
#       <td id="T_769a2_row5_col5" class="data row5 col5" >0.3884</td>
#       <td id="T_769a2_row5_col6" class="data row5 col6" >0.1103</td>
#       <td id="T_769a2_row5_col7" class="data row5 col7" >0.3590</td>
#     </tr>
#     <tr>
#       <th id="T_769a2_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_769a2_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_769a2_row6_col1" class="data row6 col1" >12.9101</td>
#       <td id="T_769a2_row6_col2" class="data row6 col2" >473.8482</td>
#       <td id="T_769a2_row6_col3" class="data row6 col3" >19.8896</td>
#       <td
# <style type="text/css">
# </style>
# <table id="T_d6d52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6d52_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d6d52_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d6d52_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d6d52_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d6d52_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d6d52_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d6d52_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6d52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6d52_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_d6d52_row0_col1" class="data row0 col1" >8.3589</td>
#       <td id="T_d6d52_row0_col2" class="data row0 col2" >246.7574</td>
#       <td id="T_d6d52_row0_col3" class="data row0 col3" >15.7085</td>
#       <td id="T_d6d52_row0_col4" class="data row0 col4" >0.9511</td>
#       <td id="T_d6d52_row0_col5" class="data row0 col5" >0.0922</td>
#       <td id="T_d6d52_row0_col6" class="data row0 col6" >0.0450</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mode
# <style type="text/css">
# #T_57ba5 th {
#   text-align: left;
# }
# #T_57ba5_row0_col0, #T_57ba5_row0_col3, #T_57ba5_row0_col5, #T_57ba5_row1_col0, #T_57ba5_row1_col1, #T_57ba5_row1_col2, #T_57ba5_row1_col4, #T_57ba5_row1_col5, #T_57ba5_row1_col6, #T_57ba5_row2_col0, #T_57ba5_row2_col1, #T_57ba5_row2_col2, #T_57ba5_row2_col3, #T_57ba5_row2_col4, #T_57ba5_row2_col5, #T_57ba5_row2_col6, #T_57ba5_row3_col0, #T_57ba5_row3_col1, #T_57ba5_row3_col2, #T_57ba5_row3_col3, #T_57ba5_row3_col4, #T_57ba5_row3_col5, #T_57ba5_row3_col6, #T_57ba5_row4_col0, #T_57ba5_row4_col1, #T_57
>0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_57ba5_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_57ba5_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_57ba5_row5_col1" class="data row5 col1" >11.9452</td>
#       <td id="T_57ba5_row5_col2" class="data row5 col2" >393.1532</td>
#       <td id="T_57ba5_row5_col3" class="data row5 col3" >18.2989</td>
#       <td id="T_57ba5_row5_col4" class="data row5 col4" >0.9130</td>
#       <td id="T_57ba5_row5_col5" class="data row5 col5" >0.3533</td>
#       <td id="T_57ba5_row5_col6" class="data row5 col6" >0.0968</td>
#       <td id="T_57ba5_row5_col7" class="data row5 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_57ba5_level0_row6" class="row_heading level0 row6" >catboost</th>
#       <td id="T_57ba5_row6_col0" class="data row6 col0" >CatBoost Regressor</td>
#       <td id="T_57ba5_row6_col1" class="data row6 col1" >12.1371</td>
#       <td id="T_57ba5_row6_col2" class="data row6 col2" >451.3796</td>
#       <td id="T_57ba5_row6_col3" class="data row6 col3" >19.3080</td>
# <style type="text/css">
# </style>
# <table id="T_2a625">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a625_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2a625_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2a625_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2a625_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2a625_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2a625_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2a625_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a625_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a625_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_2a625_row0_col1" class="data row0 col1" >10.9190</td>
#       <td id="T_2a625_row0_col2" class="data row0 col2" >354.1548</td>
#       <td id="T_2a625_row0_col3" class="data row0 col3" >18.8190</td>
#       <td id="T_2a625_row0_col4" class="data row0 col4" >0.9289</td>
#       <td id="T_2a625_row0_col5" class="data row0 col5" >0.0918</td>
#       <td id="T_2a625_row0_col6" class="data row0 col6" >0.0528</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice
# <style type="text/css">
# #T_52bf0 th {
#   text-align: left;
# }
# #T_52bf0_row0_col0, #T_52bf0_row0_col5, #T_52bf0_row1_col0, #T_52bf0_row1_col1, #T_52bf0_row1_col2, #T_52bf0_row1_col3, #T_52bf0_row1_col4, #T_52bf0_row1_col5, #T_52bf0_row1_col6, #T_52bf0_row2_col0, #T_52bf0_row2_col1, #T_52bf0_row2_col2, #T_52bf0_row2_col3, #T_52bf0_row2_col4, #T_52bf0_row2_col5, #T_52bf0_row2_col6, #T_52bf0_row3_col0, #T_52bf0_row3_col1, #T_52bf0_row3_col2, #T_52bf0_row3_col3, #T_52bf0_row3_col4, #T_52bf0_row3_col5, #T_52bf0_row3_col6, #T_52bf0_row4_col0, #T_52bf0_row4_col1, #T_52bf0_row4_col2, #T_52bf0_row4_col3, #T_52bf0_row4_col4, #T_52bf0_row4_col5, #T_52bf0_row4_col6, #T_52bf0_row5_col0, #T_52bf0_row5_col1, #T_52bf0_row5_col2, #T_52bf0_row5_col3, #T_52bf0_row5_col4, #T_52bf0_row5_col5, #T_52bf0_row5_col6, #T_52bf0_row6_col0, #T_52bf0_row6_col1, #T_52bf0_row6_col2, #T_52bf0_row6_col3, #T_52bf0_row6_col4, #T_52bf0_row6_col5, #T_52bf0_row6_col6, #T_52bf0_row7_col0, #T_52bf0_row7_col1, #T_52bf0_row7_col2, #T_52bf0_row7_col3, #T_52bf0_row7_col4, #T_52bf0_row7_col6, #T_52bf0_row8_col0, #T_52bf0_row8_col1, #T_52bf0_row8_col2, #T_52bf0_row8_col3, #T_52bf0_row8_col4, #T_52bf0_row8_col5, #T_52bf0_row8_col6, #T_52bf0_row9_col0, #T_52bf0_row9_col1, #T_52bf0_row9_col2, #T_52bf0_row9_col3, #T_52bf0_row9_col4, #T_52bf0_row9_col5, #T_52bf0_row9_col6, #T_52bf0_row10_col0, #T_52bf0_row10_col1, #T_52bf0_row10_col2, #T_52bf0_row10_col3, #T_52bf0_row10_col4, #T_52bf0_row10_col5, #T_52bf0_row10_col6, #T_52bf0_row11_col0, #T_52bf0_row11_col1, #T_52bf0_row11_col2, #T_52bf0_row11_col3, #T_52bf0_row11_col4, #T_52bf0_row11_col5, #T_52bf0_row11_col6, #T_52bf0_row12_col0, #T_52bf0_row12_col1, #T_52bf0_row12_col2, #T_52bf0_row12_col3, #T_52bf0_row12_col4, #T_52bf0_row12_col5, #T_52bf0_row12_col6, #T_52bf0_row13_col0, #T_52bf0_row13_col1, #T_52bf0_row13_col2, #T_52bf0_row13_col3, #T_52bf0_row13_col4, #T_52bf0_row13_col5, #T_52bf0_row13_col6, #T_52bf0_row14_col0, #T_52bf0_row14_col1, #T_52bf0_row14_col2, #T_52bf0_row14_col3, #T_52bf0_row14_col4, #T_52bf0_row14_col5, #T_52bf0_row14_col6, #T_52bf0_row15_col0, #T_52bf0_row15_col1, #T_52bf0_row15_col2, #T_52bf0_row15_col3, #T_52bf0_row15_col4, #T_52bf0_row15_col5, #T_52bf0_row15_col6 {
#   text-align: left;
# }
# #T_52bf0_row0_col1, #T_52bf0_row0_col2, #T_52bf0_row0_col3, #T_52bf0_row0_col4, #T_52bf0_row0_col6, #T_52bf0_row7_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_52bf0_row0_col7, #T_52bf0_row3_col7, #T_52bf0_row5_col7, #T_52bf0_row7_col7, #T_52bf0_row8_col7, #T_52bf0_row9_col7, #T_52bf0_row10_col7, #T_52bf0_row11_col7, #T_52bf0_row12_col7, #T_52bf0_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_52bf0_row1_col7, #T_52bf0_row2_col7, #T_52bf0_row4_col7, #T_52bf0_row6_col7, #T_52bf0_row13_col7, #T_52bf0_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_52bf0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52bf0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_52bf0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_52bf0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_52bf0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_52bf0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_52bf0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_52bf0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_52bf0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52bf0_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_52bf0_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_52bf0_row0_col1" class="data row0 col1" >7.9838</td>
#       <td id="T_52bf0_row0_col2" class="data row0 col2" >249.9081</td>
#       <td id="T_52bf0_row0_col3" class="data row0 col3" >14.1079</td>
#       <td id="T_52bf0_row0_col4" class="data row0 col4" >0.9440</td>
#       <td id="T_52bf0_row0_col5" class="data row0 col5" >0.3709</td>
#       <td id="T_52bf0_row0_col6" class="data row0 col6" >0.0739</td>
#       <td id="T_52bf0_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_52bf0_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_52bf0_row1_col1" class="data row1 col1" >10.4988</td>
#       <td id="T_52bf0_row1_col2" class="data row1 col2" >318.6171</td>
#       <td id="T_52bf0_row1_col3" class="data row1 col3" >15.7339</td>
#       <td id="T_52bf0_row1_col4" class="data row1 col4" >0.9279</td>
#       <td id="T_52bf0_row1_col5" class="data row1 col5" >0.4171</td>
#       <td id="T_52bf0_row1_col6" class="data row1 col6" >0.1015</td>
#       <td id="T_52bf0_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_52bf0_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_52bf0_row2_col1" class="data row2 col1" >11.2844</td>
#       <td id="T_52bf0_row2_col2" class="data row2 col2" >358.4178</td>
#       <td id="T_52bf0_row2_col3" class="data row2 col3" >16.3633</td>
#       <td id="T_52bf0_row2_col4" class="data row2 col4" >0.9214</td>
#       <td id="T_52bf0_row2_col5" class="data row2 col5" >0.3877</td>
#       <td id="T_52bf0_row2_col6" class="data row2 col6" >0.1087</td>
#       <td id="T_52bf0_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_52bf0_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_52bf0_row3_col1" class="data row3 col1" >12.2812</td>
#       <td id="T_52bf0_row3_col2" class="data row3 col2" >399.2612</td>
#       <td id="T_52bf0_row3_col3" class="data row3 col3" >17.4197</td>
#       <td id="T_52bf0_row3_col4" class="data row3 col4" >0.9133</td>
#       <td id="T_52bf0_row3_col5" class="data row3 col5" >0.4146</td>
#       <td id="T_52bf0_row3_col6" class="data row3 col6" >0.1147</td>
#       <td id="T_52bf0_row3_col7" class="data row3 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_52bf0_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_52bf0_row4_col1" class="data row4 col1" >12.2804</td>
#       <td id="T_52bf0_row4_col2" class="data row4 col2" >399.1036</td>
#       <td id="T_52bf0_row4_col3" class="data row4 col3" >17.4181</td>
#       <td id="T_52bf0_row4_col4" class="data row4 col4" >0.9133</td>
#       <td id="T_52bf0_row4_col5" class="data row4 col5" >0.4146</td>
#       <td id="T_52bf0_row4_col6" class="data row4 col6" >0.1147</td>
#       <td id="T_52bf0_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_52bf0_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_52bf0_row5_col1" class="data row5 col1" >14.7433</td>
#       <td id="T_52bf0_row5_col2" class="data row5 col2" >586.4527</td>
#       <td id="T_52bf0_row5_col3" class="data row5 col3" >22.4901</td>
#       <td id="T_52bf0_row5_col4" class="data row5 col4" >0.8677</td>
#       <td id="T_52bf0_row5_col5" class="data row5 col5" >0.4226</td>
#       <td id="T_52bf0_row5_col6" class="data row5 col6" >0.1228</td>
#       <td id="T_52bf0_row5_col7" class="data row5 col7" >0.3780</td>
#     </tr>
#     <tr>
#       <th id="T_52bf0_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_52bf0_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_52bf0_row6_col1" class="data row6 col1" >14.9570</td>
#       <td id="T_52bf0_row6_col2" class="data row6 col2" >658.3021</td>
#       <td id="T_52bf0_row6_col3" class="data row6 col3" >21.0312</td>
#       <td
# <style type="text/css">
# </style>
# <table id="T_ac814">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac814_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ac814_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ac814_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ac814_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ac814_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ac814_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ac814_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac814_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac814_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_ac814_row0_col1" class="data row0 col1" >10.7292</td>
#       <td id="T_ac814_row0_col2" class="data row0 col2" >289.7338</td>
#       <td id="T_ac814_row0_col3" class="data row0 col3" >17.0216</td>
#       <td id="T_ac814_row0_col4" class="data row0 col4" >0.9424</td>
#       <td id="T_ac814_row0_col5" class="data row0 col5" >0.0929</td>
#       <td id="T_ac814_row0_col6" class="data row0 col6" >0.0564</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice_hgb
# <style type="text/css">
# #T_74cfb th {
#   text-align: left;
# }
# #T_74cfb_row0_col0, #T_74cfb_row0_col5, #T_74cfb_row0_col6, #T_74cfb_row1_col0, #T_74cfb_row1_col1, #T_74cfb_row1_col2, #T_74cfb_row1_col3, #T_74cfb_row1_col4, #T_74cfb_row1_col5, #T_74cfb_row1_col6, #T_74cfb_row2_col0, #T_74cfb_row2_col1, #T_74cfb_row2_col2, #T_74cfb_row2_col3, #T_74cfb_row2_col4, #T_74cfb_row2_col5, #T_74cfb_row2_col6, #T_74cfb_row3_col0, #T_74cfb_row3_col1, #T_74cfb_row3_col2, #T_74cfb_row3_col3, #T_74cfb_row3_col4, #T_74cfb_row3_col5, #T_74cfb_row3_col6, #T_74cfb_row4_col0, #T_74cfb_row4_col1, #T_74cfb_row4_col2, #T_74cfb_row4_col3, #T_74cfb_row4_col4, #T_74cfb_row4_col5, #T_74cfb_row4_col6, #T_74cfb_row5_col0, #T_74cfb_row5_col1, #T_74cfb_row5_col2, #T_74cfb_row5_col3, #T_74cfb_row5_col4, #T_74cfb_row5_col5, #T_74cfb_row5_col6, #T_74cfb_row6_col0, #T_74cfb_row6_col1, #T_74cfb_row6_col2, #T_74cfb_row6_col3, #T_74cfb_row6_col4, #T_74cfb_row6_col5, #T_74cfb_row6_col6, #T_74cfb_row7_col0, #T_74cfb_row7_col1, #T_74cfb_row7_col2, #T_74cfb_row7_col3, #T_74cfb_row7_col4, #T_74cfb_row7_col5, #T_74cfb_row8_col0, #T_74cfb_row8_col1, #T_74cfb_row8_col2, #T_74cfb_row8_col3, #T_74cfb_row8_col4, #T_74cfb_row8_col6, #T_74cfb_row9_col0, #T_74cfb_row9_col1, #T_74cfb_row9_col2, #T_74cfb_row9_col3, #T_74cfb_row9_col4, #T_74cfb_row9_col5, #T_74cfb_row9_col6, #T_74cfb_row10_col0, #T_74cfb_row10_col1, #T_74cfb_row10_col2, #T_74cfb_row10_col3, #T_74cfb_row10_col4, #T_74cfb_row10_col5, #T_74cfb_row10_col6, #T_74cfb_row11_col0, #T_74cfb_row11_col1, #T_74cfb_row11_col2, #T_74cfb_row11_col3, #T_74cfb_row11_col4, #T_74cfb_row11_col5, #T_74cfb_row11_col6, #T_74cfb_row12_col0, #T_74cfb_row12_col1, #T_74cfb_row12_col2, #T_74cfb_row12_col3, #T_74cfb_row12_col4, #T_74cfb_row12_col5, #T_74cfb_row12_col6, #T_74cfb_row13_col0, #T_74cfb_row13_col1, #T_74cfb_row13_col2, #T_74cfb_row13_col3, #T_74cfb_row13_col4, #T_74cfb_row13_col5, #T_74cfb_row13_col6, #T_74cfb_row14_col0, #T_74cfb_row14_col1, #T_74cfb_row14_col2, #T_74cfb_row14_col3, #T_74cfb_row14_col4, #T_74cfb_row14_col5, #T_74cfb_row14_col6, #T_74cfb_row15_col0, #T_74cfb_row15_col1, #T_74cfb_row15_col2, #T_74cfb_row15_col3, #T_74cfb_row15_col4, #T_74cfb_row15_col5, #T_74cfb_row15_col6 {
#   text-align: left;
# }
# #T_74cfb_row0_col1, #T_74cfb_row0_col2, #T_74cfb_row0_col3, #T_74cfb_row0_col4, #T_74cfb_row7_col6, #T_74cfb_row8_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_74cfb_row0_col7, #T_74cfb_row3_col7, #T_74cfb_row4_col7, #T_74cfb_row7_col7, #T_74cfb_row8_col7, #T_74cfb_row10_col7, #T_74cfb_row12_col7, #T_74cfb_row13_col7, #T_74cfb_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_74cfb_row1_col7, #T_74cfb_row2_col7, #T_74cfb_row5_col7, #T_74cfb_row6_col7, #T_74cfb_row9_col7, #T_74cfb_row11_col7, #T_74cfb_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_74cfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74cfb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_74cfb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_74cfb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_74cfb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_74cfb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_74cfb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_74cfb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_74cfb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74cfb_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_74cfb_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_74cfb_row0_col1" class="data row0 col1" >12.0681</td>
#       <td id="T_74cfb_row0_col2" class="data row0 col2" >380.3682</td>
#       <td id="T_74cfb_row0_col3" class="data row0 col3" >18.2981</td>
#       <td id="T_74cfb_row0_col4" class="data row0 col4" >0.9060</td>
#       <td id="T_74cfb_row0_col5" class="data row0 col5" >0.3555</td>
#       <td id="T_74cfb_row0_col6" class="data row0 col6" >0.1211</td>
#       <td id="T_74cfb_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_74cfb_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_74cfb_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_74cfb_row1_col1" class="data row1 col1" >13.1048</td>
#       <td id="T_74cfb_row1_col2" class="data row1 col2" >405.9382</td>
#       <td id="T_74cfb_row1_col3" class="data row1 col3" >18.9844</td>
#       <td id="T_74cfb_row1_col4" class="data row1 col4" >0.8974</td>
#       <td id="T_74cfb_row1_col5" class="data row1 col5" >0.4332</td>
#       <td id="T_74cfb_row1_col6" class="data row1 col6" >0.1311</td>
#       <td id="T_74cfb_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T
col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_74cfb_level0_row6" class="row_heading level0 row6" >llar</th>
#       <td id="T_74cfb_row6_col0" class="data row6 col0" >Lasso Least Angle Regression</td>
#       <td id="T_74cfb_row6_col1" class="data row6 col1" >16.0439</td>
#       <td id="T_74cfb_row6_col2" class="data row6 col2" >635.1710</td>
#       <td id="T_74cfb_row6_col3" class="data row6 col3" >22.6387</td>
# <style type="text/css">
# </style>
# <table id="T_89ef3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89ef3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_89ef3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_89ef3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_89ef3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_89ef3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_89ef3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_89ef3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89ef3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89ef3_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_89ef3_row0_col1" class="data row0 col1" >15.7760</td>
#       <td id="T_89ef3_row0_col2" class="data row0 col2" >592.6742</td>
#       <td id="T_89ef3_row0_col3" class="data row0 col3" >24.3449</td>
#       <td id="T_89ef3_row0_col4" class="data row0 col4" >0.8919</td>
#       <td id="T_89ef3_row0_col5" class="data row0 col5" >0.1167</td>
#       <td id="T_89ef3_row0_col6" class="data row0 col6" >0.0831</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice_lr
# <style type="text/css">
# #T_ae6d2 th {
#   text-align: left;
# }
# ...
#       <td id="T_cff2f_row4_col5" class="data row4 col5" >0.4337</td>
#       <td id="T_cff2f_row4_col6" class="data row4 col6" >0.1315</td>
#       <td id="T_cff2f_row4_col7" class="data row4 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_cff2f_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_cff2f_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_cff2f_row5_col1" class="data row5 col1" >16.4216</td>
#       <td id="T_cff2f_row5_col2" class="data row5 col2" >584.9550</td>
#       <td id="T_cff2f_row5_col3" class="data row5 col3" >21.8207</td>
#       <td id="T_cff2f_row5_col4" class="data row5 col4" >0.8653</td>
#       <td id="T_cff2f_row5_col5" class="data row5 col5" >0.4545</td>
#       <td id="T_cff2f_row5_col6" class="data row5 col6" >0.1531</td>
#       <td id="T_cff2f_row5_col7" class="data row5 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_cff2f_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_cff2f_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_cff2f_row6_col1" class="data row6 col1" >17.1267</td>
#       <td id="T_cff2f_row6_col2" class="data row6 col2" >644.5716</td>
#       <td id="T_cff2f_row6_col3" class="data row6 col3" >22.5195</td>
#       <td id="T
# <style type="text/css">
# </style>
# <table id="T_514ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_514ec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_514ec_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_514ec_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_514ec_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_514ec_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_514ec_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_514ec_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_514ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_514ec_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_514ec_row0_col1" class="data row0 col1" >13.3290</td>
#       <td id="T_514ec_row0_col2" class="data row0 col2" >454.2332</td>
#       <td id="T_514ec_row0_col3" class="data row0 col3" >21.3127</td>
#       <td id="T_514ec_row0_col4" class="data row0 col4" >0.9094</td>
#       <td id="T_514ec_row0_col5" class="data row0 col5" >0.1046</td>
#       <td id="T_514ec_row0_col6" class="data row0 col6" >0.0694</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Processing dataset: mice_knn_5_distance
# <style type="text/css">
# #T_fb153 th {
#   text-align: left;
# }
# #T_fb153_row0_col0, #T_fb153_row0_col5, #T_fb153_row1_col0, #T_fb153_row1_col1, #T_fb153_row1_col2, #T_fb153_row1_col3, #T_fb153_row1_col4, #T_fb153_row1_col5, #T_fb153_row1_col6, #T_fb153_row2_col0, #T_fb153_row2_col1, #T_fb153_row2_col2, #T_fb153_row2_col3, #T_fb153_row2_col4, #T_fb153_row2_col5, #T_fb153_row2_col6, #T_fb153_row3_col0, #T_fb153_row3_col1, #T_fb153_row3_col2, #T_fb153_row3_col3, #T_fb153_row3_col4, #T_fb153_row3_col5, #T_fb153_row3_col6, #T_fb153_row4_col0, #T_fb153_row4_col1, #T_fb153_row4_col2, #T_fb153_row4_col3, #T_fb153_row4_col4, #T_fb153_row4_col5, #T_fb153_row4_col6, #T_fb153_row5_col0, #T_fb153_row5_col1, #T_fb153_row5_col2, #T_fb153_row5_col3, #T_fb153_row5_col4, #T_fb153_row5_col5, #T_fb153_row5_col6, #T_fb153_row6_col0, #T_fb153_row6_col1, #T_fb153_row6_col2, #T_fb153_row6_col3, #T_fb153_row6_col4, #T_fb153_row6_col5, #T_fb153_row6_col6, #T_fb153_row7_col0, #T_fb153_row7_col1, #T_fb153_row7_col2, #T_fb153_row7_col3, #T_fb153_row7_col4, #T_fb153_row7_col5, #T_fb153_row7_col6, #T_fb153_row8_col0, #T_fb153_row8_col1, #T_fb153_row8_col2, #T_fb153_row8_col3, #T_fb153_row8_col4, #T_fb153_row8_col5, #T_fb153_row8_col6, #T_fb153_row9_col0, #T_fb153_row9_col1, #T_fb153_row9_col2, #T_fb153_row9_col3, #T_fb153_row9_col4, #T_fb153_row9_col6, #T_fb153_row10_col0, #T_fb153_row10_col1, #T_fb153_row10_col2, #T_fb153_row10_col3, #T_fb153_row10_col4, #T_fb153_row10_col5, #T_fb153_row10_col6, #T_fb153_row11_col0, #T_fb153_row11_col1, #T_fb153_row11_col2, #T_fb153_row11_col3, #T_fb153_row11_col4, #T_fb153_row11_col5, #T_fb153_row11_col6, #T_fb153_row12_col0, #T_fb153_row12_col1, #T_fb153_row12_col2, #T_fb153_row12_col3, #T_fb153_row12_col4, #T_fb153_row12_col5, #T_fb153_row12_col6, #T_fb153_row13_col0, #T_fb153_row13_col1, #T_fb153_row13_col2, #T_fb153_row13_col3, #T_fb153_row13_col4, #T_fb153_row13_col5, #T_fb153_row13_col6, #T_fb153_row14_col0, #T_fb153_row14_col1, #T_fb153_row14_col2, #T_fb153_row14_col3, #T_fb153_row14_col4, #T_fb153_row14_col5, #T_fb153_row14_col6, #T_fb153_row15_col0, #T_fb153_row15_col1, #T_fb153_row15_col2, #T_fb153_row15_col3, #T_fb153_row15_col4, #T_fb153_row15_col5, #T_fb153_row15_col6 {
#   text-align: left;
# }
# #T_fb153_row0_col1, #T_fb153_row0_col2, #T_fb153_row0_col3, #T_fb153_row0_col4, #T_fb153_row0_col6, #T_fb153_row9_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fb153_row0_col7, #T_fb153_row1_col7, #T_fb153_row3_col7, #T_fb153_row4_col7, #T_fb153_row5_col7, #T_fb153_row6_col7, #T_fb153_row7_col7, #T_fb153_row8_col7, #T_fb153_row9_col7, #T_fb153_row10_col7, #T_fb153_row11_col7, #T_fb153_row12_col7, #T_fb153_row13_col7, #T_fb153_row14_col7, #T_fb153_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fb153_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fb153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb153_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fb153_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fb153_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fb153_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fb153_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fb153_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fb153_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fb153_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb153_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_fb153_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_fb153_row0_col1" class="data row0 col1" >10.8676</td>
#       <td id="T_fb153_row0_col2" class="data row0 col2" >341.6913</td>
#       <td id="T_fb153_row0_col3" class="data row0 col3" >17.0667</td>
#       <td id="T_fb153_row0_col4" class="data row0 col4" >0.9172</td>
#       <td id="T_fb153_row0_col5" class="data row0 col5" >0.3210</td>
#       <td id="T_fb153_row0_col6" class="data row0 col6" >0.1036</td>
#       <td id="T_fb153_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_fb153_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_fb153_row1_col1" class="data row1 col1" >11.9136</td>
#       <td id="T_fb153_row1_col2" class="data row1 col2" >375.8389</td>
#       <td id="T_fb153_row1_col3" class="data row1 col3" >17.6038</td>
#       <td id="T_fb153_row1_col4" class="data row1 col4" >0.9108</td>
#       <td id="T_fb153_row1_col5" class="data row1 col5" >0.3998</td>
#       <td id="T_fb153_row1_col6" class="data row1 col6" >0.1103</td>
#       <td id="T_fb153_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_fb153_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_fb153_row2_col1" class="data row2 col1" >12.7554</td>
#       <td id="T_fb153_row2_col2" class="data row2 col2" >396.9452</td>
#       <td id="T_fb153_row2_col3" class="data row2 col3" >18.0617</td>
#       <td id="T_fb153_row2_col4" class="data row2 col4" >0.9067</td>
#       <td id="T_fb153_row2_col5" class="data row2 col5" >0.4282</td>
#       <td id="T_fb153_row2_col6" class="data row2 col6" >0.1168</td>
#       <td id="T_fb153_row2_col7" class="data row2 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_fb153_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_fb153_row3_col1" class="data row3 col1" >14.2618</td>
#       <td id="T_fb153_row3_col2" class="data row3 col2" >468.7436</td>
#       <td id="T_fb153_row3_col3" class="data row3 col3" >19.6102</td>
#       <td id="T_fb153_row3_col4" class="data row3 col4" >0.8928</td>
#       <td id="T_fb153_row3_col5" class="data row3 col5" >0.4425</td>
#       <td id="T_fb153_row3_col6" class="data row3 col6" >0.1268</td>
#       <td id="T_fb153_row3_col7" class="data row3 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_fb153_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_fb153_row4_col1" class="data row4 col1" >14.2615</td>
#       <td id="T_fb153_row4_col2" class="data row4 col2" >468.7058</td>
#       <td id="T_fb153_row4_col3" class="data row4 col3" >19.6098</td>
#       <td id="T_fb153_row4_col4" class="data row4 col4" >0.8928</td>
#       <td id="T_fb153_row4_col5" class="data row4 col5" >0.4425</td>
#       <td id="T_fb153_row4_col6" class="data row4 col6" >0.1268</td>
#       <td id="T_fb153_row4_col7" class="data row4 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_fb153_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_fb153_row5_col1" class="data row5 col1" >16.0662</td>
#       <td id="T_fb153_row5_col2" class="data row5 col2" >563.5427</td>
#       <td id="T_fb153_row5_col3" class="data row5 col3" >21.4935</td>
#       <td id="T_fb153_row5_col4" class="data row5 col4" >0.8701</td>
#       <td id="T_fb153_row5_col5" class="data row5 col5" >0.5120</td>
#       <td id="T_fb153_row5_col6" class="data row5 col6" >0.1430</td>
#       <td id="T_fb153_row5_col7" class="data row5 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fb153_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_fb153_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_fb153_row6_col1" class="data row6 col1" >17.0160</td>
#       <td id="T_fb153_row6_col2" class="data row6 col2" >661.5854</td>
#       <td id="T_fb153_row6_col3" class="data row6 col3" >22.5658</td>
#       <td id="T
# <style type="text/css">
# </style>
# <table id="T_5db68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5db68_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5db68_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5db68_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5db68_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5db68_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5db68_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5db68_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5db68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5db68_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_5db68_row0_col1" class="data row0 col1" >13.5792</td>
#       <td id="T_5db68_row0_col2" class="data row0 col2" >452.3763</td>
#       <td id="T_5db68_row0_col3" class="data row0 col3" >21.2691</td>
#       <td id="T_5db68_row0_col4" class="data row0 col4" >0.9098</td>
#       <td id="T_5db68_row0_col5" class="data row0 col5" >0.1026</td>
#       <td id="T_5db68_row0_col6" class="data row0 col6" >0.0707</td>
#     </tr>
#   </tbody>
# </table>
# 📊 Final Results:
#                 dataset            model  R2_train   R2_test  RMSE_train  \
# 1                median  Huber Regressor    0.9298  0.951102     15.9132
# 0                  mean  Huber Regressor    0.9267  0.945662     16.1848
# 5               mice_lr  Huber Regressor    0.9375  0.945629     15.0253
# 3                  mice  Huber Regressor    0.9440  0.942365     14.1079
# 2                  mode  Huber Regressor    0.9407  0.928914     14.7901
# 14           mice_knn_4  Huber Regressor    0.9107  0.921605     17.8051
# 15  mice_knn_4_distance  Huber Regressor    0.9106  0.917191     17.6699
# 17       knn_5_distance  Huber Regressor    0.9044  0.912094     18.1295
# 8                 knn_3  Huber Regressor    0.8926  0.910302     19.2868
# 19  mice_knn_5_distance  Huber Regressor    0.9172  0.909770     17.0667
# 18           mice_knn_5  Huber Regressor    0.9174  0.909408     17.0167
# 16                knn_5  Huber Regressor    0.9077  0.909117     17.9533
# 9        knn_3_distance  Huber Regressor    0.8943  0.904954     19.1855
# 13       knn_4_distance  Huber Regressor    0.9013  0.904047     18.4629
# 18  0.910491  21.184900  13.233333
# 9   0.905930  21.819334  14.116667
# 13  0.905002  21.914987  13.700000
# 10  0.904544  21.900913  14.416667
# 12  0.902107  22.248595  13.833333
# 11  0.897660  22.693979  15.250000
# 7   0.894126  23.075600  14.783333
# 4   0.892882  24.237712  15.766667
# 6   0.891378  24.222923  15.283333

# %%
# for name, (train_df, test_df) in datasets.items():
#     path = f'data/imputed/'
#     os.makedirs(path, exist_ok=True)

#     df = pd.concat([train_df, test_df], axis=0).sort_values(by='date').reset_index(drop=True)

#     df.to_csv(path+f'{name}_df.csv', index=False)

# %%
full_df = pd.concat([train_data, test_data], ignore_index=True)

X_full = full_df.drop(columns=['total_number_of_patients', 'total_number_of_emews'])
y_full = full_df[['total_number_of_patients', 'total_number_of_emews']]

patient_cols = ['zone_a_mwr_patients', 'zone_a__patients', 'zone_b/c_patients']
emews_cols = ['zone_a_mwr_sets_of_emews', 'zone_a__sets_of_emews', 'zone_b/c_sets_of_emews']

# %%
def apply_final_imputation(X: pd.DataFrame, imputer):
    num_cols = X.select_dtypes(include='number').columns

    X_num = X[num_cols]
    needs_scaling = isinstance(imputer, (KNNImputer, IterativeImputer))

    if needs_scaling:
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X_num)
        X_imputed = imputer.fit_transform(X_scaled)
        X_imputed = scaler.inverse_transform(X_imputed)
    else:
        X_imputed = imputer.fit_transform(X_num)

    X_imputed = np.round(X_imputed).astype(int)
    X_final = X.copy()
    X_final[num_cols] = X_imputed
    return X_final

# %%
imputed_datasets = {}

for name, imputer in imputation_strategies.items():
    print(f"🔧 Imputing with: {name}")

    X_imputed = apply_final_imputation(X_full.copy(), imputer)

    # Combine with target values again
    df_imputed = pd.concat([X_imputed, y_full.copy()], axis=1)

    # Fix totals if needed
    df_imputed['total_number_of_patients'] = df_imputed['total_number_of_patients'].fillna(
        df_imputed[patient_cols].sum(axis=1)
    )
    df_imputed['total_number_of_emews'] = df_imputed['total_number_of_emews'].fillna(
        df_imputed[emews_cols].sum(axis=1)
    )

    # Save to dictionary
    imputed_datasets[name] = df_imputed
# Out:
# 🔧 Imputing with: mean
# 🔧 Imputing with: median
# 🔧 Imputing with: mode
# 🔧 Imputing with: mice
# 🔧 Imputing with: mice_hgb
# 🔧 Imputing with: mice_lr
# 🔧 Imputing with: mice_rf
# 🔧 Imputing with: mice_svr
# 🔧 Imputing with: knn_3
# 🔧 Imputing with: knn_3_distance
# 🔧 Imputing with: mice_knn_3
# 🔧 Imputing with: mice_knn_3_distance
# 🔧 Imputing with: knn_4
# 🔧 Imputing with: knn_4_distance
# 🔧 Imputing with: mice_knn_4
# 🔧 Imputing with: mice_knn_4_distance
# 🔧 Imputing with: knn_5
# 🔧 Imputing with: knn_5_distance
# 🔧 Imputing with: mice_knn_5
# 🔧 Imputing with: mice_knn_5_distance

# %%
for name, dataframe in imputed_datasets.items():
    path = f'data/imputed2/'
    os.makedirs(path, exist_ok=True)

    dataframe.to_csv(path+f'{name}_df.csv', index=False)
