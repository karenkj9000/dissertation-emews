# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df = pd.read_csv("data/EMEWS_cleaned_with_fillna_0.csv")

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[["total_number_of_emews", "zone_a_mwr_sets_of_emews", "zone_a__sets_of_emews"]])
plt.title("Boxplot of EMEWS-related Columns")
plt.show()
